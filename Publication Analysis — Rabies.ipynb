# %% [markdown]
# # Publication Analysis

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import necessary packages

# %%
import requests, lxml, sys, sent2vec, nltk, cProfile

import numpy as np
import matplotlib.pyplot as plt
import bayesian_changepoint_detection.offline_changepoint_detection as offcd

from sklearn.feature_extraction.text import CountVectorizer
from nltk import word_tokenize
from nltk.corpus import stopwords
from string import punctuation
from sklearn.decomposition import PCA
from functools import partial
from wordcloud import WordCloud
from bs4 import BeautifulSoup
# Out:
# Use scipy logsumexp().

# %% [markdown]
# ### Load models

# %%
nltk.download('stopwords')
nltk.download('punkt')

model_path = 'biosentvec.bin'
model = sent2vec.Sent2vecModel()
model.load_model(model_path)
# Out:
# [nltk_data] Downloading package stopwords to /Users/dddp/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/dddp/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Set constants

# %%
term = 'Rabies'

BASE_URL = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/'
MIN_PAPERS = 50 # minimum number of papers in a year to use for analysis
stop_words = set(stopwords.words('english'))

# %% [markdown]
# ### Define helper functions

# %%
# preprocesses text before BioSentVec embedding
def preprocess_sentence(text):
    text = text.replace('/', ' / ')
    text = text.replace('.-', ' .- ')
    text = text.replace('.', ' . ')
    text = text.replace('\'', ' \' ')
    text = text.lower()

    tokens = [token for token in word_tokenize(text) if token not in punctuation and token not in stop_words]

    return ' '.join(tokens)

# computes Euclidean distance
def dist(x, y):
    return np.linalg.norm(x - y)

# converts a list to a comma separated values format
def list_to_csv(lst):
    ret = ''
    for i, val in enumerate(lst):
        ret += f'{val},'
    return ret[:-1]

# returns the UIDs of papers based on searching the title for a query
def get_uids(query):
    uid_list = []

    retstart = 0
    RETMAX = 100000
    
    while True:
        params = {
            'db': 'pubmed',
            'term': f'{query}[title]',
            'retmax': RETMAX,
            'retstart': retstart,
        }
        res = requests.get(f'{BASE_URL}esearch.fcgi', params)
        soup = BeautifulSoup(res.text, 'xml')
        uids = soup.find_all('Id')
        num_uids = len(uids)
        if num_uids == 0:
            print(f'Found {len(uid_list)} UIDs corresponding to {query}.')
            return uid_list
        else:
            uid_list = uid_list + [uid.text for uid in uids]
            retstart += RETMAX
            
# returns the titles, abstracts, years, and year_span of publications corresponding to input UIDs          
def get_summaries(uids):
    titles = []
    abstracts = []
    years = []

    retstart = 0
    MAX_REQUEST = 10000 # number of uids to request at a time

    sys.stdout.write(f'\rRetrieved {retstart} / {len(uids)} titles.')
    sys.stdout.flush()

    while (retstart < len(uids)):
        query_uids = uids[retstart:retstart + MAX_REQUEST]
        params = {
        'db': 'pubmed',
        'id': list_to_csv(query_uids),
        'retmax': MAX_REQUEST,
        'retmode': 'xml',
        'rettyle': 'abstract,'
        }
        res = requests.post(f'{BASE_URL}efetch.fcgi', params)
        soup = BeautifulSoup(res.text, 'xml')

        soup_articles = soup.find_all('PubmedArticle')

        for soup_article in soup_articles:
            soup_title = soup_article.find('ArticleTitle')
            soup_date = soup_article.find('PubDate')
            soup_abstract = soup_article.find('AbstractText')

            if soup_title is None or soup_date is None or soup_abstract is None or soup_date.find('Year') is None:
                continue

            titles.append(soup_title.text.replace('\xa0', ' ').replace('<i>', '').replace('</i>', ''))
            years.append(int(soup_date.find('Year').text))
            abstracts.append(soup_abstract.text)

        retstart += MAX_REQUEST

        sys.stdout.write(f'\rRetrieved {min(retstart, len(uids))} / {len(uids)} summaries.')
        sys.stdout.flush()

    titles, abstracts, years = np.array(titles), np.array(abstracts), np.array(years)
    
    titles = titles[~np.isnan(years)]
    abstracts = abstracts[~np.isnan(years)]
    years = years[~np.isnan(years)]
    
    titles_mod, abstracts_mod, years_mod = [], [], []
    
    for title, abstract, year in zip(titles, abstracts, years):
        if len(years[years == year]) >= MIN_PAPERS:
            titles_mod.append(title)
            abstracts_mod.append(abstract)
            years_mod.append(year)
            
    titles, abstracts, years = np.array(titles_mod), np.array(abstracts_mod), np.array(years_mod)
    
    year_span = np.unique(years)

    print(f'\nAfter filtering, retrieved {len(titles)} summaries.')
        
    return titles, abstracts, years, year_span

def get_titles_and_abstracts_and_years(term):
    return get_summaries(get_uids(term))

# %% [markdown]
# ### Load publication data from NCBI

# %%
titles, abstracts, years, year_span = get_titles_and_abstracts_and_years(term)
# Out:
# Found 10989 UIDs corresponding to Rabies.
# Retrieved 10989 / 10989 summaries.
# After filtering, retrieved 5298 summaries.

# %% [markdown]
# ## Publication Analysis

# %% [markdown]
# ### Number of publications vs time

# %%
num_papers = [np.sum(years == year) for year in year_span]

fig = plt.figure(figsize=(20, 10))
plt.title(f'{term} Papers Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Papers')
plt.plot(year_span, num_papers, color='b')
plt.scatter(year_span, num_papers, color='b', s=100)
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Title length vs time

# %%
lengths = np.array([len(title) for title in titles])
average_lengths = [np.mean(lengths[years == year]) for year in year_span]
stdev_lengths = [np.std(lengths[years == year]) for year in year_span]

plt.figure(figsize=(20, 10))
plt.scatter(year_span, average_lengths, color='b', s=100)
plt.plot(year_span, average_lengths, color='b')
plt.errorbar(year_span, average_lengths, yerr=stdev_lengths, fmt='none', color='b', capsize=20)
plt.title(f'Yearly Title Length for {term}')
plt.xlabel('Year')
plt.ylabel('Title Length (characters)')
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Title entropies vs time

# %%
vectorizer = CountVectorizer()
v = vectorizer.fit_transform(titles).toarray()
frequencies_unsorted = np.sum(v, axis=0)
features_unsorted = vectorizer.get_feature_names()
features, frequencies = zip(*sorted(zip(features_unsorted, frequencies_unsorted), key=lambda f: -f[1]))

probabilities = []

for year in year_span:
    t = v[years == year]
    probabilities.append(np.sum(t, axis=0) / np.sum(np.sum(t, axis=0)))

entropies = [-np.sum(np.multiply(probability, np.nan_to_num(np.log2(probability), neginf=0))) for probability in probabilities]

plt.figure(figsize=(20, 10))
plt.plot(year_span, entropies, color='b')
plt.scatter(year_span, entropies, color='b', s=100)
plt.title(f'Yearly Entropy of Titles for {term}')
plt.xlabel('Year')
plt.ylabel('Entropy of Titles')
plt.rc('font', size=20)
plt.show()
# Out:
# /Users/dddp/Desktop/env_SemanticChangepointDetection/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log2
#   del sys.path[0]

# %% [markdown]
# ### Most common words in publication titles

# %%
num_plot = 40

# %%
frequencies_per_title = np.divide(frequencies, len(years))

frequencies_plot, features_plot = [], []
for frequency, feature in zip(frequencies_per_title, features):
    if feature not in stop_words:
        frequencies_plot.append(frequency)
        features_plot.append(feature)

fig = plt.figure(figsize=(20, 10))
plt.title(f'Word Frequencies in {term} Titles')
plt.xlabel('Word')
plt.ylabel('Frequency per Title')
plt.bar(range(num_plot), frequencies_plot[1:num_plot+1], color='b')
plt.xticks(range(num_plot), features_plot[1:num_plot+1])
plt.setp(plt.gca().get_xticklabels(), rotation=-90, size=30)
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Word frequency changepoint analysis in publication titles

# %%
# only consider words whose average title frequency is at least FREQUENCY_THRESHOLD
FREQUENCY_THRESHOLD = 0.05

# only consider words with a changepoint probability of at least PROBABILITY_THRESHOLD
PROBABILITY_THRESHOLD = 0.5

# %%
word_distributions = []
for year in year_span:
    t = v[years == year]
    word_distributions.append(np.sum(t, axis=0) / np.sum(years == year))
word_distributions = np.transpose(word_distributions)

for feature in features:
    if np.mean(word_distributions[features_unsorted.index(feature)]) < FREQUENCY_THRESHOLD:
        break
    
    data_unnormalized = word_distributions[features_unsorted.index(feature)]
    
    data = []
    for i, year in enumerate(year_span):
        if data_unnormalized[i] == 0:
            data.append(0)
        else:
            data.append(data_unnormalized[i] / np.max(data_unnormalized) * 100)
    data = np.array(data)
    
    Q, P, Pcp = offcd.offline_changepoint_detection(data, partial(offcd.const_prior, l=(len(data)+1)), offcd.gaussian_obs_log_likelihood, truncate=-40)
    probs = np.exp(Pcp).sum(0)
    
    if np.max(probs) < PROBABILITY_THRESHOLD:
        continue
    
    plt.figure(figsize=(20, 20))
    plt.subplot(211)
    plt.plot(year_span, word_distributions[features_unsorted.index(feature)], color='b')
    plt.scatter(year_span, word_distributions[features_unsorted.index(feature)], color='b', s=100)
    plt.title(f'Word Frequency Per Title for {term}: {feature}')
    plt.xlabel('Year')
    plt.ylabel('Frequency Per Title')
    plt.rc('font', size=20)
    
    plt.subplot(212)
    plt.title(f'Changepoint Analysis for {term}: {feature}')
    plt.xlabel('Year')
    plt.ylabel('Changepoint Probability')
    plt.plot(year_span[1:], probs, color='r')
    plt.scatter(year_span[1:], probs, color='r', s=100)
    plt.rc('font', size=20)
    plt.show()

# %% [markdown]
# ### Generate title vectors with BioSentVec

# %%
titles_processed = [preprocess_sentence(title) for title in titles]
title_vectors = model.embed_sentences(titles_processed)
titles_reduced = PCA(n_components=2).fit_transform(title_vectors)

plt.figure(figsize=(15, 10))
plt.scatter(titles_reduced.T[0], titles_reduced.T[1], c=years, cmap='plasma')
plt.title(f'{term} Title Embeddings')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.rc('font', size=20)
plt.colorbar().set_label('Year', rotation=90)
plt.show()

# %%
titles_span = np.array([np.mean(title_vectors[years == year], axis=0) for year in year_span])
titles_span_reduced = PCA(n_components=2).fit_transform(titles_span)

plt.figure(figsize=(15, 10))
plt.scatter(titles_span_reduced.T[0], titles_span_reduced.T[1], c=year_span, cmap='plasma', s=100)
plt.title(f'{term} Average Title Embeddings by Year')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar().set_label('Year', rotation=90)

plot_1 = titles_span_reduced[:-1]
plot_2 = titles_span_reduced[1:]
for i, p1 in enumerate(plot_1):
    p2 = plot_2[i]
    plt.plot([p1[0], p2[0]], [p1[1], p2[1]], color='gray')

plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Identify research trends by identifying the paper titles with embeddings closest to the mean for each year

# %%
# number of representative papers to list closest to the mean
NUMBER_OF_PAPERS = 5

# %%
for title_mean, year in zip(titles_span, year_span):
    titles_mod = titles[year == years]
    title_vectors_mod = title_vectors[year == years]
    ds = [dist(title_mean, t_v) for t_v in title_vectors_mod]
    ds_sorted, titles_sorted = zip(*sorted(zip(ds, titles_mod), key=lambda x: x[0]))
    print(f'Year: {year}')
    print()
    for i in range(NUMBER_OF_PAPERS):
        try:
            print(f'Distance to mean: {ds_sorted[i]}')
            print(f'Title: {titles_sorted[i]}')
            print()
        except:
            break
# Out:
# Year: 1976
#
# Distance to mean: 2.2538483142852783
# Title: Successful protection of humans exposed to rabies infection. Postexposure treatment with the new human diploid cell rabies vaccine and antirabies serum.
#
# Distance to mean: 2.683122396469116
# Title: [Comparative study "in vitro" between rabies and rabies related viruses by the sensitized lymphocytes technique].
#
# Distance to mean: 2.985429286956787
# Title: [Effectiveness of specific treatment of rabies. II. Analysis of cases of human death from rabies following a complete course of treatment with specific agents].
#
# Distance to mean: 3.001638412475586
# Title: Canine rabies in the United States, 1971-1973: study of reported cases with reference to vaccination history.
#
# Distance to mean: 3.0518581867218018
# Title: [Postinfectious antirabic vaccination of children with duck embryo vaccine and heterologous rabies hyperimmunity serum (author's transl)].
#
# Year: 1978
#
# Distance to mean: 2.3102028369903564
# Title: [Results of preventive rabies vaccination with a concentrated vaccine of the PM/WI38-1503-3M rabies strain cultured on human diploid cells. Preparation of mixed antirabies-antitetanus hyperimmune immunoglobulin by plasmapheresis of blood taken from vaccinated veterinary students].
#
# Distance to mean: 2.5639777183532715
# Title: Evaluation of the inactivated tissue culture rabies vaccine from the Vnukovo-32 strain. Results of its industrial production and field use for post-exposure immunization of man.
#
# Distance to mean: 2.669733762741089
# Title: Some experiences with human diploid cell strain-(HDCS) rabies vaccine in pre- and post-exposure vaccinated humans.
#
# Distance to mean: 2.6874678134918213
# Title: Serological investigations on rabies tissue culture vaccine (USSR) and development of short methods in post-exposure treatment.
#
# Distance to mean: 2.7228574752807617
# Title: Humoral immunity conferred by the HDCS rabies vaccine Mérieux administered after exposure: 151 cases with and without specific immune globulin of human origin. Preliminary communication.
#
# Year: 1982
#
# Distance to mean: 2.620664358139038
# Title: Pathogenesis of rabies in dogs inoculated with an Ethiopian rabies virus strain. Immunofluorescence, histologic and ultrastructural studies of the central nervous system.
#
# Distance to mean: 2.9711453914642334
# Title: A single-radial-immunodiffusion technique for the assay of rabies glycoprotein antigen: application for potency tests of vaccines against rabies.
#
# Distance to mean: 3.0452044010162354
# Title: Potency of two rabies vaccines in cats as determined by antibody assay and virulent virus challenge.
#
# Distance to mean: 3.1305909156799316
# Title: Evaluation of a human diploid cell strain rabies vaccine: final report of a three year study of pre-exposure immunization.
#
# Distance to mean: 3.2214338779449463
# Title: Rabies virus pathogenicity and challenge. Influence of the method of preparation, the route of inoculation, and the species. Comparison of the characteristics of the modified, fixed and wild strains.
#
# Year: 1984
#
# Distance to mean: 2.8457770347595215
# Title: Enzyme immunoassay for rabies antibody in hybridoma culture fluids and its application to differentiation of street and laboratory strains of rabies virus.
#
# Distance to mean: 2.921642541885376
# Title: Anti-rabies treatment of dog-bite victims in Lagos, Nigeria: trial of suckling mouse brain and fetal bovine kidney cell rabies vaccines.
#
# Distance to mean: 3.003225088119507
# Title: Purified chick embryo cell (PCEC) rabies vaccine for human use. Laboratory data.
#
# Distance to mean: 3.015199661254883
# Title: Frequency analysis of cytolytic T lymphocyte precursors (CTL-P) generated in vivo during lethal rabies infection of mice. II. Rabies virus genus specificity of CTL-P.
#
# Distance to mean: 3.0228161811828613
# Title: Characterization of rabies virus strains used for vaccine production by means of monoclonal antibodies.
#
# Year: 1985
#
# Distance to mean: 2.5938796997070312
# Title: Serologic and immune responses to rabies virus during different human treatments with tissue culture and suckling mouse brain vaccines.
#
# Distance to mean: 2.7695565223693848
# Title: Intradermal immunization with reduced doses of human diploid cell strain rabies vaccine: evaluation of antibody response by ELISA and mixed hemadsorption test.
#
# Distance to mean: 2.965348482131958
# Title: Rabies virus in different segments of brain and spinal cord of naturally and experimentally infected dogs.
#
# Distance to mean: 3.021371603012085
# Title: Cell-mediated immune response to rabies virus in dogs following vaccination and challenge.
#
# Distance to mean: 3.068683385848999
# Title: On the replication and spread of rabies virus in the human central nervous system.
#
# Year: 1986
#
# Distance to mean: 2.6713781356811523
# Title: Genetic control of serum neutralizing-antibody response to rabies vaccination and survival after a rabies challenge infection in mice.
#
# Distance to mean: 2.8995370864868164
# Title: High rate of insufficient antibody titers after single-day immunization with human diploid-cell-strain vaccine against rabies.
#
# Distance to mean: 2.9184370040893555
# Title: Immune complex-like disease in 23 persons following a booster dose of rabies human diploid cell vaccine.
#
# Distance to mean: 2.918473243713379
# Title: A rapid rabies enzyme immuno-diagnosis (RREID): a useful and simple technique for the routine diagnosis of rabies.
#
# Distance to mean: 2.957984447479248
# Title: Sensitization induced in guinea pigs with beta-propiolactone-treated serum albumin: experimental evidence for the cause of allergic reactions in humans receiving human diploid cell rabies vaccines.
#
# Year: 1987
#
# Distance to mean: 2.654273271560669
# Title: Pre-exposure studies with purified chick embryo cell culture rabies vaccine and human diploid cell vaccine: serological and clinical responses in man.
#
# Distance to mean: 2.6740169525146484
# Title: Persistence of rabies antibody 5 years after pre-exposure prophylaxis with human diploid cell antirabies vaccine and antibody response to a single booster dose.
#
# Distance to mean: 2.780994176864624
# Title: An attempt to treat rabies encephalitis in monkeys with intrathecal live rabies virus RV 675. Brief report.
#
# Distance to mean: 2.781283140182495
# Title: Human rabies immunoglobulin assayed by the rapid fluorescent focus inhibition test suppresses active rabies immunization.
#
# Distance to mean: 2.913374185562134
# Title: Rabies pre-exposure prophylaxis using intradermal human diploid cell vaccine: immunologic efficacy and cost-effectiveness in a university medical center and a review of selected literature.
#
# Year: 1988
#
# Distance to mean: 2.549391269683838
# Title: Efficacy of rabies vaccines against Duvenhage virus isolated from European house bats (Eptesicus serotinus), classic rabies and rabies-related viruses.
#
# Distance to mean: 2.567030668258667
# Title: Immunity against the European bat rabies (Duvenhage) virus induced by rabies vaccines: an experimental study in mice.
#
# Distance to mean: 2.8000247478485107
# Title: Interaction of rabies vaccine with human rabies immunoglobulin and reliability of a 2-1-1 schedule application for postexposure treatment.
#
# Distance to mean: 2.885727643966675
# Title: First field trial of fox vaccination against rabies using a vaccinia-rabies recombinant virus.
#
# Distance to mean: 3.004699468612671
# Title: Use of recombinant vaccinia-rabies virus for oral vaccination of fox cubs (Vulpes vulpes, L) against rabies.
#
# Year: 1989
#
# Distance to mean: 2.421527862548828
# Title: Enhanced antibody response to rabies virus in patients with neurologic complications following brain tissue-derived rabies vaccination.
#
# Distance to mean: 2.6761677265167236
# Title: Post exposure studies with human diploid cell rabies vaccine and purified chick embryo cell vaccine: comparative serological responses in man.
#
# Distance to mean: 2.6950314044952393
# Title: Comparative study of the safety and protective value, in pre-exposure use, of rabies vaccine cultivated on human diploid cells (HDCV) and of the new vaccine grown on Vero cells.
#
# Distance to mean: 2.715939998626709
# Title: Immune response to purified chick embryo cell culture rabies vaccine (Rabipur) in dog-bite victims.
#
# Distance to mean: 2.7335617542266846
# Title: Regional distribution of rabies viral antigen in central nervous system of human encephalitic and paralytic rabies.
#
# Year: 1990
#
# Distance to mean: 2.6448888778686523
# Title: [The efficacy of a cultured rabies vaccine studied on guinea pigs previously infected with the rabies street virus].
#
# Distance to mean: 2.798971652984619
# Title: Epidemiologic factors, clinical findings, and vaccination status of rabies in cats and dogs in the United States in 1988. National Study Group on Rabies.
#
# Distance to mean: 2.9513816833496094
# Title: Seroepidemiological survey of rabies virus antibodies in non vaccinated dogs in Nsukka environs, Nigeria.
#
# Distance to mean: 2.9530205726623535
# Title: Comparison of human immune responses to purified Vero cell and human diploid cell rabies vaccines by using two different antibody titration methods.
#
# Distance to mean: 2.95412278175354
# Title: [Evaluation of the ERA antirabies vaccine against antigenic variants of rabies virus in various post-immunization periods].
#
# Year: 1991
#
# Distance to mean: 2.6358065605163574
# Title: One-year study of the 2-1-1 intramuscular postexposure rabies vaccine regimen in 100 severely exposed Thai patients using rabies immune globulin and Vero cell rabies vaccine.
#
# Distance to mean: 2.694241523742676
# Title: [The efficacy of a cultured rabies vaccine studied in guinea pigs preliminarily infected with a fixed rabies virus].
#
# Distance to mean: 2.7051334381103516
# Title: [Study of revaccination with primary hamster kidney cell rabies vaccine in human beings and its possibility of pre-exposure prevention of rabies].
#
# Distance to mean: 2.7540833950042725
# Title: [The localization and distribution of the antigen of the fixed rabies virus in the central nervous system of animals studied by the fluorescent antibody method].
#
# Distance to mean: 2.926600456237793
# Title: Rabies virus infection in Aedes pseudoscutellaris cells: a study on receptorial structures.
#
# Year: 1992
#
# Distance to mean: 2.8026297092437744
# Title: The microepidemiology of wasting syndrome, a common link to diarrheal disease, cancer, rabies, animal models of AIDS, and HIV-AIDS YHAIDS). The feline leukemia virus and rabies virus models.
#
# Distance to mean: 2.9501583576202393
# Title: The distribution of Challenge virus standard rabies virus versus skunk street rabies virus in the brains of experimentally infected rabid skunks.
#
# Distance to mean: 3.005873203277588
# Title: Sickness and recovery of dogs challenged with a street rabies virus after vaccination with a vaccinia virus recombinant expressing rabies virus N protein.
#
# Distance to mean: 3.081512928009033
# Title: An immune stimulating complex (ISCOM) subunit rabies vaccine protects dogs and mice against street rabies challenge.
#
# Distance to mean: 3.1267354488372803
# Title: Human rabies: epidemiological and laboratory studies in 80 cases.
#
# Year: 1993
#
# Distance to mean: 2.9428951740264893
# Title: The role of the yellow mongoose (Cynictis penicillata) in the epidemiology of rabies in South Africa--preliminary results.
#
# Distance to mean: 3.05214786529541
# Title: Differential effects of rabies and borna disease viruses on immediate-early- and late-response gene expression in brain tissues.
#
# Distance to mean: 3.0693342685699463
# Title: Oral vaccination of racoons (Procyon lotor) with baculovirus-expressed rabies virus glycoprotein.
#
# Distance to mean: 3.087343454360962
# Title: Aspects of rabies infection and control in the conservation of the African wild dog (Lycaon pictus) in the Serengeti region, Tanzania.
#
# Distance to mean: 3.160928964614868
# Title: Rabies eradication in Belgium by fox vaccination using vaccinia-rabies recombinant virus.
#
# Year: 1994
#
# Distance to mean: 2.851996898651123
# Title: Towards rabies elimination in Belgium by fox vaccination using a vaccinia-rabies glycoprotein recombinant virus.
#
# Distance to mean: 3.0036284923553467
# Title: Clinical evaluation of purified vero-cell rabies vaccine in patients bitten by rabid animals in India.
#
# Distance to mean: 3.0235393047332764
# Title: A unique mutation of glycoprotein gene of the attenuated RC-HL strain of rabies virus, a seed virus used for production of animal vaccine in Japan.
#
# Distance to mean: 3.0601541996002197
# Title: Studies on the antigenicity and nucleotide sequence of the rabies virus Nishigahara strain, a current seed strain used for dog vaccine production in Japan.
#
# Distance to mean: 3.1406970024108887
# Title: Assay of oral vaccination of dogs against rabies in Tunisia with the vaccinal strain SADBern.
#
# Year: 1995
#
# Distance to mean: 2.641852617263794
# Title: Ten year longitudinal study of efficacy and safety of purified chick embryo cell vaccine for pre- and post-exposure prophylaxis of rabies in Indian population.
#
# Distance to mean: 2.8311686515808105
# Title: Efficacy study of a new albumin-free human diploid cell rabies vaccine (Lyssavac-HDC, Berna) in 100 severely rabies-exposed Thai patients.
#
# Distance to mean: 2.907381296157837
# Title: Molecular epidemiology of rabies virus in South Africa: evidence for two distinct virus groups.
#
# Distance to mean: 2.921123504638672
# Title: Appearance of inducible nitric oxide synthase in the rat central nervous system after rabies virus infection and during experimental allergic encephalomyelitis but not after peripheral administration of endotoxin.
#
# Distance to mean: 2.9846913814544678
# Title: Efficacy of SAD (Berne) rabies vaccine given by the oral route in two species of jackal (Canis mesomelas and Canis adustus).
#
# Year: 1996
#
# Distance to mean: 2.661456823348999
# Title: Safety study of the SAG2 rabies virus mutant in several non-target species with a view to its future use for the immunization of foxes in Europe.
#
# Distance to mean: 2.7200863361358643
# Title: Immune response to tissue culture rabies vaccine in subjects who had previous postexposure treatment with Semple or suckling mouse brain vaccine.
#
# Distance to mean: 2.7648403644561768
# Title: Early events in rabies virus infection of the central nervous system in skunks (Mephitis mephitis).
#
# Distance to mean: 2.8181118965148926
# Title: The design of strain-specific polymerase chain reactions for discrimination of the racoon rabies virus strain from indigenous rabies viruses of Ontario.
#
# Distance to mean: 2.828660726547241
# Title: The development and use of a vaccinia-rabies recombinant oral vaccine for the control of wildlife rabies; a link between Jenner and Pasteur.
#
# Year: 1997
#
# Distance to mean: 2.820918321609497
# Title: Five-year longitudinal study of efficacy and safety of purified Vero cell rabies vaccine for post-exposure prophylaxis of rabies in Indian population.
#
# Distance to mean: 3.111330509185791
# Title: A new competitive enzyme-linked immunosorbent assay demonstrates adequate immune levels to rabies virus in compulsorily vaccinated Japanese domestic dogs.
#
# Distance to mean: 3.1121931076049805
# Title: Emergence of raccoon rabies in Connecticut, 1991-1994: spatial and temporal characteristics of animal infection and human contact.
#
# Distance to mean: 3.194875478744507
# Title: Molecular mimicry between the rabies virus glycoprotein and human immunodeficiency virus-1 GP120: cross-reacting antibodies induced by rabies vaccination.
#
# Distance to mean: 3.2563109397888184
# Title: The use of an E1-deleted, replication-defective adenovirus recombinant expressing the rabies virus glycoprotein for early vaccination of mice against rabies virus.
#
# Year: 1998
#
# Distance to mean: 2.297830820083618
# Title: Human diploid cell culture rabies vaccine (HDCV) and purified chick embryo cell culture rabies vaccine (PCECV) both confer protective immunity against infection with the silver-haired bat rabies virus strain (SHBRV).
#
# Distance to mean: 2.417249917984009
# Title: Suppressant effect of human or equine rabies immunoglobulins on the immunogenicity of post-exposure rabies vaccination under the 2-1-1 regimen: a field trial in Indonesia. MAS054 Clinical Investigator Group.
#
# Distance to mean: 2.6528706550598145
# Title: Efficacy of an oral vaccinia-rabies glycoprotein recombinant vaccine in controlling epidemic raccoon rabies in New Jersey.
#
# Distance to mean: 2.66245698928833
# Title: Antigen detection in vivo after immunization with different presentation forms of rabies virus antigen, II. Cellular, but not humoral, systemic immune responses against rabies virus immune-stimulating complexes are macrophage dependent.
#
# Distance to mean: 2.7961666584014893
# Title: Evaluation of the safety and immunogenicity of a new, heat-treated human rabies immune globulin using a sham, post-exposure prophylaxis of rabies.
#
# Year: 1999
#
# Distance to mean: 2.8837506771087646
# Title: A rabies serosurvey of domestic dogs in rural Tanzania: results of a rapid fluorescent focus inhibition test (RFFIT) and a liquid-phase blocking ELISA used in parallel.
#
# Distance to mean: 2.9578399658203125
# Title: Article I: Prevention and education regarding rabies in human beings. National Working Group on Rabies Prevention and Control.
#
# Distance to mean: 2.9748826026916504
# Title: Pathogenicity of different rabies virus variants inversely correlates with apoptosis and rabies virus glycoprotein expression in infected primary neuron cultures.
#
# Distance to mean: 3.051774024963379
# Title: Molecular characterization of rabies virus isolates from Mexico: implications for transmission dynamics and human risk.
#
# Distance to mean: 3.1562552452087402
# Title: Human rabies in India: epidemiological features, management and current methods of prevention.
#
# Year: 2000
#
# Distance to mean: 2.6444854736328125
# Title: The development of monoclonal human rabies virus-neutralizing antibodies as a substitute for pooled human immune globulin in the prophylactic treatment of rabies virus exposure.
#
# Distance to mean: 2.827941656112671
# Title: Immunogenicity and effectiveness of post-exposure rabies prophylaxis with a new chromatographically purified Vero-cell rabies vaccine (CPRV): a two-stage randomised clinical trial in the Philippines.
#
# Distance to mean: 2.9787416458129883
# Title: Adult dogs receiving a rabies booster dose with a recombinant adenovirus expressing rabies virus glycoprotein develop high titers of neutralizing antibodies.
#
# Distance to mean: 2.9926884174346924
# Title: Purified Chick Embryo Cell Culture Rabies Vaccine: interchangeability with Human Diploid Cell Culture Rabies Vaccine and comparison of one versus two-dose post-exposure booster regimen for previously immunized persons.
#
# Distance to mean: 3.239635944366455
# Title: Antibody response of patients after postexposure rabies vaccination with small intradermal doses of purified chick embryo cell vaccine or purified Vero cell rabies vaccine.
#
# Year: 2001
#
# Distance to mean: 2.7953879833221436
# Title: Postexposure rabies prophylaxis protocol for domestic animals and epidemiologic characteristics of rabies vaccination failures in Texas: 1995-1999.
#
# Distance to mean: 2.801084518432617
# Title: One-time gene gun or intramuscular rabies DNA vaccination of non-human primates: comparison of neutralizing antibody responses and protection against rabies virus 1 year after vaccination.
#
# Distance to mean: 2.815187454223633
# Title: Immunogenicity and efficacy of Fermi-type nerve tissue rabies vaccine in mice and in humans undergoing post-exposure prophylaxis for rabies in Ethiopia.
#
# Distance to mean: 2.8331491947174072
# Title: Preliminary report on a single-tube, non-interrupted reverse transcription-polymerase chain reaction for the detection of rabies virus in brain tissue.
#
# Distance to mean: 2.8423192501068115
# Title: Comparative immunogenicity and efficacy studies with oral rabies virus vaccine SAD P5/88 in raccoon dogs and red foxes.
#
# Year: 2002
#
# Distance to mean: 2.6441023349761963
# Title: Distribution of rabies antigen in infected brain material: determining the reliability of different regions of the brain for the rabies fluorescent antibody test.
#
# Distance to mean: 2.786756992340088
# Title: Economical multi-site intradermal regimen with purified chick embryo cell vaccine (Rabipur) prevents rabies in people bitten by confirmed rabid animals.
#
# Distance to mean: 2.8047144412994385
# Title: [Anti-rabies antibody titers among subjects who received rabies post-exposure prophylaxis with foreign-made rabies vaccines at the beginning and followed with Japanese rabies vaccine].
#
# Distance to mean: 2.8818535804748535
# Title: Evaluation of various serum and animal protein free media for the production of a veterinary rabies vaccine in BHK-21 cells.
#
# Distance to mean: 2.9979898929595947
# Title: Studies on the different conditions for rabies virus neutralization by monoclonal antibodies #1-46-12 and #7-1-9.
#
# Year: 2003
#
# Distance to mean: 2.67413592338562
# Title: [Molecular epidemiology of rabies epizootics in Colombia, 1994-2002: evidence of human and canine rabies associated with chiroptera].
#
# Distance to mean: 2.9336955547332764
# Title: Neutralising antibody titration in 25,000 sera of dogs and cats vaccinated against rabies in France, in the framework of the new regulations that offer an alternative to quarantine.
#
# Distance to mean: 3.009150505065918
# Title: Discrimination between dog-related and vampire bat-related rabies viruses in Brazil by strain-specific reverse transcriptase-polymerase chain reaction and restriction fragment length polymorphism analysis.
#
# Distance to mean: 3.016563892364502
# Title: Seroconversion in captive African wild dogs (Lycaon pictus) following administration of a chicken head bait/SAG-2 oral rabies vaccine combination.
#
# Distance to mean: 3.027843952178955
# Title: Development of a cocktail of recombinant-expressed human rabies virus-neutralizing monoclonal antibodies for postexposure prophylaxis of rabies.
#
# Year: 2004
#
# Distance to mean: 2.4566903114318848
# Title: Live vaccinia-rabies virus recombinants, but not an inactivated rabies virus cell culture vaccine, protect B-lymphocyte-deficient A/WySnJ mice against rabies: considerations of recombinant defective poxviruses for rabies immunization of immunocompromised individuals.
#
# Distance to mean: 2.550464153289795
# Title: Rabies cell culture vaccines reconstituted and stored at 4 degrees C for 1 year prior to use protect mice against rabies virus.
#
# Distance to mean: 2.7913761138916016
# Title: Development of a hemi-nested RT-PCR method for the specific determination of European Bat Lyssavirus 1. Comparison with other rabies diagnostic methods.
#
# Distance to mean: 2.993385076522827
# Title: [Immune response of suckling mouse brain (CRL) rabies vaccine and tissue culture rabies vaccine (Verorab) in pre-exposure prophylaxis in humans].
#
# Distance to mean: 3.0429847240448
# Title: Rabies neutralizing antibody detection by indirect immunperoxidase serum neutralization assay performed on chicken embryo related cell line.
#
# Year: 2005
#
# Distance to mean: 2.6530816555023193
# Title: Reducing the cost of post-exposure rabies prophylaxis: efficacy of 0.1 ml PCEC rabies vaccine administered intradermally using the Thai Red Cross post-exposure regimen in patients severely exposed to laboratory-confirmed rabid animals.
#
# Distance to mean: 2.663134813308716
# Title: Antigenic and genetic characterization of rabies viruses isolated from domestic and wild animals of Brazil identifies the hoary fox as a rabies reservoir.
#
# Distance to mean: 2.857245683670044
# Title: Rabies human diploid cell vaccine elicits cross-neutralising and cross-protecting immune responses against European and Australian bat lyssaviruses.
#
# Distance to mean: 2.8931431770324707
# Title: Persistence of elevated rabies prevention costs following post-epizootic declines in rates of rabies among raccoons (Procyon lotor).
#
# Distance to mean: 2.904942750930786
# Title: Molecular epidemiology of rabies in northern Colombia 1994-2003. Evidence for human and fox rabies associated with dogs.
#
# Year: 2006
#
# Distance to mean: 2.7431647777557373
# Title: Evaluation of cases admitted to a center in Istanbul, Turkey in 2003 for rabies vaccination and three rabies cases followed up in the last 15 years.
#
# Distance to mean: 2.816451072692871
# Title: Complex genetic structure of the rabies virus in Bangkok and its surrounding provinces, Thailand: implications for canine rabies control.
#
# Distance to mean: 2.9037907123565674
# Title: Epidemiological analysis of setbacks in oral vaccination in the final stage of fox rabies elimination in densely populated areas in Germany.
#
# Distance to mean: 2.915867567062378
# Title: Presence of rabies specific immune complexes in cerebro-spinal fluid can help in ante-mortem diagnosis of human paralytic rabies.
#
# Distance to mean: 2.975559711456299
# Title: Three-year rabies duration of immunity in dogs following vaccination with a core combination vaccine against canine distemper virus, canine adenovirus type-1, canine parvovirus, and rabies virus.
#
# Year: 2007
#
# Distance to mean: 2.444448709487915
# Title: [An epidemiological study of rabies virus in domestic dogs, cats and wildlife and the immunogenicity study for rabies vaccines derived from different cell cultured virus strains].
#
# Distance to mean: 2.5478978157043457
# Title: Development and evaluation of an in vitro isolation of street rabies virus in mouse neuroblastoma cells as compared to conventional tests used for diagnosis of rabies.
#
# Distance to mean: 2.6881210803985596
# Title: Multicenter comparative study of a new ELISA, PLATELIA RABIES II, for the detection and titration of anti-rabies glycoprotein antibodies and comparison with the rapid fluorescent focus inhibition test (RFFIT) on human samples from vaccinated and non-vaccinated people.
#
# Distance to mean: 2.81489896774292
# Title: Rabies challenge of captive striped skunks (Mephitis mephitis) following oral administration of a live vaccinia-vectored rabies vaccine.
#
# Distance to mean: 2.8293938636779785
# Title: Preventing rabies with the Verorab vaccine: 1985-2005 Twenty years of clinical experience.
#
# Year: 2008
#
# Distance to mean: 2.6394269466400146
# Title: [Survey and anslysis of infection rate of dog rabies in the regions with high incidence of human rabies].
#
# Distance to mean: 2.6990134716033936
# Title: Potential effect of prior raccoonpox virus infection in raccoons on vaccinia-based rabies immunization.
#
# Distance to mean: 2.73408579826355
# Title: Economic evaluation of an oral rabies vaccination program for control of a domestic dog-coyote rabies epizootic: 1995-2006.
#
# Distance to mean: 2.7563514709472656
# Title: Rabies post-exposure prophylaxis in the Philippines: health status of patients having received purified equine F(ab')(2) fragment rabies immunoglobulin (Favirab).
#
# Distance to mean: 2.818463087081909
# Title: The rabies elimination programme in Estonia using oral rabies vaccination of wildlife: preliminary results.
#
# Year: 2009
#
# Distance to mean: 2.4299213886260986
# Title: No adverse effects of simultaneous vaccination with the immunocontraceptive GonaCon and a commercial rabies vaccine on rabies virus neutralizing antibody production in dogs.
#
# Distance to mean: 2.7163257598876953
# Title: Rabies post-exposure prophylaxis with purified equine rabies immunoglobulin: one-year follow-up of patients with laboratory-confirmed category III rabies exposure in the Philippines.
#
# Distance to mean: 2.857300043106079
# Title: Rabies virus dissemination in neural tissues of autopsy cases due to rabies imported into Japan from the Philippines: immunohistochemistry.
#
# Distance to mean: 2.887185573577881
# Title: Induction of immune responses and protection in mice against rabies using a self-replicating RNA vaccine encoding rabies virus glycoprotein.
#
# Distance to mean: 2.9031002521514893
# Title: Rabies control in rural Africa: evaluating strategies for effective domestic dog vaccination.
#
# Year: 2010
#
# Distance to mean: 2.6975884437561035
# Title: Immunohistochemical study of rabies virus within the central nervous system of domestic and wildlife species.
#
# Distance to mean: 2.735747814178467
# Title: Epidemiology of vampire bat-transmitted rabies virus in Goiás, central Brazil: re-evaluation based on G-L intergenic region.
#
# Distance to mean: 2.8123598098754883
# Title: Spatial and temporal dynamics of rabies virus variants in big brown bat populations across Canada: footprints of an emerging zoonosis.
#
# Distance to mean: 2.8448212146759033
# Title: Immunogenicity, safety and tolerance of a purified duck embryo vaccine (PDEV, VAXIRAB) for rabies post-exposure prophylaxis: Results of a multicentric study in India.
#
# Distance to mean: 2.920865297317505
# Title: Impact of emergency oral rabies vaccination of foxes in northeastern Italy, 28 December 2009-20 January 2010: preliminary evaluation.
#
# Year: 2011
#
# Distance to mean: 2.5013632774353027
# Title: In situ apoptosis of adaptive immune cells and the cellular escape of rabies virus in CNS from patients with human rabies transmitted by Desmodus rotundus.
#
# Distance to mean: 2.6324915885925293
# Title: Signs Observed Among Animal Species Infected with Raccoon Rabies Variant Virus, Massachusetts, USA, 1992-2010.
#
# Distance to mean: 2.6630353927612305
# Title: Awareness about rabies post exposure prophylaxis in Pakistan among patients and health care workers: results from an Asian Rabies Expert Bureau study.
#
# Distance to mean: 2.6711673736572266
# Title: Rabies in South Indian Cows: An evidence of Sri Lankan Rabies virus Variant Infection Based on the Analysis of Partial Nucleoprotein Gene.
#
# Distance to mean: 2.7335569858551025
# Title: International interlaboratory trials on rabies diagnosis: an overview of results and variation in reference diagnosis techniques (fluorescent antibody test, rabies tissue culture infection test, mouse inoculation test) and molecular biology techniques.
#
# Year: 2012
#
# Distance to mean: 2.6998560428619385
# Title: Postexposure treatment with the live-attenuated rabies virus (RV) vaccine TriGAS triggers the clearance of wild-type RV from the Central Nervous System (CNS) through the rapid induction of genes relevant to adaptive immunity in CNS tissues.
#
# Distance to mean: 2.7817485332489014
# Title: Risk of rabies transmission and adverse effects of postexposure prophylaxis in health care workers exposed to a fatal case of human rabies.
#
# Distance to mean: 2.8238730430603027
# Title: Adaptation of a Chinese ferret badger strain of rabies virus to high-titered growth in BHK-21 cells for canine vaccine development.
#
# Distance to mean: 2.829815149307251
# Title: Rabies risk assessment of exposures to a bat on a commercial airliner - United States, August 2011.
#
# Distance to mean: 2.879079580307007
# Title: [Review on domestic published papers regarding the acute disseminated encephalomyelitis and its relations with rabies vaccination].
#
# Year: 2013
#
# Distance to mean: 2.390493154525757
# Title: Epidemic and maintenance of rabies in Chinese ferret badgers (Melogale moschata) indicated by epidemiology and the molecular signatures of rabies viruses.
#
# Distance to mean: 2.617124319076538
# Title: Intramuscular inoculation of mice with the live-attenuated recombinant rabies virus TriGAS results in a transient infection of the draining lymph nodes and a robust, long-lasting protective immune response against rabies.
#
# Distance to mean: 2.6906566619873047
# Title: Clinical features of dog- and bat-acquired rabies in humans.
#
# Distance to mean: 2.708664655685425
# Title: High prevalence of antibodies against canine adenovirus (CAV) type 2 in domestic dog populations in South Africa precludes the use of CAV-based recombinant rabies vaccines.
#
# Distance to mean: 2.7524590492248535
# Title: Factors associated with dog rabies vaccination in Bhol, Philippines: results of a cross-sectional cluster survey conducted following the island-wide rabies elimination campaign.
#
# Year: 2014
#
# Distance to mean: 2.359722375869751
# Title: Prevention and control of rabies in an age of global travel: a review of travel- and trade-associated rabies events--United States, 1986-2012.
#
# Distance to mean: 2.559943675994873
# Title: Enhancement of blood-brain barrier permeability is required for intravenously administered virus neutralizing antibodies to clear an established rabies virus infection from the brain and prevent the development of rabies in mice.
#
# Distance to mean: 2.6639797687530518
# Title: Pre-exposure prophylaxis against rabies in children: safety of purified chick embryo cell rabies vaccine (Vaxirab N) when administered by intradermal route.
#
# Distance to mean: 2.7512824535369873
# Title: Effect of Corticosteroids on RVNA production of a patient with acute disseminated encephalomyelitis following rabies vaccination as well as administration of HRIG.
#
# Distance to mean: 2.754789113998413
# Title: Sequencing and molecular characterization of CTNCEC25, a China fixed rabies virus vaccine strain CTN-1 adapted to primary chicken embryo cells.
#
# Year: 2015
#
# Distance to mean: 2.4351110458374023
# Title: Clinical management and humoral immune responses to rabies post-exposure prophylaxis among three patients who received solid organs from a donor with rabies.
#
# Distance to mean: 2.5301594734191895
# Title: Comparison of mark-resight methods to estimate abundance and rabies vaccination coverage of free-roaming dogs in two urban areas of south Bhutan.
#
# Distance to mean: 2.626368761062622
# Title: 30 Years of rabies vaccination with Rabipur: a summary of clinical data and global experience.
#
# Distance to mean: 2.696596384048462
# Title: Comparison of safety and immunogenicity of 2 WHO prequalified rabies vaccines administered by one week, 4 site intra dermal regimen (4-4-4-0-0) in animal bite cases.
#
# Distance to mean: 2.7015957832336426
# Title: Immunogenicity and safety of purified chick-embryo cell rabies vaccine under Zagreb 2-1-1 or 5-dose Essen regimen in Chinese children 6 to 17 years old and adults over 50 years: a randomized open-label study.
#
# Year: 2016
#
# Distance to mean: 2.4636943340301514
# Title: First international collaborative study to evaluate rabies antibody detection method for use in monitoring the effectiveness of oral vaccination programmes in fox and raccoon dog in Europe.
#
# Distance to mean: 2.648820400238037
# Title: A Systematic Review of Human Bat Rabies Virus Variant Cases: Evaluating Unprotected Physical Contact with Claws and Teeth in Support of Accurate Risk Assessments.
#
# Distance to mean: 2.6599018573760986
# Title: Serologic response in eight alpacas vaccinated by extralabel use of a large animal rabies vaccine during a public health response to a rabid alpaca in South Carolina.
#
# Distance to mean: 2.72943115234375
# Title: Northern innovation in rabies prevention and control: The Weeneebayko Area Health Authorities (WAHA) dog population management pilot project.
#
# Distance to mean: 2.7402501106262207
# Title: Safety comparison of four types of rabies vaccines in patients with WHO category II animal exposure: An observation based on different age groups.
#
# Year: 2017
#
# Distance to mean: 2.3884201049804688
# Title: Epidemiology, clinical features and risk factors for human rabies and animal bites during an outbreak of rabies in Maputo and Matola cities, Mozambique, 2014: Implications for public health interventions for rabies control.
#
# Distance to mean: 2.5056872367858887
# Title: Evaluation of the efficacy of the Japanese rabies RC-HL strain vaccine in domestic dogs using past and present data: Prediction based on logistic regression and meta-analysis.
#
# Distance to mean: 2.605084180831909
# Title: Enhanced Rabies Surveillance to Support Effective Oral Rabies Vaccination of Raccoons in the Eastern United States.
#
# Distance to mean: 2.6076385974884033
# Title: An accelerated rabies vaccine schedule based on toll-like receptor 3 (TLR3) agonist PIKA adjuvant augments rabies virus specific antibody and T cell response in healthy adult volunteers.
#
# Distance to mean: 2.6451199054718018
# Title: Protection Against CNS-Targeted Rabies Virus Infection is Dependent upon Type-1 Immune Mechanisms Induced by Live-Attenuated Rabies Vaccines.
#
# Year: 2018
#
# Distance to mean: 2.1456336975097656
# Title: The epidemiology of dog rabies in Algeria: Retrospective national study of dog rabies cases, determination of vaccination coverage and immune response evaluation of three commercial used vaccines.
#
# Distance to mean: 2.3466405868530273
# Title: Experimental screening studies on rabies virus transmission and oral rabies vaccination of the Greater Kudu (Tragelaphus strepsiceros).
#
# Distance to mean: 2.4769701957702637
# Title: Strategies for controlling dog-mediated human rabies in Asia: using 'One Health' principles to assess control programmes for rabies.
#
# Distance to mean: 2.504286050796509
# Title: Application and Comparative Evaluation of Fluorescent Antibody, Immunohistochemistry and Reverse Transcription Polymerase Chain Reaction Tests for the Detection of Rabies Virus Antigen or Nucleic Acid in Brain Samples of Animals Suspected of Rabies in India.
#
# Distance to mean: 2.5594098567962646
# Title: Initial pen and field assessment of baits to use in oral rabies vaccination of Formosan ferret-badgers in response to the re-emergence of rabies in Taiwan.
#
# Year: 2019
#
# Distance to mean: 2.527639150619507
# Title: Analysis of Iophenoxic Acid Analogues in Small Indian Mongoose (Herpestes Auropunctatus) Sera for Use as an Oral Rabies Vaccination Biological Marker.
#
# Distance to mean: 2.6103856563568115
# Title: Utilising Group-Size and Home-Range Characteristics of Free-Roaming Dogs (FRD) to Guide Mass Vaccination Campaigns against Rabies in India.
#
# Distance to mean: 2.618234872817993
# Title: A Cost Effective Easy Competitive Enzyme-Linked Immunosorbent Assay Suitable for Monitoring Protective Immunity against the Rabies Virus in the Serum of Humans and Dogs.
#
# Distance to mean: 2.620753526687622
# Title: Assessment of naturally acquired neutralizing antibodies against rabies Lyssavirus in a subset of Nunavik's Inuit population considered most at risk of being exposed to rabid animals.
#
# Distance to mean: 2.650773763656616
# Title: Achieving scientific and regulatory success in implementing non-animal approaches to human and veterinary rabies vaccine testing: A NICEATM and IABS workshop report.
#
# Year: 2020
#
# Distance to mean: 2.4695301055908203
# Title: Single-visit, 4-site intradermal (ID) rabies vaccination induces robust immune responses 5 years after 1-week, 4-site ID primary post-exposure prophylaxis in the Philippines.
#
# Distance to mean: 2.570596933364868
# Title: Evaluation of rabies virus characterization to enhance early detection of important rabies epizootic events in the United States.
#
# Distance to mean: 2.5765767097473145
# Title: Evaluation of post-exposure prophylaxis practices to improve the cost-effectiveness of rabies control in human cases potentially exposed to rabies in southern Bhutan.
#
# Distance to mean: 2.6008334159851074
# Title: Origin of 3 Rabid Terrestrial Animals in Raccoon Rabies Virus-Free Zone, Long Island, New York, USA, 2016-2017.
#
# Distance to mean: 2.6116769313812256
# Title: Immunogenicity and safety of two-visit, intradermal pre-exposure rabies prophylaxis simultaneously administrated with chimeric live-attenuated Japanese encephalitis vaccine in children living in rabies and Japanese encephalitis endemic country.

# %% [markdown]
# ### Quantify novelty of each year by the proportion of papers whose title embeddings are far from previous years' title embeddings

# %%
# threshold distance to consider a paper to be novel
CUTOFF_DISTANCE = 5

# %%
year = year_span[0]

titles_prev = titles[years == year]
title_vectors_prev = title_vectors[years == year]
years_prev = years[years == year]

counts = []

for year in year_span[1:]:
    titles_curr = titles[years == year]
    title_vectors_curr = title_vectors[years == year]
    years_curr = years[years == year]
    
    ds = []
    titles_r, years_r = [], []
    
    count = 0.0
    
    for (title_curr, title_vector_curr, year_curr) in zip(titles_curr, title_vectors_curr, years_curr):
        min_distance = np.inf
        title_min, title_vector_min, year_min = None, None, None
        title_rmin, title_vector_rmin, year_rmin = None, None, None
        for (title_prev, title_vector_prev, year_prev) in zip(titles_prev, title_vectors_prev, years_prev):
            if dist(title_vector_curr, title_vector_prev) < min_distance:
                min_distance = dist(title_vector_curr, title_vector_prev)
                title_min, title_vector_min, year_min = title_curr, title_vector_curr, year_curr
                title_rmin, title_vector_rmin, year_rmin = title_prev, title_vector_prev, year_prev
                
        ds.append(min_distance)
        titles_r.append(title_rmin)
        years_r.append(year_rmin)
        
        if min_distance > CUTOFF_DISTANCE:
            count += 1
                
    ds_sorted, titles_r_sorted, years_r_sorted, titles_curr_sorted = zip(*sorted(zip(ds, titles_r, years_r, titles_curr), key=lambda x: -x[0]))
                                    
    titles_prev = np.concatenate((titles_prev, titles_curr))
    title_vectors_prev = np.concatenate((title_vectors_prev, title_vectors_curr))
    years_prev = np.concatenate((years_prev, years_curr))
    
    counts.append(count / len(years_curr))

# %%
plt.figure(figsize=(20, 10))
plt.scatter(year_span[1:], counts, color='b', s=100)
plt.plot(year_span[1:], counts, color='b')
plt.title(f'Semantic Distance Novelty for {term} from Titles')
plt.xlabel('Year')
plt.ylabel('Proportion of Novel Papers')
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Identify clusters of novel research based on paper titles

# %%
# identify research papers published between year CHANGEPOINT and CHANGEPOINT + DELTA,  such that
# (the mean distance between the paper title and its K nearest neighbors published before CHANGEPOINT)
# is at least RATIO_THRESHOLD times (the mean distance between the paper title and its K nearest neighbors
# also published between CHANGEPOINT and CHANGEPOINT + DELTA)
CHANGEPOINT = 2000
K = 3
DELTA = 5
RATIO_THRESHOLD = 1.2

# %%
titles_old, title_vectors_old, years_old = [], [], []
titles_new, title_vectors_new, years_new = [], [], []

for title, title_vector, year in zip(titles, title_vectors, years):
    if year < CHANGEPOINT:
        titles_old.append(title)
        title_vectors_old.append(title_vector)
        years_old.append(year)
    if year >= CHANGEPOINT and year <= CHANGEPOINT + DELTA:
        titles_new.append(title)
        title_vectors_new.append(title_vector)
        years_new.append(year)
            
for title, title_vector, year in zip(titles_new, title_vectors_new, years_new):
    new_distance = np.mean(sorted([dist(title_vector, t_v) for t_v in title_vectors_new])[1:][:K])
    old_distance = np.mean(sorted([dist(title_vector, t_v) for t_v in title_vectors_old])[:K])
    
    if (old_distance / new_distance) > RATIO_THRESHOLD:
        print(f'Year: {year}')
        print(f'Ratio: {old_distance / new_distance}')
        print(f'New Distance: {new_distance}')
        print(f'Old Distance: {old_distance}')
        print(f'Title: {title}')
        print()
# Out:
# Year: 2005
# Ratio: 1.5199613571166992
# New Distance: 4.188262462615967
# Old Distance: 6.365997314453125
# Title: Rabies in Europe in 2005.
#
# Year: 2005
# Ratio: 1.5143636465072632
# New Distance: 2.2924306392669678
# Old Distance: 3.4715735912323
# Title: An imported case of canine rabies in Aquitaine: investigation and management of the contacts at risk, August 2004-March 2005.
#
# Year: 2005
# Ratio: 1.6024937629699707
# New Distance: 2.5805227756500244
# Old Distance: 4.1352715492248535
# Title: A human case of travel-related rabies in Austria, September 2004.
#
# Year: 2005
# Ratio: 1.5199613571166992
# New Distance: 4.188262462615967
# Old Distance: 6.365997314453125
# Title: Rabies in Europe in 2005.
#
# Year: 2005
# Ratio: 1.5143636465072632
# New Distance: 2.2924306392669678
# Old Distance: 3.4715735912323
# Title: An imported case of canine rabies in Aquitaine: Investigation and management of the contacts at risk, August 2004-March 2005.
#
# Year: 2005
# Ratio: 1.6024937629699707
# New Distance: 2.5805227756500244
# Old Distance: 4.1352715492248535
# Title: A human case of travel-related rabies in Austria, September 2004.
#
# Year: 2005
# Ratio: 2.2946908473968506
# New Distance: 2.1937763690948486
# Old Distance: 5.034038543701172
# Title: [Rabies in Poland in 2003].
#
# Year: 2005
# Ratio: 1.499961018562317
# New Distance: 2.7038965225219727
# Old Distance: 4.055739402770996
# Title: Transmission of rabies virus from an organ donor to four transplant recipients.
#
# Year: 2005
# Ratio: 1.370502233505249
# New Distance: 2.6470537185668945
# Old Distance: 3.627793073654175
# Title: Molecular epidemiology of rabies in northern Colombia 1994-2003. Evidence for human and fox rabies associated with dogs.
#
# Year: 2005
# Ratio: 1.3470921516418457
# New Distance: 3.1446073055267334
# Old Distance: 4.2360758781433105
# Title: Genetic characterization of rabies virus isolates in Korea.
#
# Year: 2005
# Ratio: 1.499961018562317
# New Distance: 2.7038965225219727
# Old Distance: 4.055739402770996
# Title: Transmission of rabies virus from an organ donor to four transplant recipients.
#
# Year: 2005
# Ratio: 1.3763757944107056
# New Distance: 2.673668622970581
# Old Distance: 3.6799728870391846
# Title: Compendium of animal rabies prevention and control, 2005.
#
# Year: 2004
# Ratio: 1.3104302883148193
# New Distance: 2.8328282833099365
# Old Distance: 3.712224006652832
# Title: Update: investigation of rabies infections in organ donor and transplant recipients--Alabama, Arkansas, Oklahoma, and Texas, 2004.
#
# Year: 2004
# Ratio: 1.2888598442077637
# New Distance: 2.844473123550415
# Old Distance: 3.6661272048950195
# Title: Investigation of rabies infections in organ donor and transplant recipients--Alabama, Arkansas, Oklahoma, and Texas, 2004.
#
# Year: 2004
# Ratio: 2.1580731868743896
# New Distance: 2.377168893814087
# Old Distance: 5.1301045417785645
# Title: [Rabies in Poland in 2002].
#
# Year: 2004
# Ratio: 1.20225989818573
# New Distance: 4.150816917419434
# Old Distance: 4.990360736846924
# Title: [Construction of human phage-displayed scFv library and selection of the ScFv against rabies virus].
#
# Year: 2003
# Ratio: 1.3047308921813965
# New Distance: 3.5622942447662354
# Old Distance: 4.6478352546691895
# Title: Characterization of rabies virus isolates in Bolivia.
#
# Year: 2003
# Ratio: 2.219083547592163
# New Distance: 2.2907729148864746
# Old Distance: 5.08341646194458
# Title: [Rabies in Poland in 2001].
#
# Year: 2003
# Ratio: 1.463959813117981
# New Distance: 2.4427013397216797
# Old Distance: 3.576016664505005
# Title: [Molecular epidemiology of rabies epizootics in Colombia, 1994-2002: evidence of human and canine rabies associated with chiroptera].
#
# Year: 2003
# Ratio: 1.3756318092346191
# New Distance: 2.6659252643585205
# Old Distance: 3.6673316955566406
# Title: Compendium of animal rabies prevention and control, 2003.
#
# Year: 2003
# Ratio: 1.488477349281311
# New Distance: 2.61669921875
# Old Distance: 3.8948974609375
# Title: Molecular epidemiology of rabies epizootics in Colombia: evidence for human and dog rabies associated with bats.
#
# Year: 2002
# Ratio: 1.8412905931472778
# New Distance: 2.9249656200408936
# Old Distance: 5.385711669921875
# Title: [Rabies in Poland in 2000].
#
# Year: 2002
# Ratio: 1.238379955291748
# New Distance: 7.71976900100708
# Old Distance: 9.560007095336914
# Title: Update on rabies.
#
# Year: 2002
# Ratio: 1.2067406177520752
# New Distance: 3.242098569869995
# Old Distance: 3.912371873855591
# Title: Molecular characterization of rabies virus isolates from Trinidad.
#
# Year: 2001
# Ratio: 2.0717897415161133
# New Distance: 2.5050251483917236
# Old Distance: 5.18988561630249
# Title: [Rabies in Poland in 1999].
#
# Year: 2000
# Ratio: 1.2627376317977905
# New Distance: 3.335002899169922
# Old Distance: 4.211233615875244
# Title: Interaction of the rabies virus P protein with the LC8 dynein light chain.
#
# Year: 2000
# Ratio: 1.232280969619751
# New Distance: 6.57689905166626
# Old Distance: 8.10458755493164
# Title: Rabies update.

# %% [markdown]
# ### Create differential wordclouds for paper titles

# %%
# creates a differential wordcloud for words appearing in year2, vs all words appearing before or during year1
def create_wordcloud(year1, year2):
    freqs_prev = np.sum(v[years <= year1], axis=0) / np.sum(years <= year1)
    freqs_new = np.sum(v[years == year2], axis=0) / np.sum(years == year2)

    diffs = np.subtract(freqs_prev, freqs_new)

    pos_features, neg_features = set(), set()

    d = {}
    for diff, feature in zip(diffs, features_unsorted):
        if feature in stop_words:
            continue

        diff = round(diff * 1000)
        if diff > 0:
            d[feature] = diff
            pos_features.add(feature)
        if diff < 0:
            neg_features.add(feature) 
            d[feature] = -diff

    def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
        if word in pos_features:
            return "rgb(0, 0, 0)"
        if word in neg_features:
            return "rgb(256, 0, 0)"

    wordcloud = WordCloud(background_color='white', height=500, width=1000)
    wordcloud.generate_from_frequencies(frequencies=d)
    plt.figure(figsize=(20, 10))
    plt.imshow(wordcloud.recolor(color_func=color_func, random_state=3),
               interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(1999, 2000)

# %% [markdown]
# ### Abstract length vs time

# %%
lengths = np.array([len(abstract) for abstract in abstracts])
average_lengths = [np.mean(lengths[years == year]) for year in year_span]
stdev_lengths = [np.std(lengths[years == year]) for year in year_span]

plt.figure(figsize=(20, 10))
plt.scatter(year_span, average_lengths, color='b', s=100)
plt.plot(year_span, average_lengths, color='b')
plt.errorbar(year_span, average_lengths, yerr=stdev_lengths, fmt='none', color='b', capsize=20)
plt.title(f'Weekly Abstract Length for {term}')
plt.xlabel('Year')
plt.ylabel('Abstract Length (characters)')
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Abstract entropies vs time

# %%
vectorizer = CountVectorizer()
v = vectorizer.fit_transform(abstracts).toarray()
frequencies_unsorted = np.sum(v, axis=0)
features_unsorted = vectorizer.get_feature_names()
features, frequencies = zip(*sorted(zip(features_unsorted, frequencies_unsorted), key=lambda f: -f[1]))

probabilities = []

for year in year_span:
    t = v[years == year]
    probabilities.append(np.sum(t, axis=0) / np.sum(np.sum(t, axis=0)))

entropies = [-np.sum(np.multiply(probability, np.nan_to_num(np.log2(probability), neginf=0))) for probability in probabilities]

plt.figure(figsize=(20, 10))
plt.plot(year_span, entropies, color='b')
plt.scatter(year_span, entropies, color='b', s=100)
plt.title(f'Yearly Entropy of Abstracts for {term}')
plt.xlabel('Year')
plt.ylabel('Entropy of Abstracts')
plt.rc('font', size=20)
plt.show()
# Out:
# /Users/dddp/Desktop/env_SemanticChangepointDetection/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log2
#   del sys.path[0]

# %% [markdown]
# ### Most common words in abstracts

# %%
num_plot = 40

# %%
frequencies_per_abstract = np.divide(frequencies, len(years))

frequencies_plot, features_plot = [], []
for frequency, feature in zip(frequencies_per_abstract, features):
    if feature not in stop_words:
        frequencies_plot.append(frequency)
        features_plot.append(feature)

fig = plt.figure(figsize=(20, 10))
plt.title(f'Word Frequencies in {term} Abstracts')
plt.xlabel('Word')
plt.ylabel('Frequency per Abstract')
plt.bar(range(num_plot), frequencies_plot[1:num_plot+1], color='b')
plt.xticks(range(num_plot), features_plot[1:num_plot+1])
plt.setp(plt.gca().get_xticklabels(), rotation=-90, size=30)
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Word frequency changepoint analysis in publication abstracts

# %%
# only consider words whose average abstract frequency is at least FREQUENCY_THRESHOLD
FREQUENCY_THRESHOLD = 0.05

# only consider words with a changepoint probability of at least PROBABILITY_THRESHOLD
PROBABILITY_THRESHOLD = 0.8

# %%
word_distributions = []
for year in year_span:
    t = v[years == year]
    word_distributions.append(np.sum(t, axis=0) / np.sum(years == year))
word_distributions = np.transpose(word_distributions)

for feature in features:
    if np.mean(word_distributions[features_unsorted.index(feature)]) < FREQUENCY_THRESHOLD:
        break
    
    data_unnormalized = word_distributions[features_unsorted.index(feature)]
    
    data = []
    for i, year in enumerate(year_span):
        if data_unnormalized[i] == 0:
            data.append(0)
        else:
            data.append(data_unnormalized[i] / np.max(data_unnormalized) * 100)
    data = np.array(data)
    
    Q, P, Pcp = offcd.offline_changepoint_detection(data, partial(offcd.const_prior, l=(len(data)+1)), offcd.gaussian_obs_log_likelihood, truncate=-40)
    probs = np.exp(Pcp).sum(0)
    
    if np.max(probs) < PROBABILITY_THRESHOLD:
        continue
    
    plt.figure(figsize=(20, 20))
    plt.subplot(211)
    plt.plot(year_span, word_distributions[features_unsorted.index(feature)], color='b')
    plt.scatter(year_span, word_distributions[features_unsorted.index(feature)], color='b', s=100)
    plt.title(f'Word Frequency Per Abstract for {term}: {feature}')
    plt.xlabel('Year')
    plt.ylabel('Frequency Per Abstract')
    plt.rc('font', size=20)
    
    plt.subplot(212)
    plt.title(f'Changepoint Analysis for {term}: {feature}')
    plt.xlabel('Year')
    plt.ylabel('Changepoint Probability')
    plt.plot(year_span[1:], probs, color='r')
    plt.scatter(year_span[1:], probs, color='r', s=100)
    plt.rc('font', size=20)
    plt.show()

# %% [markdown]
# ### Generate abstract vectors with BioSentVec

# %%
abstracts_processed = [preprocess_sentence(abstract) for abstract in abstracts]
abstract_vectors = model.embed_sentences(abstracts_processed)
abstracts_reduced = PCA(n_components=2).fit_transform(abstract_vectors)

plt.figure(figsize=(15, 10))
plt.scatter(abstracts_reduced.T[0], abstracts_reduced.T[1], c=years, cmap='plasma')
plt.title(f'{term} Abstract Embeddings')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.rc('font', size=20)
plt.colorbar().set_label('Year', rotation=90)
plt.show()

# %%
abstracts_span = np.array([np.mean(abstract_vectors[years == year], axis=0) for year in year_span])
abstracts_span_reduced = PCA(n_components=2).fit_transform(abstracts_span)

plt.figure(figsize=(15, 10))
plt.scatter(abstracts_span_reduced.T[0], abstracts_span_reduced.T[1], c=year_span, cmap='plasma', s=100)
plt.title(f'{term} Average Abstract Embeddings by Year')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar().set_label('Year', rotation=90)

plot_1 = abstracts_span_reduced[:-1]
plot_2 = abstracts_span_reduced[1:]
for i, p1 in enumerate(plot_1):
    p2 = plot_2[i]
    plt.plot([p1[0], p2[0]], [p1[1], p2[1]], color='gray')

plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Identify research trends by identifying the paper abstracts with embeddings closest to the mean for each year

# %%
# number of representative papers to list closest to the mean
NUMBER_OF_PAPERS = 5

# %%
for abstract_mean, year in zip(abstracts_span, year_span):
    abstracts_mod = abstracts[year == years]
    titles_mod = titles[year == years]
    abstract_vectors_mod = abstract_vectors[year == years]
    ds = [dist(abstract_mean, t_v) for t_v in abstract_vectors_mod]
    ds_sorted, abstracts_sorted, titles_sorted = zip(*sorted(zip(ds, abstracts_mod, titles_mod), key=lambda x: x[0]))
    print(f'Year: {year}')
    print()
    for i in range(NUMBER_OF_PAPERS):
        try:
            print(f'Distance to mean: {ds_sorted[i]}')
            print(f'Title: {titles_sorted[i]}')
            print()
        except:
            break
# Out:
# Year: 1976
#
# Distance to mean: 1.3309820890426636
# Title: Clinical use of human globulin immune to rabies virus.
#
# Distance to mean: 1.3502589464187622
# Title: Ethylenimine-inactivated rabies vaccine of tissue culture origin.
#
# Distance to mean: 1.3656609058380127
# Title: Recovery from rabies in man.
#
# Distance to mean: 1.3683284521102905
# Title: Role of interferon in prophylaxis of rabies after exposure.
#
# Distance to mean: 1.3747092485427856
# Title: [Postinfectious antirabic vaccination of children with duck embryo vaccine and heterologous rabies hyperimmunity serum (author's transl)].
#
# Year: 1978
#
# Distance to mean: 1.045249581336975
# Title: Evaluation of the inactivated tissue culture rabies vaccine from the Vnukovo-32 strain. Results of its industrial production and field use for post-exposure immunization of man.
#
# Distance to mean: 1.0785868167877197
# Title: Serovaccination by human immune globulin and HDCS-vaccine against rabies.
#
# Distance to mean: 1.098921537399292
# Title: Standardization of methods used for testing the safety of tissue culture rabies vaccines.
#
# Distance to mean: 1.1504360437393188
# Title: [Passive immunization against rabies (author's transl)].
#
# Distance to mean: 1.2608084678649902
# Title: Clinical trial with an anti-rabies human diploid cell vaccine (HDCV).
#
# Year: 1982
#
# Distance to mean: 1.3045685291290283
# Title: Rabies virus pathogenicity and challenge. Influence of the method of preparation, the route of inoculation, and the species. Comparison of the characteristics of the modified, fixed and wild strains.
#
# Distance to mean: 1.396600604057312
# Title: Small wild rodents rabies in Czechoslovakia.
#
# Distance to mean: 1.4443491697311401
# Title: Intradermal use of human diploid cell vaccine for preexposure rabies immunizations.
#
# Distance to mean: 1.473673701286316
# Title: Specific activity of concentrated and purified cell culture rabies vaccine (CPCRV) from the strain Vnukovo -32-107 in an experiment with therapeutical immunization of humans.
#
# Distance to mean: 1.476124882698059
# Title: Antibody responses to human diploid cell vaccine for rabies with and without human rabies immune globulin.
#
# Year: 1984
#
# Distance to mean: 1.1886013746261597
# Title: [Immunogenicity of a new, highly purified, highly concentrated duck-embryo rabies vaccine].
#
# Distance to mean: 1.2816085815429688
# Title: Anti-rabies treatment of dog-bite victims in Lagos, Nigeria: trial of suckling mouse brain and fetal bovine kidney cell rabies vaccines.
#
# Distance to mean: 1.3201751708984375
# Title: [Experimental bovine rabies: susceptibility, symptoms, humoral immunologic reactions, lesions and virus excretion].
#
# Distance to mean: 1.3847914934158325
# Title: [Rabies in the common hamster (Cricetus cricetus) in Slovakia].
#
# Distance to mean: 1.4359185695648193
# Title: Purified chick embryo cell (PCEC) rabies vaccine for human use: clinical trials.
#
# Year: 1985
#
# Distance to mean: 1.3414984941482544
# Title: Rabies immunosome (subunit vaccine) structure and immunogenicity. Pre- and post-exposure protection studies.
#
# Distance to mean: 1.3785243034362793
# Title: Production of rabies vaccine by an industrial scale BHK 21 suspension cell culture process.
#
# Distance to mean: 1.3983017206192017
# Title: [Effect of previous anti-rabies treatment with Fermi type vaccine on the antibody response to one dose of HDCV].
#
# Distance to mean: 1.4143133163452148
# Title: Characteristics of cellular and humoral immune responses after immunization with different rabies vaccines.
#
# Distance to mean: 1.4450520277023315
# Title: Experimental rabies in hibernator rodents.
#
# Year: 1986
#
# Distance to mean: 1.2031012773513794
# Title: [Experiences with oral immunization of foxes against rabies in Hesse].
#
# Distance to mean: 1.3392579555511475
# Title: New purified Vero-cell vaccine prevents rabies in patients bitten by rabid animals.
#
# Distance to mean: 1.4204133749008179
# Title: [Vaccination of ferrets (Putorius furo) against rabies using a tissue vaccine].
#
# Distance to mean: 1.4857797622680664
# Title: Purified Vero cell rabies vaccine and human diploid cell strain vaccine: comparison of neutralizing antibody responses to post-exposure regimens.
#
# Distance to mean: 1.5009666681289673
# Title: Pathologic findings in rabies-suspect, random-source, and accidentally killed skunks.
#
# Year: 1987
#
# Distance to mean: 1.2443175315856934
# Title: Antibody response to suckling mouse brain rabies vaccines for post exposure treatment.
#
# Distance to mean: 1.306450366973877
# Title: Experimental rabies in skunks: immune response and salivary gland infection.
#
# Distance to mean: 1.312573790550232
# Title: Early antibody responses to rabies post-exposure vaccine regimens.
#
# Distance to mean: 1.3348851203918457
# Title: Experimental rabies in skunks and foxes. Pathogenesis of the spongiform lesions.
#
# Distance to mean: 1.3431938886642456
# Title: Reactogenicity and immunogenicity of the newly developed purified chick embryo cell (PCEC)-rabies vaccine in man.
#
# Year: 1988
#
# Distance to mean: 1.376488447189331
# Title: Interleukin-2 production in vitro: a new approach to the study of rabies vaccine immunogenicity as appraised by testing different glycoprotein presentations.
#
# Distance to mean: 1.3870735168457031
# Title: Effectiveness and tolerance of pre- and postexposure treatment with purified inactivated rabies vaccine prepared on Vero cell line.
#
# Distance to mean: 1.418708324432373
# Title: The present status of rabies vaccine development and clinical experience with rabies vaccine.
#
# Distance to mean: 1.4238941669464111
# Title: Efficacy of rabies vaccines against Duvenhage virus isolated from European house bats (Eptesicus serotinus), classic rabies and rabies-related viruses.
#
# Distance to mean: 1.442370057106018
# Title: Pathogenesis of rabies virus from a Danish bat (Eptesicus serotinus): neuronal changes suggestive of spongiosis.
#
# Year: 1989
#
# Distance to mean: 1.1461724042892456
# Title: [Rabies as a public health problem].
#
# Distance to mean: 1.2768431901931763
# Title: Rabies and post-exposure prophylaxis in Thai children.
#
# Distance to mean: 1.3108856678009033
# Title: Lymphocyte proliferative response to rabies virus antigen.
#
# Distance to mean: 1.3365095853805542
# Title: [Safety and efficacy of an antirabies vaccine consisting of recombinant vaccinia-rabies virus administered orally to the fox, dog and cat].
#
# Distance to mean: 1.3797426223754883
# Title: Prevalence of rabies specific antibodies in the Mexican free-tailed bat (Tadarida brasiliensis mexicana) at Lava Cave, New Mexico.
#
# Year: 1990
#
# Distance to mean: 1.2770158052444458
# Title: Seroepidemiological survey of rabies virus antibodies in non-vaccinated dogs in Nsukka Environs, Nigeria.
#
# Distance to mean: 1.313415288925171
# Title: Seroepidemiological survey of rabies virus antibodies in non vaccinated dogs in Nsukka environs, Nigeria.
#
# Distance to mean: 1.322545051574707
# Title: [Rabies Tissue Culture Infection Test as an Alternative for the Mouse Inoculation Test]
#
# Distance to mean: 1.3500086069107056
# Title: [The efficacy of a cultured rabies vaccine studied on guinea pigs previously infected with the rabies street virus].
#
# Distance to mean: 1.3891667127609253
# Title: [Testing for immunogenic and protective properties of vaccine against tissue-inactivated rabies].
#
# Year: 1991
#
# Distance to mean: 1.2764551639556885
# Title: A rabies-specific human monoclonal antibody that protects mice against lethal rabies.
#
# Distance to mean: 1.4247337579727173
# Title: The clinical picture of rabies in a child.
#
# Distance to mean: 1.442254900932312
# Title: Raccoon poxvirus recombinants expressing the rabies virus nucleoprotein protect mice against lethal rabies virus infection.
#
# Distance to mean: 1.4988073110580444
# Title: Immune response to rabies vaccine in Thai dogs: a preliminary report.
#
# Distance to mean: 1.500681757926941
# Title: One-year study of the 2-1-1 intramuscular postexposure rabies vaccine regimen in 100 severely exposed Thai patients using rabies immune globulin and Vero cell rabies vaccine.
#
# Year: 1992
#
# Distance to mean: 1.1150411367416382
# Title: Consideration of inactivated rabies vaccines as oral immunogens of wild carnivores.
#
# Distance to mean: 1.2827130556106567
# Title: Immunisation with canarypox virus expressing rabies glycoprotein.
#
# Distance to mean: 1.3280481100082397
# Title: Development of a recombinant vaccinia-rabies vaccine for oral vaccination of foxes against rabies.
#
# Distance to mean: 1.3395986557006836
# Title: Outbreak of human rabies in the Peruvian jungle.
#
# Distance to mean: 1.3521158695220947
# Title: Experimental inoculation of raccoons (Procyon lotor) with rabies virus of skunk origin.
#
# Year: 1993
#
# Distance to mean: 1.295684814453125
# Title: Polymerase chain reaction and other laboratory techniques in the diagnosis of long incubation rabies in Australia.
#
# Distance to mean: 1.3118765354156494
# Title: Identification of regional variants of the rabies virus within the Canadian province of Ontario.
#
# Distance to mean: 1.3418207168579102
# Title: Aspects of rabies infection and control in the conservation of the African wild dog (Lycaon pictus) in the Serengeti region, Tanzania.
#
# Distance to mean: 1.410210371017456
# Title: Recombinant rabies vaccines: efficacy assessment in free-ranging animals.
#
# Distance to mean: 1.4928948879241943
# Title: Equine rabies.
#
# Year: 1994
#
# Distance to mean: 1.218986988067627
# Title: Clinical evaluation of purified vero-cell rabies vaccine in patients bitten by rabid animals in India.
#
# Distance to mean: 1.3400956392288208
# Title: Survey of fox trappers in northern Alaska for rabies antibody.
#
# Distance to mean: 1.3887265920639038
# Title: A molecular epidemiological study of rabies virus in central Ontario and western Quebec.
#
# Distance to mean: 1.4319566488265991
# Title: [Antigenic determination of human anti-rabies vaccine against viral street strains common in the wild animal population in Poland].
#
# Distance to mean: 1.4456698894500732
# Title: Rabies in a vaccinated wolf-dog hybrid.
#
# Year: 1995
#
# Distance to mean: 1.2195686101913452
# Title: [Rabies in France, 100 years after Pasteur].
#
# Distance to mean: 1.381558895111084
# Title: [Epidemiology and campaign against rabies in France and in Europe].
#
# Distance to mean: 1.4293749332427979
# Title: Elimination of fox rabies from Belgium using a recombinant vaccinia-rabies vaccine: an update.
#
# Distance to mean: 1.431343913078308
# Title: Maintenance of a microparasite infecting several host species: rabies in the Serengeti.
#
# Distance to mean: 1.4359177350997925
# Title: Field trials of a recombinant rabies vaccine.
#
# Year: 1996
#
# Distance to mean: 1.0820999145507812
# Title: Characterization of a unique variant of bat rabies virus responsible for newly emerging human cases in North America.
#
# Distance to mean: 1.2361105680465698
# Title: Rabies encephalitis in a patient with AIDS: a clinicopathological study.
#
# Distance to mean: 1.2941974401474
# Title: Immune response to tissue culture rabies vaccine in subjects who had previous postexposure treatment with Semple or suckling mouse brain vaccine.
#
# Distance to mean: 1.3207576274871826
# Title: Human safety and immunogenicity of a canarypox-rabies glycoprotein recombinant vaccine: an alternative poxvirus vector system.
#
# Distance to mean: 1.3254990577697754
# Title: Investigation of rabies virus strains in Mexico with a panel of monoclonal antibodies used to classify Lyssavirus.
#
# Year: 1997
#
# Distance to mean: 1.214553952217102
# Title: Innocuity studies of SAG-2 oral rabies vaccine in various Zimbabwean wild non-target species.
#
# Distance to mean: 1.2472890615463257
# Title: The current state of rabies prevention in Europe.
#
# Distance to mean: 1.2697569131851196
# Title: Emergence of raccoon rabies in Connecticut, 1991-1994: spatial and temporal characteristics of animal infection and human contact.
#
# Distance to mean: 1.2700859308242798
# Title: The long incubation period in rabies: delayed progression of infection in muscle at the site of exposure.
#
# Distance to mean: 1.312107801437378
# Title: [Current status of animal rabies in France].
#
# Year: 1998
#
# Distance to mean: 1.2974040508270264
# Title: A review of the economics of the prevention and control of rabies. Part 2: Rabies in dogs, livestock and wildlife.
#
# Distance to mean: 1.3028604984283447
# Title: Efficacy of an oral vaccinia-rabies glycoprotein recombinant vaccine in controlling epidemic raccoon rabies in New Jersey.
#
# Distance to mean: 1.3138054609298706
# Title: First North American field release of a vaccinia-rabies glycoprotein recombinant virus.
#
# Distance to mean: 1.3512054681777954
# Title: A comparison of two serological methods for detecting the immune response after rabies vaccination in dogs and cats being exported to rabies-free areas.
#
# Distance to mean: 1.3605542182922363
# Title: Immunogenicity and safety in adults of a new chromatographically purified Vero-cell rabies vaccine (CPRV): a randomized, double-blind trial with purified Vero-cell rabies vaccine (PVRV).
#
# Year: 1999
#
# Distance to mean: 1.3303636312484741
# Title: Characterization and observation of animals responsible for rabies post-exposure treatment in Phnom Penh, Cambodia.
#
# Distance to mean: 1.4013628959655762
# Title: [Practical aspects of human rabies prevention]
#
# Distance to mean: 1.4264240264892578
# Title: Epidemiology and control of fox rabies in Europe.
#
# Distance to mean: 1.4310137033462524
# Title: Rabies DNA vaccines for protection and therapeutic treatment.
#
# Distance to mean: 1.433570384979248
# Title: Immunization of dogs with a DNA vaccine induces protection against rabies virus.
#
# Year: 2000
#
# Distance to mean: 1.153454065322876
# Title: Immunogenicity and effectiveness of post-exposure rabies prophylaxis with a new chromatographically purified Vero-cell rabies vaccine (CPRV): a two-stage randomised clinical trial in the Philippines.
#
# Distance to mean: 1.215013861656189
# Title: Rabies in Israel: decades of prevention and a human case.
#
# Distance to mean: 1.363279938697815
# Title: ELISA test for rabies antibody titration in orally vaccinated foxes sampled in the fields.
#
# Distance to mean: 1.4224892854690552
# Title: Mammalian reservoirs and epidemiology of rabies diagnosed in human beings in the United States, 1981-1998.
#
# Distance to mean: 1.4255050420761108
# Title: Antibody response of patients after postexposure rabies vaccination with small intradermal doses of purified chick embryo cell vaccine or purified Vero cell rabies vaccine.
#
# Year: 2001
#
# Distance to mean: 1.2798279523849487
# Title: Immunogenicity and efficacy of Fermi-type nerve tissue rabies vaccine in mice and in humans undergoing post-exposure prophylaxis for rabies in Ethiopia.
#
# Distance to mean: 1.3026610612869263
# Title: Rapid clearance of SAG-2 rabies virus from dogs after oral vaccination.
#
# Distance to mean: 1.3213865756988525
# Title: [Clinical endpoints during rabies vaccine control tests].
#
# Distance to mean: 1.3421088457107544
# Title: Regular exposure to rabies virus and lack of symptomatic disease in Serengeti spotted hyenas.
#
# Distance to mean: 1.3654345273971558
# Title: [Transitory changes in public and physician behavior following the reappearance of human rabies in Israel].
#
# Year: 2002
#
# Distance to mean: 1.1515908241271973
# Title: Rabies re-examined.
#
# Distance to mean: 1.2459473609924316
# Title: New approaches to the development of live attenuated rabies vaccines.
#
# Distance to mean: 1.310339093208313
# Title: Rabies intradermal post-exposure vaccination of humans using reconstituted and stored vaccine.
#
# Distance to mean: 1.4133415222167969
# Title: [Standardization of rabies virus genome amplification for its use in molecular epidemiology studies].
#
# Distance to mean: 1.431478500366211
# Title: Rabies post-exposure management in South Africa: a telephonic survey used as a rapid tool for operational research.
#
# Year: 2003
#
# Distance to mean: 1.0996689796447754
# Title: Case report: rapid ante-mortem diagnosis of a human case of rabies imported into the UK from the Philippines.
#
# Distance to mean: 1.131740689277649
# Title: Risk factors associated with travel to rabies endemic countries.
#
# Distance to mean: 1.2755520343780518
# Title: Rabies in wildlife in Latvia.
#
# Distance to mean: 1.3280049562454224
# Title: Case report: isolation of a European bat lyssavirus type 2a from a fatal human case of rabies encephalitis.
#
# Distance to mean: 1.333815336227417
# Title: Development of a cocktail of recombinant-expressed human rabies virus-neutralizing monoclonal antibodies for postexposure prophylaxis of rabies.
#
# Year: 2004
#
# Distance to mean: 1.1355648040771484
# Title: Oral vaccination of wildlife against rabies: opportunities and challenges in prevention and control.
#
# Distance to mean: 1.1563273668289185
# Title: Elimination of terrestrial rabies in Western European countries.
#
# Distance to mean: 1.2940943241119385
# Title: [Human rabies in France in 2004: update and management].
#
# Distance to mean: 1.3769376277923584
# Title: Rabies in red foxes (Vulpes vulpes) experimentally infected with European bat lyssavirus type 1.
#
# Distance to mean: 1.4469642639160156
# Title: Rabies neutralizing antibody detection by indirect immunperoxidase serum neutralization assay performed on chicken embryo related cell line.
#
# Year: 2005
#
# Distance to mean: 1.2015101909637451
# Title: Rabies as a traveler's risk, especially in high-endemicity areas.
#
# Distance to mean: 1.2269349098205566
# Title: Pathophysiology of human paralytic rabies.
#
# Distance to mean: 1.2602794170379639
# Title: Efficacy of rabies biologics against new lyssaviruses from Eurasia.
#
# Distance to mean: 1.30003023147583
# Title: WHO Expert Consultation on rabies.
#
# Distance to mean: 1.3020493984222412
# Title: Clinical laboratory advances in the detection of rabies virus.
#
# Year: 2006
#
# Distance to mean: 1.2114754915237427
# Title: Control and prevention of rabies in animals: paradigm shifts.
#
# Distance to mean: 1.2143911123275757
# Title: Current and future trends in the prevention, treatment and control of rabies.
#
# Distance to mean: 1.2169935703277588
# Title: Ability of rabies vaccine strains to elicit cross-neutralising antibodies.
#
# Distance to mean: 1.2370423078536987
# Title: Ecoepidemiological and Social Factors Related to Rabies Incidence in Venezuela during 2002-2004.
#
# Distance to mean: 1.262434720993042
# Title: Antemortem diagnosis of new york human rabies case and review of u.s. Cases.
#
# Year: 2007
#
# Distance to mean: 1.1846429109573364
# Title: [An epidemiological study of rabies virus in domestic dogs, cats and wildlife and the immunogenicity study for rabies vaccines derived from different cell cultured virus strains].
#
# Distance to mean: 1.2923396825790405
# Title: Failure to open the blood-brain barrier and deliver immune effectors to central nervous system tissues leads to the lethal outcome of silver-haired bat rabies virus infection.
#
# Distance to mean: 1.3901281356811523
# Title: Oral vaccination of raccoons (Procyon lotor) with genetically modified rabies virus vaccines.
#
# Distance to mean: 1.4148088693618774
# Title: Synchronous cycles of domestic dog rabies in sub-Saharan Africa and the impact of control efforts.
#
# Distance to mean: 1.437730073928833
# Title: Animal-based national surveillance for zoonotic disease: quality, limitations, and implications of a model system for monitoring rabies.
#
# Year: 2008
#
# Distance to mean: 1.147436261177063
# Title: Era vaccine-derived cases of rabies in wildlife and domestic animals in Ontario, Canada, 1989-2004.
#
# Distance to mean: 1.2371705770492554
# Title: Use of a molecular epidemiological database to track human rabies case histories in South Africa.
#
# Distance to mean: 1.2398366928100586
# Title: The control of rabies in Eurasia: overview, history and background.
#
# Distance to mean: 1.2405685186386108
# Title: Epidemiology of animal bites and rabies cases in India. A multicentric study.
#
# Distance to mean: 1.2458196878433228
# Title: Post-exposure prophylaxis (PEP) of rabies-infected Indian street dogs.
#
# Year: 2009
#
# Distance to mean: 1.1833416223526
# Title: [Rabies].
#
# Distance to mean: 1.2345675230026245
# Title: Analysis of vaccine-virus-associated rabies cases in red foxes (Vulpes vulpes) after oral rabies vaccination campaigns in Germany and Austria.
#
# Distance to mean: 1.2356956005096436
# Title: Development of a mouse monoclonal antibody cocktail for post-exposure rabies prophylaxis in humans.
#
# Distance to mean: 1.2396527528762817
# Title: Competitive ELISA using a rabies glycoprotein-transformed cell line to semi-quantify rabies neutralizing-related antibodies in dogs.
#
# Distance to mean: 1.2581623792648315
# Title: Is there a need for anti-rabies vaccine and immunoglobulins rationing in Europe?
#
# Year: 2010
#
# Distance to mean: 1.244419813156128
# Title: Development in Immunoprophylaxis against Rabies for Animals and Humans.
#
# Distance to mean: 1.251891016960144
# Title: Rabies and African bat lyssavirus encephalitis and its prevention.
#
# Distance to mean: 1.272546648979187
# Title: [A human rabies case with antemortem diagnosis].
#
# Distance to mean: 1.3211753368377686
# Title: New rabies virus variant found during an epizootic in white-nosed coatis from the Yucatan Peninsula.
#
# Distance to mean: 1.3354469537734985
# Title: [Evaluation of rabies-suspected bites in Giresun, eastern Black-Sea region, Turkey].
#
# Year: 2011
#
# Distance to mean: 1.1276911497116089
# Title: Human rabies encephalitis prevention and treatment: progress since Pasteur's discovery.
#
# Distance to mean: 1.1313223838806152
# Title: A case study of rabies diagnosis from formalin-fixed brain material.
#
# Distance to mean: 1.1646429300308228
# Title: Update on rabies.
#
# Distance to mean: 1.272044062614441
# Title: Rabies research in resource-poor countries.
#
# Distance to mean: 1.3021620512008667
# Title: An evaluation of dog rabies control in Limpopo province (South Africa).
#
# Year: 2012
#
# Distance to mean: 1.145648717880249
# Title: [Vaccination against rabies: how and when?].
#
# Distance to mean: 1.2341610193252563
# Title: Developments in rabies vaccines.
#
# Distance to mean: 1.2387347221374512
# Title: New introduction and spread of rabies among dog population in Bangui.
#
# Distance to mean: 1.2466247081756592
# Title: Process optimization and scale-up for production of rabies vaccine live adenovirus vector (AdRG1.3).
#
# Distance to mean: 1.258678674697876
# Title: Recovery of a patient from clinical rabies--California, 2011.
#
# Year: 2013
#
# Distance to mean: 0.9899157285690308
# Title: Rabies in Iraq: trends in human cases 2001-2010 and characterisation of animal rabies strains from Baghdad.
#
# Distance to mean: 1.022023320198059
# Title: Rabid fox bites and human rabies in a village community in southern India: epidemiological and laboratory investigations, management and follow-up.
#
# Distance to mean: 1.136557698249817
# Title: Current and future approaches to the therapy of human rabies.
#
# Distance to mean: 1.1365768909454346
# Title: [Rabies].
#
# Distance to mean: 1.1801106929779053
# Title: Rabies and canine distemper virus epidemics in the red fox population of northern Italy (2006-2010).
#
# Year: 2014
#
# Distance to mean: 1.0349153280258179
# Title: The phylogeography of rabies in Grenada, West Indies, and implications for control.
#
# Distance to mean: 1.2484562397003174
# Title: Characterizing rabies epidemiology in remote Inuit communities in Québec, Canada: a "One Health" approach.
#
# Distance to mean: 1.2567732334136963
# Title: Development and evaluation of a new immunohistochemistry-based test for the detection of rabies virus neutralizing antibodies.
#
# Distance to mean: 1.2751532793045044
# Title: Diagnostic evaluation of RT-PCR-ELISA for the detection of rabies virus.
#
# Distance to mean: 1.2788105010986328
# Title: Antibodies to rabies virus in terrestrial wild mammals in native rainforest on the north coast of São Paulo State, Brazil.
#
# Year: 2015
#
# Distance to mean: 1.0957138538360596
# Title: Everything You Always Wanted to Know About Rabies Virus (But Were Afraid to Ask).
#
# Distance to mean: 1.1399791240692139
# Title: Public Health Responses to Reemergence of Animal Rabies, Taiwan, July 16-December 28, 2013.
#
# Distance to mean: 1.1885713338851929
# Title: Instructive even after a decade: Complete results of initial virological diagnostics and re-evaluation of molecular data in the German rabies virus "outbreak" caused by transplantations.
#
# Distance to mean: 1.2361079454421997
# Title: Rabies: the clinical features, management and prevention of the classic zoonosis.
#
# Distance to mean: 1.247084379196167
# Title: A case report on indirect transmission of human rabies.
#
# Year: 2016
#
# Distance to mean: 1.210321307182312
# Title: Diagnostic difficulties in human rabies: A case report and review of the literature.
#
# Distance to mean: 1.262146234512329
# Title: Laboratory diagnostics in dog-mediated rabies: an overview of performance and a proposed strategy for various settings.
#
# Distance to mean: 1.2753875255584717
# Title: A Presumptive Case of Human Rabies: A Rare Survived Case in Rural Ghana.
#
# Distance to mean: 1.2870604991912842
# Title: Serologic response in eight alpacas vaccinated by extralabel use of a large animal rabies vaccine during a public health response to a rabid alpaca in South Carolina.
#
# Distance to mean: 1.29056715965271
# Title: Local infiltration of rabies immunoglobulins without systemic intramuscular administration: An alternative cost effective approach for passive immunization against rabies.
#
# Year: 2017
#
# Distance to mean: 1.010284662246704
# Title: Lyssaviruses and rabies: current conundrums, concerns, contradictions and controversies.
#
# Distance to mean: 1.0372560024261475
# Title: Rabies - epidemiology, pathogenesis, public health concerns and advances in diagnosis and control: a comprehensive review.
#
# Distance to mean: 1.1335303783416748
# Title: Management and modeling approaches for controlling raccoon rabies: The road to elimination.
#
# Distance to mean: 1.1374011039733887
# Title: Epidemiology of Rabies in Lesotho: The Importance of Routine Surveillance and Virus Characterization.
#
# Distance to mean: 1.1748530864715576
# Title: Oral vaccination of wildlife using a vaccinia-rabies-glycoprotein recombinant virus vaccine (RABORAL V-RG®): a global review.
#
# Year: 2018
#
# Distance to mean: 0.9590775370597839
# Title: Experimental screening studies on rabies virus transmission and oral rabies vaccination of the Greater Kudu (Tragelaphus strepsiceros).
#
# Distance to mean: 1.0214353799819946
# Title: Human rabies in Côte d'Ivoire 2014-2016: Results following reinforcements to rabies surveillance.
#
# Distance to mean: 1.028599739074707
# Title: A Perspective on Rabies in the Middle East-Beyond Neglect.
#
# Distance to mean: 1.0898411273956299
# Title: Rabies Virus.
#
# Distance to mean: 1.1311790943145752
# Title: Practical inter-sectoral linking: Tool to rabies One Health coordination to the grass-roots level.
#
# Year: 2019
#
# Distance to mean: 1.0412638187408447
# Title: Current status of human rabies prevention: remaining barriers to global biologics accessibility and disease elimination.
#
# Distance to mean: 1.1289256811141968
# Title: An evaluation of Brazil's surveillance and prophylaxis of canine rabies between 2008 and 2017.
#
# Distance to mean: 1.137755274772644
# Title: Intradermal rabies post-exposure prophylaxis can be abridged with no measurable impact on clinical outcome in Cambodia, 2003-2014.
#
# Distance to mean: 1.1546796560287476
# Title: The impact of transmission dynamics of rabies control: Systematic review.
#
# Distance to mean: 1.1662176847457886
# Title: Development and validation of a real-time RT-PCR assay for the quantification of rabies virus as quality control of inactivated rabies vaccines.
#
# Year: 2020
#
# Distance to mean: 1.1798632144927979
# Title: Molecular study of rabies virus in slaughtered dogs in Billiri and Kaltungo local government areas of Gombe state, Nigeria.
#
# Distance to mean: 1.2235568761825562
# Title: Modern biologics for rabies prophylaxis and the elimination of human cases mediated by dogs.
#
# Distance to mean: 1.2405834197998047
# Title: Towards rabies elimination in the Asia-Pacific region: From theory to practice.
#
# Distance to mean: 1.2571940422058105
# Title: Survival in human rabies but left against medical advice and death followed - Community education is the need of the hour.
#
# Distance to mean: 1.2658571004867554
# Title: A next generation vaccine against human rabies based on a single dose of a chimpanzee adenovirus vector serotype C.

# %% [markdown]
# ### Quantify novelty of each year by the proportion of papers whose abstract embeddings are far from previous years' abstract embeddings

# %%
# threshold distance to consider a paper to be novel
CUTOFF_DISTANCE = 5

# %%
year = year_span[0]

abstracts_prev = abstracts[years == year]
abstract_vectors_prev = abstract_vectors[years == year]
abstracts_prev = years[years == year]

counts = []

for year in year_span[1:]:
    abstracts_curr = abstracts[years == year]
    abstract_vectors_curr = abstract_vectors[years == year]
    years_curr = years[years == year]
    
    ds = []
    abstracts_r, years_r = [], []
    
    count = 0.0
    
    for (abstract_curr, abstract_vector_curr, year_curr) in zip(abstracts_curr, abstract_vectors_curr, years_curr):
        min_distance = np.inf
        abstract_min, abstract_vector_min, year_min = None, None, None
        abstract_rmin, abstract_vector_rmin, year_rmin = None, None, None
        for (abstract_prev, abstract_vector_prev, year_prev) in zip(abstracts_prev, abstract_vectors_prev, years_prev):
            if dist(abstract_vector_curr, abstract_vector_prev) < min_distance:
                min_distance = dist(abstract_vector_curr, abstract_vector_prev)
                abstract_min, abstract_vector_min, year_min = abstract_curr, abstract_vector_curr, year_curr
                abstract_rmin, abstract_vector_rmin, year_rmin = abstract_prev, abstract_vector_prev, year_prev
                
        ds.append(min_distance)
        abstracts_r.append(abstract_rmin)
        years_r.append(year_rmin)
        
        if min_distance > CUTOFF_DISTANCE:
            count += 1
                
    ds_sorted, abstracts_r_sorted, years_r_sorted, abstracts_curr_sorted = zip(*sorted(zip(ds, abstracts_r, years_r, abstracts_curr), key=lambda x: -x[0]))
                                    
    abstracts_prev = np.concatenate((abstracts_prev, abstracts_curr))
    abstract_vectors_prev = np.concatenate((abstract_vectors_prev, abstract_vectors_curr))
    years_prev = np.concatenate((years_prev, years_curr))
    
    counts.append(count / len(years_curr))

# %%
plt.figure(figsize=(20, 10))
plt.scatter(year_span[1:], counts, color='b', s=100)
plt.plot(year_span[1:], counts, color='b')
plt.title(f'Semantic Distance Novelty for {term} from Abstracts')
plt.xlabel('Year')
plt.ylabel('Proportion of Novel Papers')
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Identify clusters of novel research based on paper abstracts

# %%
# identify research papers published between year CHANGEPOINT and CHANGEPOINT + DELTA,  such that
# (the mean distance between the paper abstract and its K nearest neighbors published before week CHANGEPOINT)
# is at least RATIO_THRESHOLD times (the mean distance between the paper abstract and its K nearest neighbors
# also published between CHANGEPOINT and CHANGEPOINT + DELTA)
CHANGEPOINT = 2000
K = 3
DELTA = 5
RATIO_THRESHOLD = 1.2

# %%
abstracts_old, abstract_vectors_old, years_old = [], [], []
abstracts_new, abstract_vectors_new, years_new, titles_new = [], [], [], []

for abstract, abstract_vector, year in zip(abstracts, abstract_vectors, years):
    if year < CHANGEPOINT:
        abstracts_old.append(abstract)
        abstract_vectors_old.append(abstract_vector)
        years_old.append(year)
    if year >= CHANGEPOINT and year <= CHANGEPOINT + DELTA:
        abstracts_new.append(abstract)
        abstract_vectors_new.append(abstract_vector)
        years_new.append(year)
        titles_new.append(title)
            
for abstract, abstract_vector, year, title in zip(abstracts_new, abstract_vectors_new, years_new, titles_new):
    new_distance = np.mean(sorted([dist(abstract_vector, t_v) for t_v in abstract_vectors_new])[1:][:K])
    old_distance = np.mean(sorted([dist(abstract_vector, t_v) for t_v in abstract_vectors_old])[:K])
    
    if (old_distance / new_distance) > RATIO_THRESHOLD:
        print(f'Year: {year}')
        print(f'Ratio: {old_distance / new_distance}')
        print(f'New Distance: {new_distance}')
        print(f'Old Distance: {old_distance}')
        print(f'Title: {title}')
        print()
# Out:
# Year: 2005
# Ratio: 1.3419805765151978
# New Distance: 0.6779802441596985
# Old Distance: 0.9098362922668457
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.4945796728134155
# New Distance: 1.028464674949646
# Old Distance: 1.537122368812561
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.6081777811050415
# New Distance: 0.9453350901603699
# Old Distance: 1.5202668905258179
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.6863805055618286
# New Distance: 1.1947669982910156
# Old Distance: 2.014831781387329
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.4945796728134155
# New Distance: 1.028464674949646
# Old Distance: 1.537122368812561
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.6081777811050415
# New Distance: 0.9453350901603699
# Old Distance: 1.5202668905258179
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.6863805055618286
# New Distance: 1.1947669982910156
# Old Distance: 2.014831781387329
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.8260196447372437
# New Distance: 0.7449491620063782
# Old Distance: 1.360291838645935
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.4944766759872437
# New Distance: 2.0564053058624268
# Old Distance: 3.0732498168945312
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.3303099870681763
# New Distance: 1.5857535600662231
# Old Distance: 2.109543800354004
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.2156168222427368
# New Distance: 1.3083678483963013
# Old Distance: 1.590474009513855
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.5279968976974487
# New Distance: 1.3090356588363647
# Old Distance: 2.0002024173736572
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.4944766759872437
# New Distance: 2.0564053058624268
# Old Distance: 3.0732498168945312
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2005
# Ratio: 1.2188701629638672
# New Distance: 0.688254177570343
# Old Distance: 0.8388924598693848
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2004
# Ratio: 1.4326356649398804
# New Distance: 0.5755756497383118
# Old Distance: 0.8245902061462402
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2004
# Ratio: 1.3311504125595093
# New Distance: 1.5239028930664062
# Old Distance: 2.0285439491271973
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2004
# Ratio: 1.9745506048202515
# New Distance: 0.6618085503578186
# Old Distance: 1.3067744970321655
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2004
# Ratio: 1.622802972793579
# New Distance: 0.3567264974117279
# Old Distance: 0.5788968205451965
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2004
# Ratio: 1.5360628366470337
# New Distance: 1.3034733533859253
# Old Distance: 2.0022170543670654
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2004
# Ratio: 1.2410112619400024
# New Distance: 1.3018370866775513
# Old Distance: 1.615594506263733
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2003
# Ratio: 1.5339267253875732
# New Distance: 0.5221017599105835
# Old Distance: 0.8008658289909363
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2003
# Ratio: 1.222557783126831
# New Distance: 2.202228307723999
# Old Distance: 2.6923513412475586
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2003
# Ratio: 1.965630054473877
# New Distance: 0.6832329630851746
# Old Distance: 1.3429832458496094
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2003
# Ratio: 1.622802972793579
# New Distance: 0.3567264974117279
# Old Distance: 0.5788968205451965
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2003
# Ratio: 1.229514718055725
# New Distance: 1.2114969491958618
# Old Distance: 1.4895533323287964
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2002
# Ratio: 1.6734355688095093
# New Distance: 0.5149593353271484
# Old Distance: 0.8617512583732605
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2002
# Ratio: 1.573563575744629
# New Distance: 0.8226470947265625
# Old Distance: 1.294487476348877
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2002
# Ratio: 1.2099932432174683
# New Distance: 1.544864296913147
# Old Distance: 1.869275450706482
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2001
# Ratio: 1.5701147317886353
# New Distance: 0.5381028652191162
# Old Distance: 0.8448832631111145
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2001
# Ratio: 1.5594658851623535
# New Distance: 0.8887481689453125
# Old Distance: 1.385972499847412
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2001
# Ratio: 1.3456529378890991
# New Distance: 1.749222755432129
# Old Distance: 2.353846788406372
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2000
# Ratio: 1.249969244003296
# New Distance: 0.5858919024467468
# Old Distance: 0.7323468327522278
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2000
# Ratio: 1.4064278602600098
# New Distance: 0.8506572842597961
# Old Distance: 1.1963881254196167
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.
#
# Year: 2000
# Ratio: 1.2926266193389893
# New Distance: 1.7834806442260742
# Old Distance: 2.3053746223449707
# Title: The phosphoprotein of rabies virus is phosphorylated by a unique cellular protein kinase and specific isomers of protein kinase C.

# %% [markdown]
# ### Create differential wordclouds for paper abstracts

# %%
# creates a differential wordcloud for words appearing in year2, vs all words appearing before or during year1
def create_wordcloud(year1, year2):
    freqs_prev = np.sum(v[years <= year1], axis=0) / np.sum(years <= year1)
    freqs_new = np.sum(v[years == year2], axis=0) / np.sum(years == year2)

    diffs = np.subtract(freqs_prev, freqs_new)

    pos_features, neg_features = set(), set()

    d = {}
    for diff, feature in zip(diffs, features_unsorted):
        if feature in stop_words:
            continue

        diff = round(diff * 1000)
        if diff > 0:
            d[feature] = diff
            pos_features.add(feature)
        if diff < 0:
            neg_features.add(feature) 
            d[feature] = -diff

    def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
        if word in pos_features:
            return "rgb(0, 0, 0)"
        if word in neg_features:
            return "rgb(256, 0, 0)"

    wordcloud = WordCloud(background_color='white', height=500, width=1000)
    wordcloud.generate_from_frequencies(frequencies=d)
    plt.figure(figsize=(20, 10))
    plt.imshow(wordcloud.recolor(color_func=color_func, random_state=3),
               interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(1999, 2000)
