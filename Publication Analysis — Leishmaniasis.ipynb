# %% [markdown]
# # Publication Analysis

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import necessary packages

# %%
import requests, lxml, sys, sent2vec, nltk, cProfile

import numpy as np
import matplotlib.pyplot as plt
import bayesian_changepoint_detection.offline_changepoint_detection as offcd

from sklearn.feature_extraction.text import CountVectorizer
from nltk import word_tokenize
from nltk.corpus import stopwords
from string import punctuation
from sklearn.decomposition import PCA
from functools import partial
from wordcloud import WordCloud
from bs4 import BeautifulSoup
# Out:
# Use scipy logsumexp().

# %% [markdown]
# ### Load models

# %%
nltk.download('stopwords')
nltk.download('punkt')

model_path = 'biosentvec.bin'
model = sent2vec.Sent2vecModel()
model.load_model(model_path)
# Out:
# [nltk_data] Downloading package stopwords to /Users/dddp/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/dddp/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Set constants

# %%
term = 'Leishmaniasis'

BASE_URL = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/'
MIN_PAPERS = 50 # minimum number of papers in a year to use for analysis
stop_words = set(stopwords.words('english'))

# %% [markdown]
# ### Define helper functions

# %%
# preprocesses text before BioSentVec embedding
def preprocess_sentence(text):
    text = text.replace('/', ' / ')
    text = text.replace('.-', ' .- ')
    text = text.replace('.', ' . ')
    text = text.replace('\'', ' \' ')
    text = text.lower()

    tokens = [token for token in word_tokenize(text) if token not in punctuation and token not in stop_words]

    return ' '.join(tokens)

# computes Euclidean distance
def dist(x, y):
    return np.linalg.norm(x - y)

# converts a list to a comma separated values format
def list_to_csv(lst):
    ret = ''
    for i, val in enumerate(lst):
        ret += f'{val},'
    return ret[:-1]

# returns the UIDs of papers based on searching the title for a query
def get_uids(query):
    uid_list = []

    retstart = 0
    RETMAX = 100000
    
    while True:
        params = {
            'db': 'pubmed',
            'term': f'{query}[title]',
            'retmax': RETMAX,
            'retstart': retstart,
        }
        res = requests.get(f'{BASE_URL}esearch.fcgi', params)
        soup = BeautifulSoup(res.text, 'xml')
        uids = soup.find_all('Id')
        num_uids = len(uids)
        if num_uids == 0:
            print(f'Found {len(uid_list)} UIDs corresponding to {query}.')
            return uid_list
        else:
            uid_list = uid_list + [uid.text for uid in uids]
            retstart += RETMAX
            
# returns the titles, abstracts, years, and year_span of publications corresponding to input UIDs          
def get_summaries(uids):
    titles = []
    abstracts = []
    years = []

    retstart = 0
    MAX_REQUEST = 10000 # number of uids to request at a time

    sys.stdout.write(f'\rRetrieved {retstart} / {len(uids)} titles.')
    sys.stdout.flush()

    while (retstart < len(uids)):
        query_uids = uids[retstart:retstart + MAX_REQUEST]
        params = {
        'db': 'pubmed',
        'id': list_to_csv(query_uids),
        'retmax': MAX_REQUEST,
        'retmode': 'xml',
        'rettyle': 'abstract,'
        }
        res = requests.post(f'{BASE_URL}efetch.fcgi', params)
        soup = BeautifulSoup(res.text, 'xml')

        soup_articles = soup.find_all('PubmedArticle')

        for soup_article in soup_articles:
            soup_title = soup_article.find('ArticleTitle')
            soup_date = soup_article.find('PubDate')
            soup_abstract = soup_article.find('AbstractText')

            if soup_title is None or soup_date is None or soup_abstract is None or soup_date.find('Year') is None:
                continue

            titles.append(soup_title.text.replace('\xa0', ' ').replace('<i>', '').replace('</i>', ''))
            years.append(int(soup_date.find('Year').text))
            abstracts.append(soup_abstract.text)

        retstart += MAX_REQUEST

        sys.stdout.write(f'\rRetrieved {min(retstart, len(uids))} / {len(uids)} summaries.')
        sys.stdout.flush()

    titles, abstracts, years = np.array(titles), np.array(abstracts), np.array(years)
    
    titles = titles[~np.isnan(years)]
    abstracts = abstracts[~np.isnan(years)]
    years = years[~np.isnan(years)]
    
    titles_mod, abstracts_mod, years_mod = [], [], []
    
    for title, abstract, year in zip(titles, abstracts, years):
        if len(years[years == year]) >= MIN_PAPERS:
            titles_mod.append(title)
            abstracts_mod.append(abstract)
            years_mod.append(year)
            
    titles, abstracts, years = np.array(titles_mod), np.array(abstracts_mod), np.array(years_mod)
    
    year_span = np.unique(years)

    print(f'\nAfter filtering, retrieved {len(titles)} summaries.')
        
    return titles, abstracts, years, year_span

def get_titles_and_abstracts_and_years(term):
    return get_summaries(get_uids(term))

# %% [markdown]
# ### Load publication data from NCBI

# %%
titles, abstracts, years, year_span = get_titles_and_abstracts_and_years(term)
# Out:
# Found 13810 UIDs corresponding to Leishmaniasis.
# Retrieved 13810 / 13810 summaries.
# After filtering, retrieved 8592 summaries.

# %% [markdown]
# ## Publication Analysis

# %% [markdown]
# ### Number of publications vs time

# %%
num_papers = [np.sum(years == year) for year in year_span]

fig = plt.figure(figsize=(20, 10))
plt.title(f'{term} Papers Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Papers')
plt.plot(year_span, num_papers, color='b')
plt.scatter(year_span, num_papers, color='b', s=100)
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Title length vs time

# %%
lengths = np.array([len(title) for title in titles])
average_lengths = [np.mean(lengths[years == year]) for year in year_span]
stdev_lengths = [np.std(lengths[years == year]) for year in year_span]

plt.figure(figsize=(20, 10))
plt.scatter(year_span, average_lengths, color='b', s=100)
plt.plot(year_span, average_lengths, color='b')
plt.errorbar(year_span, average_lengths, yerr=stdev_lengths, fmt='none', color='b', capsize=20)
plt.title(f'Yearly Title Length for {term}')
plt.xlabel('Year')
plt.ylabel('Title Length (characters)')
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Title entropies vs time

# %%
vectorizer = CountVectorizer()
v = vectorizer.fit_transform(titles).toarray()
frequencies_unsorted = np.sum(v, axis=0)
features_unsorted = vectorizer.get_feature_names()
features, frequencies = zip(*sorted(zip(features_unsorted, frequencies_unsorted), key=lambda f: -f[1]))

probabilities = []

for year in year_span:
    t = v[years == year]
    probabilities.append(np.sum(t, axis=0) / np.sum(np.sum(t, axis=0)))

entropies = [-np.sum(np.multiply(probability, np.nan_to_num(np.log2(probability), neginf=0))) for probability in probabilities]

plt.figure(figsize=(20, 10))
plt.plot(year_span, entropies, color='b')
plt.scatter(year_span, entropies, color='b', s=100)
plt.title(f'Yearly Entropy of Titles for {term}')
plt.xlabel('Year')
plt.ylabel('Entropy of Titles')
plt.rc('font', size=20)
plt.show()
# Out:
# /Users/dddp/Documents/TemporalLandscape/env_TemporalLandscape/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log2
#   del sys.path[0]

# %% [markdown]
# ### Most common words in publication titles

# %%
num_plot = 40

# %%
frequencies_per_title = np.divide(frequencies, len(years))

frequencies_plot, features_plot = [], []
for frequency, feature in zip(frequencies_per_title, features):
    if feature not in stop_words:
        frequencies_plot.append(frequency)
        features_plot.append(feature)

fig = plt.figure(figsize=(20, 10))
plt.title(f'Word Frequencies in {term} Titles')
plt.xlabel('Word')
plt.ylabel('Frequency per Title')
plt.bar(range(num_plot), frequencies_plot[1:num_plot+1], color='b')
plt.xticks(range(num_plot), features_plot[1:num_plot+1])
plt.setp(plt.gca().get_xticklabels(), rotation=-90, size=30)
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Word frequency changepoint analysis in publication titles

# %%
# only consider words whose average title frequency is at least FREQUENCY_THRESHOLD
FREQUENCY_THRESHOLD = 0.05

# only consider words with a changepoint probability of at least PROBABILITY_THRESHOLD
PROBABILITY_THRESHOLD = 0.5

# %%
word_distributions = []
for year in year_span:
    t = v[years == year]
    word_distributions.append(np.sum(t, axis=0) / np.sum(years == year))
word_distributions = np.transpose(word_distributions)

for feature in features:
    if np.mean(word_distributions[features_unsorted.index(feature)]) < FREQUENCY_THRESHOLD:
        break
    
    data_unnormalized = word_distributions[features_unsorted.index(feature)]
    
    data = []
    for i, year in enumerate(year_span):
        if data_unnormalized[i] == 0:
            data.append(0)
        else:
            data.append(data_unnormalized[i] / np.max(data_unnormalized) * 100)
    data = np.array(data)
    
    Q, P, Pcp = offcd.offline_changepoint_detection(data, partial(offcd.const_prior, l=(len(data)+1)), offcd.gaussian_obs_log_likelihood, truncate=-40)
    probs = np.exp(Pcp).sum(0)
    
    if np.max(probs) < PROBABILITY_THRESHOLD:
        continue
    
    plt.figure(figsize=(20, 20))
    plt.subplot(211)
    plt.plot(year_span, word_distributions[features_unsorted.index(feature)], color='b')
    plt.scatter(year_span, word_distributions[features_unsorted.index(feature)], color='b', s=100)
    plt.title(f'Word Frequency Per Title for {term}: {feature}')
    plt.xlabel('Year')
    plt.ylabel('Frequency Per Title')
    plt.rc('font', size=20)
    
    plt.subplot(212)
    plt.title(f'Changepoint Analysis for {term}: {feature}')
    plt.xlabel('Year')
    plt.ylabel('Changepoint Probability')
    plt.plot(year_span[1:], probs, color='r')
    plt.scatter(year_span[1:], probs, color='r', s=100)
    plt.rc('font', size=20)
    plt.show()

# %% [markdown]
# ### Generate title vectors with BioSentVec

# %%
titles_processed = [preprocess_sentence(title) for title in titles]
title_vectors = model.embed_sentences(titles_processed)
titles_reduced = PCA(n_components=2).fit_transform(title_vectors)

plt.figure(figsize=(15, 10))
plt.scatter(titles_reduced.T[0], titles_reduced.T[1], c=years, cmap='plasma')
plt.title(f'{term} Title Embeddings')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.rc('font', size=20)
plt.colorbar().set_label('Year', rotation=90)
plt.show()

# %%
titles_span = np.array([np.mean(title_vectors[years == year], axis=0) for year in year_span])
titles_span_reduced = PCA(n_components=2).fit_transform(titles_span)

plt.figure(figsize=(15, 10))
plt.scatter(titles_span_reduced.T[0], titles_span_reduced.T[1], c=year_span, cmap='plasma', s=100)
plt.title(f'{term} Average Title Embeddings by Year')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar().set_label('Year', rotation=90)

plot_1 = titles_span_reduced[:-1]
plot_2 = titles_span_reduced[1:]
for i, p1 in enumerate(plot_1):
    p2 = plot_2[i]
    plt.plot([p1[0], p2[0]], [p1[1], p2[1]], color='gray')

plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Identify research trends by identifying the paper titles with embeddings closest to the mean for each year

# %%
# number of representative papers to list closest to the mean
NUMBER_OF_PAPERS = 5

# %%
for title_mean, year in zip(titles_span, year_span):
    titles_mod = titles[year == years]
    title_vectors_mod = title_vectors[year == years]
    ds = [dist(title_mean, t_v) for t_v in title_vectors_mod]
    ds_sorted, titles_sorted = zip(*sorted(zip(ds, titles_mod), key=lambda x: x[0]))
    print(f'Year: {year}')
    print()
    for i in range(NUMBER_OF_PAPERS):
        try:
            print(f'Distance to mean: {ds_sorted[i]}')
            print(f'Title: {titles_sorted[i]}')
            print()
        except:
            break
# Out:
# Year: 1983
#
# Distance to mean: 2.7623977661132812
# Title: Leishmaniasis in The Gambia. 2. A study of possible vectors and animal reservoirs, with the first report of a case of canine leishmaniasis in The Gambia.
#
# Distance to mean: 2.7671611309051514
# Title: Leishmaniasis in Brazil: XX. Prevalence of "enzootic rodent leishmaniasis" (Leishmania mexicana amazonensis), and apparent absence of "pian bois" (Le. braziliensis guyanensis), in plantations of introduced tree species and in other non-climax forests in eastern Amazônia.
#
# Distance to mean: 2.8804585933685303
# Title: The cellular and humoral immune response in subjects vaccinated against cutaneous leishmaniasis using Leishmania tropica major promastigotes.
#
# Distance to mean: 3.0040907859802246
# Title: Characterization of the cellular immune response in American cutaneous leishmaniasis.
#
# Distance to mean: 3.099562406539917
# Title: [Diffuse cutaneous leishmaniasis. Anatomo-pathologic aspects].
#
# Year: 1984
#
# Distance to mean: 2.623940944671631
# Title: Prophylactic immunization against experimental leishmaniasis. II. Further characterization of the protective immunity against fatal Leishmania tropica infection induced by irradiated promastigotes.
#
# Distance to mean: 2.7033727169036865
# Title: Prophylactic immunization against experimental leishmaniasis. III. Protection against fatal Leishmania tropica infection induced by irradiated promastigotes involves Lyt-1+2- T cells that do not mediate cutaneous DTH.
#
# Distance to mean: 2.832249879837036
# Title: Application of the indirect fluorescent antibody test in serodiagnosis of cutaneous leishmaniasis in experimentally infected mice and naturally infected Rhombomys opimus.
#
# Distance to mean: 2.832770347595215
# Title: Pathologic changes in murine leishmaniasis (Leishmania donovani) with special reference to the dynamics of granuloma formation in the liver.
#
# Distance to mean: 2.8344180583953857
# Title: Leishmaniasis in Greece II. Isolation and identification of the parasite causing cutaneous leishmaniasis in man.
#
# Year: 1985
#
# Distance to mean: 2.6268067359924316
# Title: Zoonotic cutaneous leishmaniasis in Saudi Arabia: lesions healing naturally in man followed by a second infection with the same zymodeme of Leishmania major.
#
# Distance to mean: 2.872692108154297
# Title: Leishmania braziliensis guyanensis dermal leishmaniasis: cell-mediated immunity related to clinical features.
#
# Distance to mean: 2.9510812759399414
# Title: Electron microscopy of Leishmania donovani in splenic aspirates from patients with visceral leishmaniasis during treatment with sodium stibogluconate.
#
# Distance to mean: 3.043307304382324
# Title: Prophylactic immunization against experimental leishmaniasis. V. Mechanism of the anti-protective blocking effect induced by subcutaneous immunization against Leishmania major infection.
#
# Distance to mean: 3.05613112449646
# Title: Visceral leishmaniasis unresponsive to antimonial drugs. III. Successful treatment using a combination of sodium stibogluconate plus allopurinol.
#
# Year: 1986
#
# Distance to mean: 2.92671799659729
# Title: The glycoconjugate derived from a Leishmania major receptor for macrophages is a suppressogenic, disease-promoting antigen in murine cutaneous leishmaniasis.
#
# Distance to mean: 2.983729600906372
# Title: Isolation of Leishmania mexicana amazonensis from the bone marrow in a case of American visceral leishmaniasis.
#
# Distance to mean: 3.0065486431121826
# Title: Leishmania major: solid phase radioimmunoassay for antibody detection in human cutaneous leishmaniasis.
#
# Distance to mean: 3.0134265422821045
# Title: Leishmaniasis in Brazil. XXII: Characterization of Leishmania from man, dogs and the sandfly Lutzomyia longipalpis (Lutz & Neiva, 1912) isolated during an outbreak of visceral leishmaniasis in Santarém, Pará State.
#
# Distance to mean: 3.0771820545196533
# Title: Characterization of the humoral immune response in Sudanese leishmaniasis: specific antibody detected by class- and subclass-specific reagents.
#
# Year: 1987
#
# Distance to mean: 2.613994598388672
# Title: Induction of delayed-type hypersensitivity to Leishmania major and the concomitant acceleration of disease development in progressive murine cutaneous leishmaniasis.
#
# Distance to mean: 2.687305212020874
# Title: Cutaneous leishmaniasis in Bolivia. A study of 185 human cases from Alto Beni (La Paz Department). Isolation and isoenzyme characterization of 26 strains of Leishmania braziliensis braziliensis [corrected].
#
# Distance to mean: 2.6923916339874268
# Title: Involvement of specific Lyt-2+ T cells in the immunological control of experimentally induced murine cutaneous leishmaniasis.
#
# Distance to mean: 2.7245585918426514
# Title: Experimental cutaneous leishmaniasis. II. A possible role for prostaglandins in exacerbation of disease in Leishmania major-infected BALB/c mice.
#
# Distance to mean: 2.7387702465057373
# Title: The relationship between severity of ulcerated lesions and immune responses in the early stage of cutaneous leishmaniasis in Ecuador.
#
# Year: 1988
#
# Distance to mean: 2.4888272285461426
# Title: Differential recognition of Leishmania aethiopica antigens by lymphocytes from patients with local and diffuse cutaneous leishmaniasis. Evidence for antigen-induced immune suppression.
#
# Distance to mean: 2.5436551570892334
# Title: Studies on canine leishmaniasis control. 1. Evolution of infection of different clinical forms of canine leishmaniasis following antimonial treatment.
#
# Distance to mean: 2.6792032718658447
# Title: Leishmania mexicana: effect of concomitant malaria on cutaneous leishmaniasis. Development of lesions in a Leishmania-susceptible (BALB/c) strain of mouse.
#
# Distance to mean: 2.7536396980285645
# Title: Canine American cutaneous leishmaniasis: a clinical and immunological study in dogs naturally infected with Leishmania braziliensis braziliensis in an endemic area of Rio de Janeiro, Brazil.
#
# Distance to mean: 2.761570453643799
# Title: Immunosuppressive medication associated with leishmanial antibodies in adults residing in an endemic focus of infantile visceral leishmaniasis--a case/control study.
#
# Year: 1989
#
# Distance to mean: 2.6735727787017822
# Title: [Eco-epidemiology of visceral and cutaneous leishmaniasis in the Arab Republic of Yemen. II. A survey using intradermal reaction to leishmanin in a zone of mixed infestation with Leishmania tropica, L. donovani and L. infantum].
#
# Distance to mean: 3.0652003288269043
# Title: [Eco-epidemiology of visceral and cutaneous leishmaniasis in the Yemen Arab Republic. I. Presence, in sympatric condition, of Leishmania infantum and Leishmania donovani complexes].
#
# Distance to mean: 3.11637806892395
# Title: Visceral leishmaniasis: drug carrier system characteristics and the ability to clear parasites from the liver, spleen and bone marrow in Leishmania donovani infected BALB/c mice.
#
# Distance to mean: 3.129560947418213
# Title: Peripheral neural involvement in cutaneous leishmaniasis. A pathologic study of human and experimental animal lesions.
#
# Distance to mean: 3.1953465938568115
# Title: Vaccination against murine cutaneous leishmaniasis by using Leishmania major antigen/liposomes. Optimization and assessment of the requirement for intravenous immunization.
#
# Year: 1990
#
# Distance to mean: 2.7013113498687744
# Title: Elevated cerebroside antibody levels in human visceral and cutaneous leishmaniasis, Trypanosoma rangeli infection, and chronic Chagas' disease.
#
# Distance to mean: 2.753479480743408
# Title: [Ecoepidemiology of leishmaniasis in Syria. 1. Leishmania major Yakimoff and Schokhor (Kinetoplastida-Trypanosomatidae) infestation of Psammomys obesus Cretzschmar (Rodentia-Gerbillidae)].
#
# Distance to mean: 2.776270866394043
# Title: Quantitative study of Leishmania braziliensis braziliensis reactive T cells in peripheral blood and in the lesions of patients with American mucocutaneous leishmaniasis.
#
# Distance to mean: 2.8184452056884766
# Title: Visceral leishmaniasis in patients infected with human immunodeficiency virus. Co-operative Group for the Study of Leishmaniasis in AIDS.
#
# Distance to mean: 2.852638006210327
# Title: Placebo-controlled clinical trial of meglumine antimonate (glucantime) vs. localized controlled heat in the treatment of cutaneous leishmaniasis in Guatemala.
#
# Year: 1991
#
# Distance to mean: 2.7144553661346436
# Title: Fine structure of Leishmania donovani in bone marrow aspirates from a patient with visceral leishmaniasis before and during treatment with sodium stibogluconate.
#
# Distance to mean: 2.7613775730133057
# Title: Cutaneous leishmaniasis of man due to Leishmania (Viannia) shawi Lainson, de Souza, Póvoa, Ishikawa & Silveira, in Pará State, Brazil.
#
# Distance to mean: 2.7972042560577393
# Title: Evidence of subjects sensitized to Leishmania infantum on the French Mediterranean coast: differences in gamma interferon production between this population and visceral leishmaniasis patients.
#
# Distance to mean: 2.9197940826416016
# Title: [Human cutaneous leishmaniasis caused by Leishmania Major MON-26 in the region of Damascus (Syria)].
#
# Distance to mean: 2.96458101272583
# Title: Experimental American leishmaniasis and Chagas' disease in the Brazilian squirrel monkey: effect of dual infection on antibodies to parasite antigens.
#
# Year: 1992
#
# Distance to mean: 2.5304887294769287
# Title: [Leishmaniasis in Karamay. XI. The development of cutaneous leishmaniasis in monkey and man experimentally infected with Leishmania from Karamay big gerbil].
#
# Distance to mean: 2.919283151626587
# Title: [Visceral leishmaniasis in Algeria. Evolution of visceral leishmaniasis in the Grande Kabylie area (1985-1990)].
#
# Distance to mean: 2.955152750015259
# Title: [Unilateral chronic granulomatous blepharitis as a leading symptom of Oriental cutaneous leishmaniasis in Germany. Giesma stain as rapid diagnosis and initial description of systemic therapy with gamma-interferon].
#
# Distance to mean: 3.015232563018799
# Title: Placebo-controlled clinical trial of sodium stibogluconate (Pentostam) versus ketoconazole for treating cutaneous leishmaniasis in Guatemala.
#
# Distance to mean: 3.0156097412109375
# Title: Ten years of kala-azar in west Bengal, Part I. Did post-kala-azar dermal leishmaniasis initiate the outbreak in 24-Parganas?
#
# Year: 1993
#
# Distance to mean: 2.792543888092041
# Title: Molecular characterization of a kinesin-related antigen of Leishmania chagasi that detects specific antibody in African and American visceral leishmaniasis.
#
# Distance to mean: 2.8223745822906494
# Title: Studies on the control of visceral leishmaniasis: validation of the Falcon assay screening test--enzyme-linked immunosorbent assay (FAST-ELISA) for field diagnosis of canine visceral leishmaniasis.
#
# Distance to mean: 2.843352794647217
# Title: Determination of the cytokine profile in American cutaneous leishmaniasis using the polymerase chain reaction.
#
# Distance to mean: 2.8502957820892334
# Title: Successful treatment of antimony-resistant visceral leishmaniasis with liposomal amphotericin B in patients infected with human immunodeficiency virus.
#
# Distance to mean: 2.9511232376098633
# Title: Isolation and characterization of a repetitive DNA sequence from Leishmania infantum: development of a visceral leishmaniasis polymerase chain reaction.
#
# Year: 1994
#
# Distance to mean: 2.5499467849731445
# Title: Cutaneous leishmaniasis in Kenya: Sergentomyia garnhami (Diptera Psychodidae), a possible vector of Leishmania major in Kitui District: a new focus of the disease.
#
# Distance to mean: 2.807502031326294
# Title: Antileishmanial activity of a tetralone isolated from Ampelocera edentula, a Bolivian plant used as a treatment for cutaneous leishmaniasis.
#
# Distance to mean: 2.818737268447876
# Title: Serial study of the immune response of an individual with exacerbated simple cutaneous leishmaniasis.
#
# Distance to mean: 2.854896068572998
# Title: Relapse in Ethiopian visceral leishmaniasis (VL) patients after therapy with pentavalent antimonials: a ten year observation.
#
# Distance to mean: 2.9108505249023438
# Title: Identification of a 94-kilodalton antigen on Leishmania promastigote forms and its specific recognition in human and canine visceral leishmaniasis.
#
# Year: 1995
#
# Distance to mean: 2.630746841430664
# Title: Experimental immunization against cutaneous leishmaniasis using Leishmania major subcellular fractions alone or in combination with Phlebotomus duboscqi gut antigens.
#
# Distance to mean: 2.7189109325408936
# Title: Dichotomy of the T cell response to Leishmania antigens in patients suffering from cutaneous leishmaniasis; absence or scarcity of Th1 activity is associated with severe infections.
#
# Distance to mean: 2.7698004245758057
# Title: Short report: detection of 72-75-kD and 123-kD fractions of Leishmania antigen in urine of patients with visceral leishmaniasis.
#
# Distance to mean: 2.8287739753723145
# Title: Atypical cutaneous histological features of visceral leishmaniasis in acquired immunodeficiency syndrome.
#
# Distance to mean: 2.8418877124786377
# Title: Isolation of Leishmania (L.) mexicana from wild rodents and their possible role in the transmission of localized cutaneous leishmaniasis in the state of Campeche, Mexico.
#
# Year: 1996
#
# Distance to mean: 2.7802181243896484
# Title: Visceral leishmaniasis emerging as an important opportunistic infection in HIV-infected persons living in areas nonendemic for Leishmania donovani.
#
# Distance to mean: 2.882740020751953
# Title: [Diffuse cutaneous leishmaniasis and acquired immunodeficiency syndrome in a Senegalese patient].
#
# Distance to mean: 2.8900229930877686
# Title: Reactivity of various leishmanial antigens in a direct agglutination test and their value in differentiating post-kala azar dermal leishmaniasis from leprosy and other skin conditions.
#
# Distance to mean: 2.9430084228515625
# Title: Chronic lupoid leishmaniasis. Evaluation by polymerase chain reaction.
#
# Distance to mean: 2.974376678466797
# Title: Therapy of visceral leishmaniasis due to Leishmania infantum: experimental assessment of efficacy of AmBisome.
#
# Year: 1997
#
# Distance to mean: 2.479210138320923
# Title: Short report: Leishmania tropica: etiologic agent of a case of canine visceral leishmaniasis in northern Morocco.
#
# Distance to mean: 2.4904258251190186
# Title: Experimental cutaneous leishmaniasis. IV. The humoral response of Cebus apella (Primates: Cebidae) to infections of Leishmania (Leishmania) amazonensis, L. (Viannia) lainsoni and L. (V.) braziliensis using the direct agglutination test.
#
# Distance to mean: 2.6901192665100098
# Title: Vector-host-parasite inter-relationships in leishmaniasis. III. Impact of blood meal from natural vertebrate hosts on the survival and the development of Leishmania infantum and L. major in Phlebotomus langeroni (Diptera: Psychodidae).
#
# Distance to mean: 2.757988691329956
# Title: In vitro and in vivo resistance of Leishmania infantum to meglumine antimoniate: a study of 37 strains collected from patients with visceral leishmaniasis.
#
# Distance to mean: 2.7763490676879883
# Title: Vector-host-parasite inter-relationships in leishmaniasis. II. Influence of blood meal from natural vertebrate hosts with and without Leishmania infantum and L. major on the proteolytic activity in the gut of Phlebotomus langeroni (Diptera: Psychodidae).
#
# Year: 1998
#
# Distance to mean: 2.1802399158477783
# Title: American cutaneous leishmaniasis due to Leishmania (Viannia) guyanensis as an initial clinical presentation of human immunodeficiency virus infection.
#
# Distance to mean: 2.599869966506958
# Title: Cohort study on canine emigration and Leishmania infection in an endemic area for American visceral leishmaniasis. Implications for the disease control.
#
# Distance to mean: 2.6073853969573975
# Title: Cutaneous scars in American tegumentary leishmaniasis patients: a site of Leishmania (Viannia) braziliensis persistence and viability eleven years after antimonial therapy and clinical cure.
#
# Distance to mean: 2.608398914337158
# Title: Visceral leishmaniasis (Kala-azar) in two patients with HIV-1 infection: atypical features and response to therapy.
#
# Distance to mean: 2.630031108856201
# Title: A cloned antigen (recombinant K39) of Leishmania chagasi diagnostic for visceral leishmaniasis in human immunodeficiency virus type 1 patients and a prognostic indicator for monitoring patients undergoing drug therapy.
#
# Year: 1999
#
# Distance to mean: 2.6593844890594482
# Title: Analysis of the humoral immune response against total and recombinant antigens of Leishmania infantum: correlation with disease progression in canine experimental leishmaniasis.
#
# Distance to mean: 2.6766715049743652
# Title: High frequency of serious side effects from meglumine antimoniate given without an upper limit dose for the treatment of visceral leishmaniasis in human immunodeficiency virus type-1-infected patients.
#
# Distance to mean: 2.7290198802948
# Title: Characterization of the local and systemic immune responses in patients with cutaneous leishmaniasis due to Leishmania major.
#
# Distance to mean: 2.734236240386963
# Title: [Visceral leishmaniasis: a comparative study of patients with and without human immunodeficiency virus infection].
#
# Distance to mean: 2.770601511001587
# Title: Unusual cutaneous lesions in two patients with visceral leishmaniasis and HIV infection.
#
# Year: 2000
#
# Distance to mean: 2.660550117492676
# Title: The histological spectrum of visceral leishmaniasis caused by Leishmania infantum MON-1 in acquired immune deficiency syndrome.
#
# Distance to mean: 2.6810734272003174
# Title: Evidence for determining parasitic factors in addition to host genetics and immune status in the outcome of murine Leishmania infantum visceral leishmaniasis.
#
# Distance to mean: 2.707991361618042
# Title: Post-kala-azar dermal leishmaniasis during highly active antiretroviral therapy in an AIDS patient infected with Leishmania infantum.
#
# Distance to mean: 2.7144532203674316
# Title: A novel Leishmania infantum recombinant antigen which elicits interleukin 10 production by peripheral blood mononuclear cells of patients with visceral leishmaniasis.
#
# Distance to mean: 2.895183801651001
# Title: Sodium stibogluconate (Pentostam) potentiates oxidant production in murine visceral leishmaniasis and in human blood.
#
# Year: 2001
#
# Distance to mean: 2.5904924869537354
# Title: Comparison of cutaneous leishmaniasis due to Leishmania (Viannia) braziliensis and L. (V.) guyanensis in Brazil: clinical findings and diagnostic approach.
#
# Distance to mean: 2.5984444618225098
# Title: Phase 2 trial of WR6026, an orally administered 8-aminoquinoline, in the treatment of visceral leishmaniasis caused by Leishmania chagasi.
#
# Distance to mean: 2.6291863918304443
# Title: Simple form of clinical sample preservation and Leishmania DNA extraction from human lesions for diagnosis of American cutaneous leishmaniasis via polymerase chain reaction.
#
# Distance to mean: 2.6408777236938477
# Title: Flow cytometric determination of cellular sources and frequencies of key cytokine-producing lymphocytes directed against recombinant LACK and soluble Leishmania antigen in human cutaneous leishmaniasis.
#
# Distance to mean: 2.702387809753418
# Title: Short report: detection of Leishmania DNA by polymerase chain reaction on blood samples from dogs with visceral leishmaniasis.
#
# Year: 2002
#
# Distance to mean: 2.5450263023376465
# Title: An outbreak of cutaneous leishmaniasis among soldiers in Belém, Pará State, Brazil, caused by Leishmania (Viannia) lindenbergi n. sp. A new leishmanial parasite of man in the Amazon region.
#
# Distance to mean: 2.6597533226013184
# Title: Cutaneous leishmaniasis in Sanliurfa: epidemiologic and clinical features of the last four years (1997-2000).
#
# Distance to mean: 2.706200122833252
# Title: Validation of the polymerase chain reaction for the diagnosis of human cutaneous leishmaniasis in north-west Colombia.
#
# Distance to mean: 2.7710766792297363
# Title: The high sensitivity of a PCR-ELISA in the diagnosis of cutaneous and visceral leishmaniasis caused by Leishmania infantum.
#
# Distance to mean: 2.772611379623413
# Title: Noninvasive management of Indian visceral leishmaniasis: clinical application of diagnosis by K39 antigen strip testing at a kala-azar referral unit.
#
# Year: 2003
#
# Distance to mean: 2.5553557872772217
# Title: Visceral leishmaniasis with concomittant post kala-azar dermal leishmaniasis responds to oral sitamaquine: case report.
#
# Distance to mean: 2.609407901763916
# Title: Human cutaneous leishmaniasis due to Leishmania infantum in the Sidi Bourouis focus (Northern Tunisia): epidemiological study and isoenzymatic characterization of the parasites.
#
# Distance to mean: 2.682217836380005
# Title: Quick detection of Leishmania in peripheral blood by flow cytometry. Is prestorage leucodepletion necessary for leishmaniasis prevention in endemic areas?
#
# Distance to mean: 2.7732388973236084
# Title: Parasite detection in patients with post kala-azar dermal leishmaniasis in India: a comparison between molecular and immunological methods.
#
# Distance to mean: 2.7956125736236572
# Title: High frequency of skin reactions in patients with leishmaniasis treated with meglumine antimoniate contaminated with heavy metals: a comparative approach using historical controls.
#
# Year: 2004
#
# Distance to mean: 2.408073902130127
# Title: Therapy of Venezuelan patients with severe mucocutaneous or early lesions of diffuse cutaneous leishmaniasis with a vaccine containing pasteurized Leishmania promastigotes and bacillus Calmette-Guerin: preliminary report.
#
# Distance to mean: 2.5297248363494873
# Title: Leishmania donovani is the only cause of visceral leishmaniasis in East Africa; previous descriptions of L. infantum and "L. archibaldi" from this region are a consequence of convergent evolution in the isoenzyme data.
#
# Distance to mean: 2.5570640563964844
# Title: Microscopy and polymerase chain reaction detection of Leishmania chagasi in the pleural and ascitic fluid of a patient with AIDS: Case report and review of diagnosis and therapy of visceral leishmaniasis.
#
# Distance to mean: 2.648615837097168
# Title: Identification of 9-O-acetylated sialoglycans on peripheral blood mononuclear cells in Indian Visceral Leishmaniasis.
#
# Distance to mean: 2.6654202938079834
# Title: An emerging peri-urban pattern of infection with Leishmania chagasi, the protozoan causing visceral leishmaniasis in northeast Brazil.
#
# Year: 2005
#
# Distance to mean: 2.3373093605041504
# Title: Localized cutaneous leishmaniasis due to Leishmania donovani and Leishmania tropica: preliminary findings of the study of 161 new cases from a new endemic focus in himachal pradesh, India.
#
# Distance to mean: 2.516293525695801
# Title: Kinetoplastid membrane protein-11 DNA vaccination induces complete protection against both pentavalent antimonial-sensitive and -resistant strains of Leishmania donovani that correlates with inducible nitric oxide synthase activity and IL-4 generation: evidence for mixed Th1- and Th2-like responses in visceral leishmaniasis.
#
# Distance to mean: 2.5407681465148926
# Title: Toward a novel experimental model of infection to study American cutaneous leishmaniasis caused by Leishmania braziliensis.
#
# Distance to mean: 2.590419292449951
# Title: T cell subset and cytokine profiles in human visceral leishmaniasis during active and asymptomatic or sub-clinical infection with Leishmania donovani.
#
# Distance to mean: 2.632150411605835
# Title: The burden of the Leishmania chagasi/infantum infection in a closed rural focus of visceral leishmaniasis in Lara state, west-central Venezuela.
#
# Year: 2006
#
# Distance to mean: 2.379533052444458
# Title: Successful treatment of post-kala-azar dermal leishmaniasis (PKDL) in a HIV infected patient with multiple relapsing leishmaniasis from Western Europe.
#
# Distance to mean: 2.5495107173919678
# Title: Visceral leishmaniasis, or kala azar (KA): high incidence of refractoriness to antimony is contributed by anthroponotic transmission via post-KA dermal leishmaniasis.
#
# Distance to mean: 2.5655441284179688
# Title: [Cellular immune response of patients with anthroponotic cutaneous leishmaniasis in Sanliurfa].
#
# Distance to mean: 2.6580593585968018
# Title: Sero-epidemological survey on canine visceral leishmaniasis and the distribution of sandfly vectors in northwestern Turkey: prevention strategies for childhood visceral leishmaniasis.
#
# Distance to mean: 2.660902976989746
# Title: Efficacy of vaccination with a combination of Leishmania amastigote antigens and the lipid A-analogue ONO-4007 for immunoprophylaxis and immunotherapy against Leishmania amazonensis infection in a murine model of New World cutaneous leishmaniasis.
#
# Year: 2007
#
# Distance to mean: 2.3617937564849854
# Title: Testing of four Leishmania vaccine candidates in a mouse model of infection with Leishmania (Viannia) braziliensis, the main causative agent of cutaneous leishmaniasis in the New World.
#
# Distance to mean: 2.50506329536438
# Title: Detection of anti-leishmania (Leishmania) chagasi immunoglobulin G by flow cytometry for cure assessment following chemotherapeutic treatment of American visceral leishmaniasis.
#
# Distance to mean: 2.5650951862335205
# Title: IL-10- and TGF-beta-mediated susceptibility in kala-azar and post-kala-azar dermal leishmaniasis: the significance of amphotericin B in the control of Leishmania donovani infection in India.
#
# Distance to mean: 2.626164674758911
# Title: Optimization of topical therapy for Leishmania major localized cutaneous leishmaniasis using a reliable C57BL/6 Model.
#
# Distance to mean: 2.634127616882324
# Title: Glucantime-resistant Leishmania tropica isolated from Iranian patients with cutaneous leishmaniasis are sensitive to alternative antileishmania drugs.
#
# Year: 2008
#
# Distance to mean: 2.4153075218200684
# Title: Clinical presentation and renal evaluation of human visceral leishmaniasis (kala-azar): a retrospective study of 57 patients in Brazil.
#
# Distance to mean: 2.484935760498047
# Title: Two Leishmania species circulating in the Kaleybar focus of infantile visceral leishmaniasis, northwest Iran: implications for deltamethrin dog collar intervention.
#
# Distance to mean: 2.590381622314453
# Title: Clinical features of cutaneous and disseminated cutaneous leishmaniasis caused by Leishmania (Viannia) braziliensis in Paraty, Rio de Janeiro.
#
# Distance to mean: 2.7084767818450928
# Title: Varicella zoster virus--specific immune response after treatment with sodium stibogluconate for cutaneous leishmaniasis.
#
# Distance to mean: 2.7090861797332764
# Title: [Cutaneous leishmaniasis due to Leishmania major involving the bone marrow in an AIDS patient in Burkina Faso].
#
# Year: 2009
#
# Distance to mean: 2.3122217655181885
# Title: T-cell-derived cytokines, nitric oxide production by peripheral blood monocytes and seric anti-Leishmania (Leishmania) chagasi IgG subclass patterns following immunization against canine visceral leishmaniasis using Leishvaccine and Leishmune.
#
# Distance to mean: 2.5307745933532715
# Title: Anti-fixed Leishmania chagasi promastigotes IgG antibodies detected by flow cytometry (FC-AFPA-IgG) as a tool for serodiagnosis and for post-therapeutic cure assessment in American visceral leishmaniasis.
#
# Distance to mean: 2.5847859382629395
# Title: Cellular and humoral responses to Leishmania major virulence factors in healed cutaneous leishmaniasis and Mediterranean visceral leishmaniasis patients.
#
# Distance to mean: 2.606826066970825
# Title: Leishmania (Viannia) braziliensis genotypes identified in lesions of patients with atypical or typical manifestations of tegumentary leishmaniasis: evaluation by two molecular markers.
#
# Distance to mean: 2.6744558811187744
# Title: Severe adverse reactions to meglumine antimoniate in the treatment of visceral leishmaniasis: a report of 13 cases in the southwestern region of Brazil.
#
# Year: 2010
#
# Distance to mean: 2.516702175140381
# Title: A clinical isolate of Leishmania donovani with ITS1 sequence polymorphism as a cause of para-kala-azar dermal leishmaniasis in an Ethiopian human immunodeficiency virus-positive patient on highly active antiretroviral therapy.
#
# Distance to mean: 2.5978920459747314
# Title: The use of remote sensing in the identification of the eco-environmental factors associated with the risk of human visceral leishmaniasis (kala-azar) on the Gangetic plain, in north-eastern India.
#
# Distance to mean: 2.626291513442993
# Title: A canine leishmaniasis pilot survey in an emerging focus of visceral leishmaniasis: Posadas (Misiones, Argentina).
#
# Distance to mean: 2.696538209915161
# Title: Evaluation of localized and systemic immune responses in cutaneous leishmaniasis caused by Leishmania tropica: interleukin-8, monocyte chemotactic protein-1 and nitric oxide are major regulatory factors.
#
# Distance to mean: 2.7091755867004395
# Title: Treatment of visceral leishmaniasis with intravenous pentamidine and oral fluconazole in an HIV-positive patient with chronic renal failure--a case report and brief review of the literature.
#
# Year: 2011
#
# Distance to mean: 2.0189368724823
# Title: Disseminated cutaneous leishmaniasis resembling post-kala-azar dermal leishmaniasis caused by Leishmania donovani in three patients co-infected with visceral leishmaniasis and human immunodeficiency virus/acquired immunodeficiency syndrome in Ethiopia.
#
# Distance to mean: 2.3573784828186035
# Title: Case report: Successful treatment of cutaneous leishmaniasis caused by Leishmania aethiopica with liposomal amphothericin B in an immunocompromised traveler returning from Eritrea.
#
# Distance to mean: 2.3759968280792236
# Title: Randomized controlled clinical trial to access efficacy and safety of miltefosine in the treatment of cutaneous leishmaniasis Caused by Leishmania (Viannia) guyanensis in Manaus, Brazil.
#
# Distance to mean: 2.4123566150665283
# Title: Atypical lesions as a sign of cutaneous dissemination of visceral leishmaniasis in a human immunodeficiency virus-positive patient simultaneously infected by two viscerotropic Leishmania species.
#
# Distance to mean: 2.5014774799346924
# Title: First detection of Leishmania killicki (Kinetoplastida, Trypanosomatidae) in Ctenodactylus gundi (Rodentia, Ctenodactylidae), a possible reservoir of human cutaneous leishmaniasis in Tunisia.
#
# Year: 2012
#
# Distance to mean: 2.269911050796509
# Title: Temporal distribution of positive results of tests for detecting Leishmania infection in stray dogs of an endemic area of visceral leishmaniasis in the Brazilian tropics: a 13 years survey and association with human disease.
#
# Distance to mean: 2.2724499702453613
# Title: Consecutive cutaneous and visceral leishmaniasis manifestations involving a novel Leishmania species in two HIV patients in Thailand.
#
# Distance to mean: 2.458136796951294
# Title: Evaluation of anti-lived and anti-fixed Leishmania (Viannia) braziliensis promastigote IgG antibodies detected by flow cytometry for diagnosis and post-therapeutic cure assessment in localized cutaneous leishmaniasis.
#
# Distance to mean: 2.480541944503784
# Title: First molecular detection of Leishmania major within naturally infected Phlebotomus salehi from a zoonotic cutaneous leishmaniasis focus in southern Iran.
#
# Distance to mean: 2.4875669479370117
# Title: High frequency of asymptomatic Leishmania spp. infection among HIV-infected patients living in endemic areas for visceral leishmaniasis in Brazil.
#
# Year: 2013
#
# Distance to mean: 2.2676801681518555
# Title: Cutaneous and post kala-azar dermal leishmaniasis caused by Leishmania infantum in endemic areas of visceral leishmaniasis, northwestern Iran 2002-2011: a case series.
#
# Distance to mean: 2.267690658569336
# Title: Nested polymerase chain reaction and sequence- based detection of leishmania infection of sand flies in recently emerged endemic focus of zoonotic cutaneous leishmaniasis, southern iran.
#
# Distance to mean: 2.370818614959717
# Title: Evaluation of PCR procedures for detecting and quantifying Leishmania donovani DNA in large numbers of dried human blood samples from a visceral leishmaniasis focus in Northern Ethiopia.
#
# Distance to mean: 2.4484996795654297
# Title: Molecular diagnosis of canine visceral leishmaniasis: a comparative study of three methods using skin and spleen from dogs with natural Leishmania infantum infection.
#
# Distance to mean: 2.4621379375457764
# Title: Comparison of flow cytometry and indirect immunofluorescence assay in the diagnosis and cure criterion after therapy of American tegumentary leishmaniasis by anti-live Leishmania (Viannia) braziliensis immunoglobulin G.
#
# Year: 2014
#
# Distance to mean: 2.46770977973938
# Title: Preclinical diagnosis of American visceral leishmaniasis during early onset of human Leishmania (L.) infantum chagasi-infection.
#
# Distance to mean: 2.4895401000976562
# Title: High visceral leishmaniasis mortality rate in Barra Mansa, a new area of visceral leishmaniasis transmission in the State of Rio de Janeiro, Brazil.
#
# Distance to mean: 2.547689199447632
# Title: Comparison of immune regulatory factors in acute and chronic lesions of cutaneous leishmaniasis due to Leishmania major.
#
# Distance to mean: 2.5893232822418213
# Title: Post Kala-Azar dermal leishmaniasis following treatment with 20 mg/kg liposomal amphotericin B (Ambisome) for primary visceral leishmaniasis in Bihar, India.
#
# Distance to mean: 2.605311393737793
# Title: The lost hope of elimination of Kala-azar (visceral leishmaniasis) by 2010 and cyclic occurrence of its outbreak in India, blame falls on vector control practices or co-infection with human immunodeficiency virus or therapeutic modalities?
#
# Year: 2015
#
# Distance to mean: 2.467836618423462
# Title: Visceral leishmaniasis and immunocompromise as a risk factor for the development of visceral leishmaniasis: a changing pattern at the hospital for tropical diseases, london.
#
# Distance to mean: 2.4701833724975586
# Title: Identification and glycobiological characterization of circulating immune complexes in patients with visceral leishmaniasis and post kala azar dermal leishmaniasis.
#
# Distance to mean: 2.493861675262451
# Title: The shadows of a ghost: a survey of canine leishmaniasis in Presidente Prudente and its spatial dispersion in the western region of São Paulo state, an emerging focus of visceral leishmaniasis in Brazil.
#
# Distance to mean: 2.5252814292907715
# Title: Epidemiological changes in leishmaniasis in Spain according to hospitalization-based records, 1997-2011: raising awareness towards leishmaniasis in non-HIV patients.
#
# Distance to mean: 2.5365025997161865
# Title: Chronic generalized fibrotic skin lesions from disseminated leishmaniasis caused by Leishmania martiniquensis in two patients from northern Thailand infected with HIV.
#
# Year: 2016
#
# Distance to mean: 2.31081485748291
# Title: Leishmaniasis in Turkey: first clinical isolation of Leishmania major from 18 autochthonous cases of cutaneous leishmaniasis in four geographical regions.
#
# Distance to mean: 2.423342227935791
# Title: Study on the safety and efficacy of miltefosine for the treatment of children and adolescents with post-kala-azar dermal leishmaniasis in Bangladesh, and an association of serum vitamin E and exposure to arsenic with post-kala-azar dermal leishmaniasis: an open clinical trial and case-control study protocol.
#
# Distance to mean: 2.477945566177368
# Title: Molecular detection of infection homogeneity and impact of miltefosine treatment in a Syrian golden hamster model of Leishmania donovani and L. infantum visceral leishmaniasis.
#
# Distance to mean: 2.6087965965270996
# Title: Pediatric Cutaneous Leishmaniasis in an Endemic Region in Turkey: A Retrospective Analysis of 8786 Cases during 1998-2014.
#
# Distance to mean: 2.6128172874450684
# Title: The Potential Use of Forensic DNA Methods Applied to Sand Fly Blood Meal Analysis to Identify the Infection Reservoirs of Anthroponotic Visceral Leishmaniasis.
#
# Year: 2017
#
# Distance to mean: 2.336686849594116
# Title: First description of Leishmania (Viannia) infection in Evandromyia saulensis, Pressatia sp. and Trichophoromyia auraensis (Psychodidae: Phlebotominae) in a transmission area of cutaneous leishmaniasis in Acre state, Amazon Basin, Brazil.
#
# Distance to mean: 2.3425180912017822
# Title: Disseminated Autochthonous Dermal Leishmaniasis Caused by Leishmania siamensis (PCM2 Trang) in a Patient from Central Thailand Infected with Human Immunodeficiency Virus.
#
# Distance to mean: 2.4619481563568115
# Title: Genetic diversity of Leishmania donovani that causes cutaneous leishmaniasis in Sri Lanka: a cross sectional study with regional comparisons.
#
# Distance to mean: 2.466625452041626
# Title: Natural Leishmania (Viannia) infections of phlebotomines (Diptera: Psychodidae) indicate classical and alternative transmission cycles of American cutaneous leishmaniasis in the Guiana Shield, Brazil.
#
# Distance to mean: 2.4991374015808105
# Title: Coinfection of Leishmania guyanensis and Human Immunodeficiency Virus-Acquired Immune Deficiency Syndrome: Report of a Case of Disseminated Cutaneous Leishmaniasis in Ecuador.
#
# Year: 2018
#
# Distance to mean: 2.2120110988616943
# Title: Case Report: First Coinfection Report of Mixed Leishmania infantum/Leishmania major and Human Immunodeficiency Virus-Acquired Immune Deficiency Syndrome: Report of a Case of Disseminated Cutaneous Leishmaniasis in Iran.
#
# Distance to mean: 2.259697675704956
# Title: Case Report: Diffuse Cutaneous Leishmaniasis by Leishmania infantum in a Patient Undergoing Immunosuppressive Therapy: Risk Status in an Endemic Mediterranean Area.
#
# Distance to mean: 2.323331117630005
# Title: Assessment of the role of small mammals in the transmission cycle of tegumentary leishmaniasis and first report of natural infection with Leishmania braziliensis in two sigmodontines in northeastern Argentina.
#
# Distance to mean: 2.3629252910614014
# Title: Integrated Analysis Reveals That miR-193b, miR-671, and TREM-1 Correlate With a Good Response to Treatment of Human Localized Cutaneous Leishmaniasis Caused by Leishmania braziliensis.
#
# Distance to mean: 2.4412894248962402
# Title: High accuracy of an ELISA test based in a flagella antigen of Leishmania in serodiagnosis of canine visceral leishmaniasis with potential to improve the control measures in Brazil - A Phase II study.
#
# Year: 2019
#
# Distance to mean: 2.3600544929504395
# Title: Factors associated with Leishmania spp. infection in domestic dogs from an emerging area of high endemicity for visceral leishmaniasis in Central-Western Brazil.
#
# Distance to mean: 2.4846041202545166
# Title: Relationship between treatment regimens for visceral leishmaniasis and development of post-kala-azar dermal leishmaniasis and visceral leishmaniasis relapse: A cohort study from Bangladesh.
#
# Distance to mean: 2.4854066371917725
# Title: Expansion of urban cutaneous leishmaniasis into rural areas of southeastern Iran: Clinical, epidemiological and phylogenetic profiles explored using 7SL high resolution melting-PCR analysis.
#
# Distance to mean: 2.5612926483154297
# Title: American tegumentary leishmaniasis diagnosis using L. (V.) braziliensis fixed promastigotes: a comparative performance of serological tests and spontaneous cure identification.
#
# Distance to mean: 2.5626308917999268
# Title: Verification and monitoring of visceral leishmaniasis in hamsters caused by Leishmania infantum, using non-invasive approaches involving ultrasound imaging and blood gases.
#
# Year: 2020
#
# Distance to mean: 2.350170850753784
# Title: Surveillance for Leishmania asymptomatic infection in endemic foci of cutaneous leishmaniasis in Venezuela: a combination of leishmanin skin test and PCR using blood clots improves detection and enables identification of species.
#
# Distance to mean: 2.3979856967926025
# Title: Possible introduction of Leishmania tropica to urban areas determined by epidemiological and clinical profiles of patients with cutaneous leishmaniasis in Casablanca (Morocco).
#
# Distance to mean: 2.4337024688720703
# Title: Long-term incidence of relapse and post-kala-azar dermal leishmaniasis after three different visceral leishmaniasis treatment regimens in Bihar, India.
#
# Distance to mean: 2.434562921524048
# Title: Correction: High accuracy of an ELISA test based in a flagella antigen of Leishmania in serodiagnosis of canine visceral leishmaniasis with potential to improve the control measures in Brazil-A Phase II study.
#
# Distance to mean: 2.5753302574157715
# Title: Modelling the number of dermal lesions in anthroponotic cutaneous leishmaniasis and its associated factors in Herat province, western Afghanistan, during 2012-2013.

# %% [markdown]
# ### Quantify novelty of each year by the proportion of papers whose title embeddings are far from previous years' title embeddings

# %%
# threshold distance to consider a paper to be novel
CUTOFF_DISTANCE = 5

# %%
year = year_span[0]

titles_prev = titles[years == year]
title_vectors_prev = title_vectors[years == year]
years_prev = years[years == year]

counts = []

for year in year_span[1:]:
    titles_curr = titles[years == year]
    title_vectors_curr = title_vectors[years == year]
    years_curr = years[years == year]
    
    ds = []
    titles_r, years_r = [], []
    
    count = 0.0
    
    for (title_curr, title_vector_curr, year_curr) in zip(titles_curr, title_vectors_curr, years_curr):
        min_distance = np.inf
        title_min, title_vector_min, year_min = None, None, None
        title_rmin, title_vector_rmin, year_rmin = None, None, None
        for (title_prev, title_vector_prev, year_prev) in zip(titles_prev, title_vectors_prev, years_prev):
            if dist(title_vector_curr, title_vector_prev) < min_distance:
                min_distance = dist(title_vector_curr, title_vector_prev)
                title_min, title_vector_min, year_min = title_curr, title_vector_curr, year_curr
                title_rmin, title_vector_rmin, year_rmin = title_prev, title_vector_prev, year_prev
                
        ds.append(min_distance)
        titles_r.append(title_rmin)
        years_r.append(year_rmin)
        
        if min_distance > CUTOFF_DISTANCE:
            count += 1
                
    ds_sorted, titles_r_sorted, years_r_sorted, titles_curr_sorted = zip(*sorted(zip(ds, titles_r, years_r, titles_curr), key=lambda x: -x[0]))
                                    
    titles_prev = np.concatenate((titles_prev, titles_curr))
    title_vectors_prev = np.concatenate((title_vectors_prev, title_vectors_curr))
    years_prev = np.concatenate((years_prev, years_curr))
    
    counts.append(count / len(years_curr))

# %%
plt.figure(figsize=(20, 10))
plt.scatter(year_span[1:], counts, color='b', s=100)
plt.plot(year_span[1:], counts, color='b')
plt.title(f'Semantic Distance Novelty for {term} from Titles')
plt.xlabel('Year')
plt.ylabel('Proportion of Novel Papers')
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Identify clusters of novel research based on paper titles

# %%
# identify research papers published between year CHANGEPOINT and CHANGEPOINT + DELTA,  such that
# (the mean distance between the paper title and its K nearest neighbors published before CHANGEPOINT)
# is at least RATIO_THRESHOLD times (the mean distance between the paper title and its K nearest neighbors
# also published between CHANGEPOINT and CHANGEPOINT + DELTA)
CHANGEPOINT = 2000
K = 3
DELTA = 5
RATIO_THRESHOLD = 1.2

# %%
titles_old, title_vectors_old, years_old = [], [], []
titles_new, title_vectors_new, years_new = [], [], []

for title, title_vector, year in zip(titles, title_vectors, years):
    if year < CHANGEPOINT:
        titles_old.append(title)
        title_vectors_old.append(title_vector)
        years_old.append(year)
    if year >= CHANGEPOINT and year <= CHANGEPOINT + DELTA:
        titles_new.append(title)
        title_vectors_new.append(title_vector)
        years_new.append(year)
            
for title, title_vector, year in zip(titles_new, title_vectors_new, years_new):
    new_distance = np.mean(sorted([dist(title_vector, t_v) for t_v in title_vectors_new])[1:][:K])
    old_distance = np.mean(sorted([dist(title_vector, t_v) for t_v in title_vectors_old])[:K])
    
    if (old_distance / new_distance) > RATIO_THRESHOLD:
        print(f'Year: {year}')
        print(f'Ratio: {old_distance / new_distance}')
        print(f'New Distance: {new_distance}')
        print(f'Old Distance: {old_distance}')
        print(f'Title: {title}')
        print()
# Out:
# Year: 2005
# Ratio: 2.2108054161071777
# New Distance: 1.1306124925613403
# Old Distance: 2.4995641708374023
# Title: Treatment of visceral leishmaniasis.
#
# Year: 2005
# Ratio: 1.2080265283584595
# New Distance: 2.6508445739746094
# Old Distance: 3.2022905349731445
# Title: Detection of leishmanial antigen in the urine of patients with visceral leishmaniasis by a latex agglutination test.
#
# Year: 2004
# Ratio: 1.72792649269104
# New Distance: 2.6492650508880615
# Old Distance: 4.577735424041748
# Title: Leishmaniasis: current status of vaccine development.
#
# Year: 2004
# Ratio: 1.2048912048339844
# New Distance: 3.7147538661956787
# Old Distance: 4.475874423980713
# Title: Hemophagocytic syndrome associated with visceral leishmaniasis.
#
# Year: 2004
# Ratio: 1.3206886053085327
# New Distance: 3.4018657207489014
# Old Distance: 4.492805480957031
# Title: Rapid immunochromatographic test for serodiagnosis of canine leishmaniasis.
#
# Year: 2004
# Ratio: 1.3489985466003418
# New Distance: 2.5197248458862305
# Old Distance: 3.3991050720214844
# Title: Comparative study of the efficacy of combined cryotherapy and intralesional meglumine antimoniate (Glucantime) vs. cryotherapy and intralesional meglumine antimoniate (Glucantime) alone for the treatment of cutaneous leishmaniasis.
#
# Year: 2004
# Ratio: 1.2323880195617676
# New Distance: 2.9960391521453857
# Old Distance: 3.6922826766967773
# Title: Two cases of visceral leishmaniasis in U.S. military personnel--Afghanistan, 2002-2004.
#
# Year: 2004
# Ratio: 1.4869492053985596
# New Distance: 2.428386688232422
# Old Distance: 3.6108875274658203
# Title: Update: Cutaneous leishmaniasis in U.S. military personnel--Southwest/Central Asia, 2002-2004.
#
# Year: 2004
# Ratio: 1.251300573348999
# New Distance: 2.3261210918426514
# Old Distance: 2.9106767177581787
# Title: Frequency of visceral leishmaniasis relapses in human immunodeficiency virus-infected patients receiving highly active antiretroviral therapy.
#
# Year: 2003
# Ratio: 1.2281882762908936
# New Distance: 2.7829511165618896
# Old Distance: 3.4179880619049072
# Title: Post kala-azar dermal leishmaniasis (PKDL): a first case report from Nepal.
#
# Year: 2003
# Ratio: 1.2633005380630493
# New Distance: 2.8987178802490234
# Old Distance: 3.661951780319214
# Title: The impact of highly active antiretroviral therapy (HAART) on visceral leishmaniasis in Spanish patients who are co-infected with HIV.
#
# Year: 2003
# Ratio: 1.4615002870559692
# New Distance: 2.537379264831543
# Old Distance: 3.7083804607391357
# Title: Cutaneous leishmaniasis in U.S. military personnel--Southwest/Central Asia, 2002-2003.
#
# Year: 2003
# Ratio: 1.475026249885559
# New Distance: 2.640306234359741
# Old Distance: 3.8945209980010986
# Title: Post-kala-azar dermal leishmaniasis associated with AIDS.
#
# Year: 2003
# Ratio: 1.3710765838623047
# New Distance: 2.02431583404541
# Old Distance: 2.775491952896118
# Title: Effect of highly active antiretroviral therapy on the incidence and clinical manifestations of visceral leishmaniasis in human immunodeficiency virus-infected patients.
#
# Year: 2003
# Ratio: 1.2614402770996094
# New Distance: 3.00225830078125
# Old Distance: 3.7871696949005127
# Title: Post-kala-azar dermal leishmaniasis (PKDL): the first case report from Nepal.
#
# Year: 2003
# Ratio: 1.3797014951705933
# New Distance: 2.4700634479522705
# Old Distance: 3.4079501628875732
# Title: The efficacy of treatment with intralesional meglumine antimoniate alone, compared with that of cryotherapy combined with the meglumine antimoniate or intralesional sodium stibogluconate, in the treatment of cutaneous leishmaniasis.
# /Users/dddp/Documents/TemporalLandscape/env_TemporalLandscape/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in float_scalars
# /Users/dddp/Documents/TemporalLandscape/env_TemporalLandscape/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: divide by zero encountered in float_scalars
# Year: 2003
# Ratio: inf
# New Distance: 0.0
# Old Distance: 1.9820643663406372
# Title: [Cutaneous leishmaniasis].
#
# Year: 2003
# Ratio: 1.2018169164657593
# New Distance: 2.741901159286499
# Old Distance: 3.2952632904052734
# Title: Protection in dogs against visceral leishmaniasis caused by Leishmania infantum is achieved by immunization with a heterologous prime-boost regime using DNA and vaccinia recombinant vectors expressing LACK.
#
# Year: 2002
# Ratio: 1.2145012617111206
# New Distance: 2.8250057697296143
# Old Distance: 3.4309730529785156
# Title: Influence of meteorological parameters on the clinical presentation of cutaneous leishmaniasis in French Guiana and on the efficacy of pentamidine treatment of the disease.
#
# Year: 2002
# Ratio: 1.475026249885559
# New Distance: 2.640306234359741
# Old Distance: 3.8945209980010986
# Title: Post-kala-azar dermal leishmaniasis associated with AIDS.
#
# Year: 2002
# Ratio: 1.6932628154754639
# New Distance: 2.084824323654175
# Old Distance: 3.5301554203033447
# Title: Diagnosis of visceral leishmaniasis: comparative potential of amastigote antigen, recombinant antigen and PCR.
#
# Year: 2002
# Ratio: 1.2875969409942627
# New Distance: 4.069018840789795
# Old Distance: 5.239256381988525
# Title: [Hemophagocytic lymphohistiocytosis as a manifestation of visceral leishmaniasis].
#
# Year: 2002
# Ratio: 1.271743655204773
# New Distance: 2.1019811630249023
# Old Distance: 2.6731812953948975
# Title: Impact of highly active antiretroviral therapy on the incidence of visceral leishmaniasis in a French cohort of patients infected with human immunodeficiency virus.
#
# Year: 2002
# Ratio: 1.201352834701538
# New Distance: 2.35115122795105
# Old Distance: 2.8245620727539062
# Title: Seasonality of Lutzomyia intermedia and Lutzomyia whitmani (Diptera: Psychodidae: Phlebotominae), occurring sympatrically in area of cutaneous leishmaniasis in the State of Rio de Janeiro, Brazil.
#
# Year: 2002
# Ratio: 1.2272207736968994
# New Distance: 3.444251298904419
# Old Distance: 4.226856708526611
# Title: Hemophagocytic syndrome as the presenting manifestation of visceral leishmaniasis.
#
# Year: 2002
# Ratio: 1.3199938535690308
# New Distance: 2.668729066848755
# Old Distance: 3.5227060317993164
# Title: Evaluating the efficacy of allopurinol and meglumine antimoniate (Glucantime) in the treatment of cutaneous leishmaniasis.
#
# Year: 2002
# Ratio: 1.2331938743591309
# New Distance: 2.535022020339966
# Old Distance: 3.126173734664917
# Title: A heterologous prime-boost regime using DNA and recombinant vaccinia virus expressing the Leishmania infantum P36/LACK antigen protects BALB/c mice from cutaneous leishmaniasis.
#
# Year: 2001
# Ratio: 2.2108054161071777
# New Distance: 1.1306124925613403
# Old Distance: 2.4995641708374023
# Title: Treatment of visceral leishmaniasis.
#
# Year: 2002
# Ratio: 1.6932628154754639
# New Distance: 2.084824323654175
# Old Distance: 3.5301554203033447
# Title: Diagnosis of visceral leishmaniasis: comparative potential of amastigote antigen, recombinant antigen and PCR.
#
# Year: 2001
# Ratio: 2.2108054161071777
# New Distance: 1.1306124925613403
# Old Distance: 2.4995641708374023
# Title: [Treatment of visceral leishmaniasis].
#
# Year: 2001
# Ratio: 1.2766929864883423
# New Distance: 2.5762054920196533
# Old Distance: 3.2890233993530273
# Title: Protective immune response against cutaneous leishmaniasis by prime/booster immunization regimens with vaccinia virus recombinants expressing Leishmania infantum p36/LACK and IL-12 in combination with purified p36.
#
# Year: 2001
# Ratio: 1.3480758666992188
# New Distance: 4.262521743774414
# Old Distance: 5.74620246887207
# Title: Leishmaniasis in Sudan. Visceral leishmaniasis.
#
# Year: 2001
# Ratio: 1.5699833631515503
# New Distance: 4.243565082550049
# Old Distance: 6.662326335906982
# Title: Leishmaniasis in Sudan. Mucosal leishmaniasis.
#
# Year: 2001
# Ratio: 1.4000470638275146
# New Distance: 4.245053768157959
# Old Distance: 5.943274974822998
# Title: Leishmaniasis in Sudan. Cutaneous leishmaniasis.
#
# Year: 2001
# Ratio: 1.72792649269104
# New Distance: 2.6492650508880615
# Old Distance: 4.577735424041748
# Title: Leishmaniasis: current status of vaccine development.
#
# Year: 2001
# Ratio: 1.2512197494506836
# New Distance: 2.4300239086151123
# Old Distance: 3.040493965148926
# Title: Influence of highly active antiretroviral therapy on the outcome of subclinical visceral leishmaniasis in human immunodeficiency virus-infected patients.
#
# Year: 2001
# Ratio: 1.2957825660705566
# New Distance: 2.613633155822754
# Old Distance: 3.386700391769409
# Title: Latex agglutination test for the detection of urinary antigens in visceral leishmaniasis.
#
# Year: 2000
# Ratio: 1.251168131828308
# New Distance: 2.3966314792633057
# Old Distance: 2.998588800430298
# Title: Prospective evaluation and follow-up of European patients with visceral leishmaniasis and HIV-1 coinfection in the era of highly active antiretroviral therapy.
#
# Year: 2000
# Ratio: inf
# New Distance: 0.0
# Old Distance: 1.9820643663406372
# Title: Cutaneous leishmaniasis.
#
# Year: 2000
# Ratio: inf
# New Distance: 0.0
# Old Distance: 1.9820643663406372
# Title: [Cutaneous leishmaniasis].
#
# Year: 2000
# Ratio: inf
# New Distance: 0.0
# Old Distance: 1.9820643663406372
# Title: Cutaneous leishmaniasis.
#
# Year: 2000
# Ratio: 1.2168891429901123
# New Distance: 3.0956056118011475
# Old Distance: 3.7670090198516846
# Title: [Infantile visceral leishmaniasis from Leishmania infantum MON-24: a reality in Tunisia].

# %% [markdown]
# ### Create differential wordclouds for paper titles

# %%
# creates a differential wordcloud for words appearing in year2, vs all words appearing before or during year1
def create_wordcloud(year1, year2):
    freqs_prev = np.sum(v[years <= year1], axis=0) / np.sum(years <= year1)
    freqs_new = np.sum(v[years == year2], axis=0) / np.sum(years == year2)

    diffs = np.subtract(freqs_prev, freqs_new)

    pos_features, neg_features = set(), set()

    d = {}
    for diff, feature in zip(diffs, features_unsorted):
        if feature in stop_words:
            continue

        diff = round(diff * 1000)
        if diff > 0:
            d[feature] = diff
            pos_features.add(feature)
        if diff < 0:
            neg_features.add(feature) 
            d[feature] = -diff

    def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
        if word in pos_features:
            return "rgb(0, 0, 0)"
        if word in neg_features:
            return "rgb(256, 0, 0)"

    wordcloud = WordCloud(background_color='white', height=500, width=1000)
    wordcloud.generate_from_frequencies(frequencies=d)
    plt.figure(figsize=(20, 10))
    plt.imshow(wordcloud.recolor(color_func=color_func, random_state=3),
               interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(1999, 2000)

# %% [markdown]
# ### Abstract length vs time

# %%
lengths = np.array([len(abstract) for abstract in abstracts])
average_lengths = [np.mean(lengths[years == year]) for year in year_span]
stdev_lengths = [np.std(lengths[years == year]) for year in year_span]

plt.figure(figsize=(20, 10))
plt.scatter(year_span, average_lengths, color='b', s=100)
plt.plot(year_span, average_lengths, color='b')
plt.errorbar(year_span, average_lengths, yerr=stdev_lengths, fmt='none', color='b', capsize=20)
plt.title(f'Weekly Abstract Length for {term}')
plt.xlabel('Year')
plt.ylabel('Abstract Length (characters)')
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Abstract entropies vs time

# %%
vectorizer = CountVectorizer()
v = vectorizer.fit_transform(abstracts).toarray()
frequencies_unsorted = np.sum(v, axis=0)
features_unsorted = vectorizer.get_feature_names()
features, frequencies = zip(*sorted(zip(features_unsorted, frequencies_unsorted), key=lambda f: -f[1]))

probabilities = []

for year in year_span:
    t = v[years == year]
    probabilities.append(np.sum(t, axis=0) / np.sum(np.sum(t, axis=0)))

entropies = [-np.sum(np.multiply(probability, np.nan_to_num(np.log2(probability), neginf=0))) for probability in probabilities]

plt.figure(figsize=(20, 10))
plt.plot(year_span, entropies, color='b')
plt.scatter(year_span, entropies, color='b', s=100)
plt.title(f'Yearly Entropy of Abstracts for {term}')
plt.xlabel('Year')
plt.ylabel('Entropy of Abstracts')
plt.rc('font', size=20)
plt.show()
# Out:
# /Users/dddp/Documents/TemporalLandscape/env_TemporalLandscape/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log2
#   del sys.path[0]

# %% [markdown]
# ### Most common words in abstracts

# %%
num_plot = 40

# %%
frequencies_per_abstract = np.divide(frequencies, len(years))

frequencies_plot, features_plot = [], []
for frequency, feature in zip(frequencies_per_abstract, features):
    if feature not in stop_words:
        frequencies_plot.append(frequency)
        features_plot.append(feature)

fig = plt.figure(figsize=(20, 10))
plt.title(f'Word Frequencies in {term} Abstracts')
plt.xlabel('Word')
plt.ylabel('Frequency per Abstract')
plt.bar(range(num_plot), frequencies_plot[1:num_plot+1], color='b')
plt.xticks(range(num_plot), features_plot[1:num_plot+1])
plt.setp(plt.gca().get_xticklabels(), rotation=-90, size=30)
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Word frequency changepoint analysis in publication abstracts

# %%
# only consider words whose average abstract frequency is at least FREQUENCY_THRESHOLD
FREQUENCY_THRESHOLD = 0.05

# only consider words with a changepoint probability of at least PROBABILITY_THRESHOLD
PROBABILITY_THRESHOLD = 0.8

# %%
word_distributions = []
for year in year_span:
    t = v[years == year]
    word_distributions.append(np.sum(t, axis=0) / np.sum(years == year))
word_distributions = np.transpose(word_distributions)

for feature in features:
    if np.mean(word_distributions[features_unsorted.index(feature)]) < FREQUENCY_THRESHOLD:
        break
    
    data_unnormalized = word_distributions[features_unsorted.index(feature)]
    
    data = []
    for i, year in enumerate(year_span):
        if data_unnormalized[i] == 0:
            data.append(0)
        else:
            data.append(data_unnormalized[i] / np.max(data_unnormalized) * 100)
    data = np.array(data)
    
    Q, P, Pcp = offcd.offline_changepoint_detection(data, partial(offcd.const_prior, l=(len(data)+1)), offcd.gaussian_obs_log_likelihood, truncate=-40)
    probs = np.exp(Pcp).sum(0)
    
    if np.max(probs) < PROBABILITY_THRESHOLD:
        continue
    
    plt.figure(figsize=(20, 20))
    plt.subplot(211)
    plt.plot(year_span, word_distributions[features_unsorted.index(feature)], color='b')
    plt.scatter(year_span, word_distributions[features_unsorted.index(feature)], color='b', s=100)
    plt.title(f'Word Frequency Per Abstract for {term}: {feature}')
    plt.xlabel('Year')
    plt.ylabel('Frequency Per Abstract')
    plt.rc('font', size=20)
    
    plt.subplot(212)
    plt.title(f'Changepoint Analysis for {term}: {feature}')
    plt.xlabel('Year')
    plt.ylabel('Changepoint Probability')
    plt.plot(year_span[1:], probs, color='r')
    plt.scatter(year_span[1:], probs, color='r', s=100)
    plt.rc('font', size=20)
    plt.show()

# %% [markdown]
# ### Generate abstract vectors with BioSentVec

# %%
abstracts_processed = [preprocess_sentence(abstract) for abstract in abstracts]
abstract_vectors = model.embed_sentences(abstracts_processed)
abstracts_reduced = PCA(n_components=2).fit_transform(abstract_vectors)

plt.figure(figsize=(15, 10))
plt.scatter(abstracts_reduced.T[0], abstracts_reduced.T[1], c=years, cmap='plasma')
plt.title(f'{term} Abstract Embeddings')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.rc('font', size=20)
plt.colorbar().set_label('Year', rotation=90)
plt.show()

# %%
abstracts_span = np.array([np.mean(abstract_vectors[years == year], axis=0) for year in year_span])
abstracts_span_reduced = PCA(n_components=2).fit_transform(abstracts_span)

plt.figure(figsize=(15, 10))
plt.scatter(abstracts_span_reduced.T[0], abstracts_span_reduced.T[1], c=year_span, cmap='plasma', s=100)
plt.title(f'{term} Average Abstract Embeddings by Year')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar().set_label('Year', rotation=90)

plot_1 = abstracts_span_reduced[:-1]
plot_2 = abstracts_span_reduced[1:]
for i, p1 in enumerate(plot_1):
    p2 = plot_2[i]
    plt.plot([p1[0], p2[0]], [p1[1], p2[1]], color='gray')

plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Identify research trends by identifying the paper abstracts with embeddings closest to the mean for each year

# %%
# number of representative papers to list closest to the mean
NUMBER_OF_PAPERS = 5

# %%
for abstract_mean, year in zip(abstracts_span, year_span):
    abstracts_mod = abstracts[year == years]
    titles_mod = titles[year == years]
    abstract_vectors_mod = abstract_vectors[year == years]
    ds = [dist(abstract_mean, t_v) for t_v in abstract_vectors_mod]
    ds_sorted, abstracts_sorted, titles_sorted = zip(*sorted(zip(ds, abstracts_mod, titles_mod), key=lambda x: x[0]))
    print(f'Year: {year}')
    print()
    for i in range(NUMBER_OF_PAPERS):
        try:
            print(f'Distance to mean: {ds_sorted[i]}')
            print(f'Title: {titles_sorted[i]}')
            print()
        except:
            break
# Out:
# Year: 1983
#
# Distance to mean: 1.2799568176269531
# Title: Visceral spreading depletion of thymus-dependent regions and amyloidosis in mice and hamsters infected intradermally with Leishmania isolated from Sudanese cutaneous leishmaniasis.
#
# Distance to mean: 1.3222756385803223
# Title: Advantages of measuring changes in the number of viable parasites in murine models of experimental cutaneous leishmaniasis.
#
# Distance to mean: 1.326740026473999
# Title: An outbreak of cutaneous leishmaniasis in Guyana: epidemiology, clinical and laboratory aspects.
#
# Distance to mean: 1.3533622026443481
# Title: Late metastatic Leishmaniasis in the mouse. A model for mucocutaneous disease.
#
# Distance to mean: 1.354143500328064
# Title: The evolution of the lesion in cutaneous leishmaniasis.
#
# Year: 1984
#
# Distance to mean: 1.2629272937774658
# Title: Mechanisms of acquired immunity in leishmaniasis.
#
# Distance to mean: 1.338673710823059
# Title: Prophylactic immunization against experimental leishmaniasis. II. Further characterization of the protective immunity against fatal Leishmania tropica infection induced by irradiated promastigotes.
#
# Distance to mean: 1.3738389015197754
# Title: Observations on local heat treatment for cutaneous leishmaniasis.
#
# Distance to mean: 1.3863098621368408
# Title: Development of cellular immunity in cutaneous leishmaniasis due to Leishmania tropica.
#
# Distance to mean: 1.3940880298614502
# Title: Exacerbation of murine cutaneous leishmaniasis by adoptive transfer of parasite-specific helper T cell populations capable of mediating Leishmania major-specific delayed-type hypersensitivity.
#
# Year: 1985
#
# Distance to mean: 1.3253157138824463
# Title: Human cutaneous leishmaniasis acquired in Texas.
#
# Distance to mean: 1.384496808052063
# Title: American visceral leishmaniasis (kala-azar).
#
# Distance to mean: 1.3881287574768066
# Title: Epidemiologic study of visceral leishmaniasis in Honduras, 1975-1983.
#
# Distance to mean: 1.4148926734924316
# Title: Zoonotic cutaneous leishmaniasis in Saudi Arabia: lesions healing naturally in man followed by a second infection with the same zymodeme of Leishmania major.
#
# Distance to mean: 1.419049859046936
# Title: Keziot--a new endemic site of cutaneous leishmaniasis in Israel. An epidemiological and clinical study of a non-immune population entering an endemic area.
#
# Year: 1986
#
# Distance to mean: 1.2443981170654297
# Title: Mucosal leishmaniasis ("espundia" Escomel, 1911).
#
# Distance to mean: 1.3408021926879883
# Title: Evaluation of the micro enzyme-linked immunosorbent assay (ELISA) for antibodies in American visceral leishmaniasis: antigen selection for detection of infection-specific responses.
#
# Distance to mean: 1.3746585845947266
# Title: New perspectives on a subclinical form of visceral leishmaniasis.
#
# Distance to mean: 1.3874036073684692
# Title: Use of the enzyme-linked immunosorbent assay (ELISA) for detection of circulating antibodies to human leishmaniasis.
#
# Distance to mean: 1.5010346174240112
# Title: Topical treatment of cutaneous leishmaniasis.
#
# Year: 1987
#
# Distance to mean: 1.3344831466674805
# Title: Leishmania major: the suitability of East African nonhuman primates as animal models for cutaneous leishmaniasis.
#
# Distance to mean: 1.3961193561553955
# Title: Visceral leishmaniasis in immunocompromised hosts.
#
# Distance to mean: 1.4079207181930542
# Title: Immunomodulation of murine visceral leishmaniasis by administration of monoclonal anti-Ia antibodies: differential effects of anti-I-A vs. anti-I-E antibodies.
#
# Distance to mean: 1.4621541500091553
# Title: Cutaneous leishmaniasis. The defect in T cell influx in BALB/c mice.
#
# Distance to mean: 1.486569881439209
# Title: Vaccination against cutaneous leishmaniasis in a murine model. I. Induction of protective immunity with a soluble extract of promastigotes.
#
# Year: 1988
#
# Distance to mean: 1.3425099849700928
# Title: Pathophysiology of experimental leishmaniasis: the role of parasite physiology in the development of metastatic disease.
#
# Distance to mean: 1.3627142906188965
# Title: [Clinico-epidemiologic forms of cutaneous leishmaniasis in Tunisia].
#
# Distance to mean: 1.4028428792953491
# Title: Quantification of Leishmania-specific T cells in human American cutaneous leishmaniasis (Leishmania braziliensis braziliensis) by limiting dilution analysis.
#
# Distance to mean: 1.409680724143982
# Title: Dissemination in cutaneous leishmaniasis. II. Satellite papules and subcutaneous induration.
#
# Distance to mean: 1.4320813417434692
# Title: Vaccination and treatment trials against murine leishmaniasis with semi-purified Leishmania antigens.
#
# Year: 1989
#
# Distance to mean: 1.1988826990127563
# Title: Mucosal leishmaniasis in Brazil.
#
# Distance to mean: 1.3071458339691162
# Title: [Mucocutaneous leishmaniasis in Panama. Etiologic agent, epidemiologic and clinical aspects].
#
# Distance to mean: 1.3285428285598755
# Title: Epidemiology of visceral leishmaniasis in Colombia.
#
# Distance to mean: 1.3682267665863037
# Title: Cell-mediated immunity in localized cutaneous leishmaniasis patients before and after treatment with immunotherapy or chemotherapy.
#
# Distance to mean: 1.3937896490097046
# Title: [Epidemiology of cutaneous leishmaniasis in Bolivia. 1. Description of study zone and prevalence of the disease].
#
# Year: 1990
#
# Distance to mean: 1.1958638429641724
# Title: Visceral leishmaniasis in HIV infection and AIDS: clinical features and response to therapy.
#
# Distance to mean: 1.3694783449172974
# Title: Visceral leishmaniasis in patients infected with human immunodeficiency virus. Co-operative Group for the Study of Leishmaniasis in AIDS.
#
# Distance to mean: 1.3981815576553345
# Title: Treatment of visceral leishmaniasis with pentavalent antimony and interferon gamma.
#
# Distance to mean: 1.4437553882598877
# Title: Elevated cerebroside antibody levels in human visceral and cutaneous leishmaniasis, Trypanosoma rangeli infection, and chronic Chagas' disease.
#
# Distance to mean: 1.4468932151794434
# Title: Immunization of susceptible hosts with a soluble antigen fraction from Leishmania major leads to aggravation of murine leishmaniasis mediated by CD4+ T cells.
#
# Year: 1991
#
# Distance to mean: 1.1442116498947144
# Title: A killing disease epidemic among displaced Sudanese population identified as visceral leishmaniasis.
#
# Distance to mean: 1.1853939294815063
# Title: A review of leishmaniasis in Ecuador.
#
# Distance to mean: 1.1980382204055786
# Title: Leishmania donovani chagasi: new clinical variant of cutaneous leishmaniasis in Honduras.
#
# Distance to mean: 1.2534294128417969
# Title: Leishmaniasis in Bahia, Brazil: evidence that Leishmania amazonensis produces a wide spectrum of clinical disease.
#
# Distance to mean: 1.357092261314392
# Title: Leishmaniasis in a domestic goat in Kenya.
#
# Year: 1992
#
# Distance to mean: 1.1566104888916016
# Title: Epidemiologic investigation of an outbreak of cutaneous leishmaniasis in a defined geographic focus of transmission.
#
# Distance to mean: 1.259842872619629
# Title: The Indian langur: preliminary report of a new nonhuman primate host for visceral leishmaniasis.
#
# Distance to mean: 1.2988723516464233
# Title: [Parasitological and immunological progress control during and after chemotherapy of canine leishmaniasis].
#
# Distance to mean: 1.3414760828018188
# Title: Visceral leishmaniasis in Africa.
#
# Distance to mean: 1.3523762226104736
# Title: [Visceral leishmaniasis in HIV infection. A totally opportunistic infection].
#
# Year: 1993
#
# Distance to mean: 1.3067368268966675
# Title: Development of in vitro parameters of cell-mediated immunity in the course of human cutaneous leishmaniasis infection.
#
# Distance to mean: 1.3207011222839355
# Title: Visceral leishmaniasis with a very-low degree of bone-marrow parasitemia, mimicking malignant histiocytosis.
#
# Distance to mean: 1.3301945924758911
# Title: [Cutaneous parasitism by Leishmania (Leishmania) chagasi during South American visceral leishmaniasis].
#
# Distance to mean: 1.3359607458114624
# Title: Diffuse cutaneous leishmaniasis in a cat.
#
# Distance to mean: 1.3443567752838135
# Title: Antigen-specific immunodeficiency and its relation to the spectrum of American cutaneous leishmaniasis.
#
# Year: 1994
#
# Distance to mean: 1.2842551469802856
# Title: [Visceral leishmaniasis in Italy. Its epidemiology, clinical picture and therapy].
#
# Distance to mean: 1.3026567697525024
# Title: Tumour necrosis factor (TNF-alpha) in zoonotic cutaneous leishmaniasis.
#
# Distance to mean: 1.33113431930542
# Title: Epidemiology and clinical manifestations of visceral and cutaneous leishmaniasis in Baringo District, Rift Valley, Kenya. A literature review.
#
# Distance to mean: 1.3428877592086792
# Title: Cytokines in the treatment of leishmaniasis: from studies of immunopathology to patient therapy.
#
# Distance to mean: 1.3603026866912842
# Title: Clinical and immunopathological aspects of disseminated cutaneous leishmaniasis.
#
# Year: 1995
#
# Distance to mean: 1.254367470741272
# Title: Cutaneous leishmaniasis in the Peruvian Andes: an epidemiological study of infection and immunity.
#
# Distance to mean: 1.2564082145690918
# Title: Diagnostic and prognostic value of K39 recombinant antigen in Indian leishmaniasis.
#
# Distance to mean: 1.2924822568893433
# Title: Characterization of a Leishmania tropica antigen that detects immune responses in Desert Storm viscerotropic leishmaniasis patients.
#
# Distance to mean: 1.3119614124298096
# Title: Serodiagnosis of leishmaniasis.
#
# Distance to mean: 1.325874924659729
# Title: Tumour necrosis factor-alpha (cachectin) in human visceral leishmaniasis.
#
# Year: 1996
#
# Distance to mean: 1.3060486316680908
# Title: Leishmania amazonensis: the Asian rhesus macaques (Macaca mulatta) as an experimental model for study of cutaneous leishmaniasis.
#
# Distance to mean: 1.3286482095718384
# Title: Leishmaniasis in Texas: epidemiology and clinical aspects of human cases.
#
# Distance to mean: 1.3332515954971313
# Title: Evaluation of the immune response in visceral leishmaniasis.
#
# Distance to mean: 1.3353581428527832
# Title: The pathology of cutaneous leishmaniasis in the Sudan: a comparison with that in other geographical areas.
#
# Distance to mean: 1.339697241783142
# Title: [Study of cases of leishmaniasis in the Province of Salta: evidences of mixed infection with Trypanosoma cruzi and Leishmania spp].
#
# Year: 1997
#
# Distance to mean: 1.160807490348816
# Title: Leishmaniasis in HIV-infected persons: a review.
#
# Distance to mean: 1.172377347946167
# Title: Visceral leishmaniasis from Bal'a, Palestine, caused by Leishmania donovani s.1. identified through polymerase chain reaction and restriction fragment length polymorphism analysis.
#
# Distance to mean: 1.1819987297058105
# Title: A low-dose antimony treatment in 159 patients with American cutaneous leishmaniasis: extensive follow-up studies (up to 10 years).
#
# Distance to mean: 1.2150214910507202
# Title: Current status of cutaneous leishmaniasis in Aleppo, Syrian Arab Republic.
#
# Distance to mean: 1.294766902923584
# Title: Treatment of cutaneous leishmaniasis with localized current field (radio frequency) in Tabasco, Mexico.
#
# Year: 1998
#
# Distance to mean: 1.2002522945404053
# Title: Serodiagnosis and epidemiology of visceral leishmaniasis in Turkey.
#
# Distance to mean: 1.2552807331085205
# Title: The re-emergence of American visceral leishmaniasis in an old focus in Venezuela: present situation of human and canine infections.
#
# Distance to mean: 1.2664384841918945
# Title: Geographic distribution and clinical description of leishmaniasis cases in Peru.
#
# Distance to mean: 1.3109499216079712
# Title: [Intestinal parasitic infections and leishmaniasis in patients with HIV infection].
#
# Distance to mean: 1.3140963315963745
# Title: Cohort study on canine emigration and Leishmania infection in an endemic area for American visceral leishmaniasis. Implications for the disease control.
#
# Year: 1999
#
# Distance to mean: 0.9511990547180176
# Title: Congenital transmission of visceral leishmaniasis (Kala Azar) from an asymptomatic mother to her child.
#
# Distance to mean: 1.145206093788147
# Title: Revival of tetracyclines--in the treatment of visceral leishmaniasis?
#
# Distance to mean: 1.22246253490448
# Title: Leishmaniasis.
#
# Distance to mean: 1.2266305685043335
# Title: Out-patient parenteral antimicrobial therapy--a viable option for the management of cutaneous leishmaniasis.
#
# Distance to mean: 1.2361857891082764
# Title: [Treatment of visceral leishmaniasis: recent modalities].
#
# Year: 2000
#
# Distance to mean: 1.291991949081421
# Title: Cutaneous leishmaniasis.
#
# Distance to mean: 1.2993682622909546
# Title: Post-kala-azar dermal leishmaniasis in the Sudan: clinical presentation and differential diagnosis.
#
# Distance to mean: 1.3267794847488403
# Title: [Childhood visceral leishmaniasis in Provence].
#
# Distance to mean: 1.3717275857925415
# Title: Kaposi's sarcoma-like lesions and other nodules as cutaneous involvement in AIDS-related visceral leishmaniasis.
#
# Distance to mean: 1.3776675462722778
# Title: Visceral leishmaniasis during childhood in southern Greece.
#
# Year: 2001
#
# Distance to mean: 0.7196840643882751
# Title: Leishmaniasis in Sudan. Visceral leishmaniasis.
#
# Distance to mean: 1.1088166236877441
# Title: Leishmaniasis in Sudan. Post kala-azar dermal leishmaniasis.
#
# Distance to mean: 1.241519570350647
# Title: Influence of clinical presentation on the efficacy of a short course of pentamidine in the treatment of cutaneous leishmaniasis in French Guiana.
#
# Distance to mean: 1.267104148864746
# Title: [A Pediatric case of lupoid leishmaniasis diagnosed by PCR].
#
# Distance to mean: 1.2729822397232056
# Title: Leishmaniasis in Sudan. Cutaneous leishmaniasis.
#
# Year: 2002
#
# Distance to mean: 1.0730645656585693
# Title: Leishmaniasis: recognition and management with a focus on the immunocompromised patient.
#
# Distance to mean: 1.1400548219680786
# Title: Parasitological and immunological follow-up of American tegumentary leishmaniasis patients.
#
# Distance to mean: 1.1469165086746216
# Title: Epidemiology of visceral leishmaniasis in Atbara River area, eastern Sudan: the outbreak of Barbar El Fugara village (1996-1997).
#
# Distance to mean: 1.1757885217666626
# Title: Diagnosis of leishmaniasis in Maltese dogs with the aid of the polymerase chain reaction.
#
# Distance to mean: 1.19339919090271
# Title: Epidemiology of visceral leishmaniasis in the Jenin District, West Bank: 1989-1998.
#
# Year: 2003
#
# Distance to mean: 1.1027647256851196
# Title: Post-kala-azar dermal leishmaniasis.
#
# Distance to mean: 1.157231092453003
# Title: Experience with New World cutaneous leishmaniasis in travelers.
#
# Distance to mean: 1.1666958332061768
# Title: [Visceral leishmaniasis].
#
# Distance to mean: 1.1892448663711548
# Title: A Therapeutic update on Cutaneous leishmaniasis.
#
# Distance to mean: 1.2811425924301147
# Title: Localized mucosal leishmaniasis due to Leishmania (Leishmania) infantum: clinical and microbiologic findings in 31 patients.
#
# Year: 2004
#
# Distance to mean: 0.9588840007781982
# Title: [Interpretation of laboratory data during cryptic leishmaniasis in dog].
#
# Distance to mean: 1.014028787612915
# Title: Leishmaniasis of the lip in a patient with Down's syndrome.
#
# Distance to mean: 1.0526399612426758
# Title: Challenges and new discoveries in the treatment of leishmaniasis.
#
# Distance to mean: 1.0721304416656494
# Title: [Parasite identification in the surveillance of imported leishmaniasis cases in Italy].
#
# Distance to mean: 1.1353070735931396
# Title: [Feline leishmaniasis: what's the epidemiological role of the cat?].
#
# Year: 2005
#
# Distance to mean: 1.0030968189239502
# Title: Localized cutaneous leishmaniasis due to Leishmania donovani and Leishmania tropica: preliminary findings of the study of 161 new cases from a new endemic focus in himachal pradesh, India.
#
# Distance to mean: 1.152328610420227
# Title: Further observations on clinical, histopathological, and immunological features of borderline disseminated cutaneous leishmaniasis caused by Leishmania (Leishmania) amazonensis.
#
# Distance to mean: 1.1596976518630981
# Title: Atypical multifocal cutaneous leishmaniasis in an immunocompetent patient treated by liposomal amphotericin B.
#
# Distance to mean: 1.1705644130706787
# Title: Protection against experimental visceral leishmaniasis infection in dogs immunized with purified excreted secreted antigens of Leishmania infantum promastigotes.
#
# Distance to mean: 1.2383016347885132
# Title: Eco-epidemiological survey of Leishmania (Viannia) braziliensis American cutaneous and mucocutaneous leishmaniasis in Ribeira Valley River, Paraná State, Brazil.
#
# Year: 2006
#
# Distance to mean: 1.073036789894104
# Title: New world cutaneous leishmaniasis in travellers.
#
# Distance to mean: 1.1192234754562378
# Title: Haematogenous dissemination of Leishmania (Viannia) braziliensis in human American tegumentary leishmaniasis.
#
# Distance to mean: 1.1779032945632935
# Title: Animal models for vaccine studies for visceral leishmaniasis.
#
# Distance to mean: 1.1893136501312256
# Title: [Oral miltefosine to treat leishmaniasis].
#
# Distance to mean: 1.2196846008300781
# Title: Visceral leishmaniasis (kala-azar)--the Bihar (India) perspective.
#
# Year: 2007
#
# Distance to mean: 1.0892837047576904
# Title: [Cutaneous leishmaniasis--an import from Belize].
#
# Distance to mean: 1.1830562353134155
# Title: [Demographic, clinical and therapeutic features of adult visceral leishmaniasis at the Rabta hospital in Tunis (tunisia) from 1983 to 2002].
#
# Distance to mean: 1.2141022682189941
# Title: Cutaneous leishmaniasis.
#
# Distance to mean: 1.2254319190979004
# Title: PCR identification of Leishmania in diagnosis and control of canine Leishmaniasis.
#
# Distance to mean: 1.2409642934799194
# Title: Cutaneous leishmaniasis: an emerging infection in a non-endemic area and a brief update.
#
# Year: 2008
#
# Distance to mean: 1.1585928201675415
# Title: Mucosal leishmaniasis . Current scenario and prospects for treatment.
#
# Distance to mean: 1.1705222129821777
# Title: [Three new cases of visceral leishmaniasis in Côte d'Ivoire].
#
# Distance to mean: 1.172340750694275
# Title: Nodular lymphangitic subcutaneous dissemination after intralesional antimonial treatment for localized cutaneous leishmaniasis.
#
# Distance to mean: 1.1728832721710205
# Title: Leishmaniasis.
#
# Distance to mean: 1.1779371500015259
# Title: Methods for diagnosis of canine leishmaniasis and immune response to infection.
#
# Year: 2009
#
# Distance to mean: 1.0841635465621948
# Title: Two cases of primary endonasal leishmaniasis in Sardinia (Italy).
#
# Distance to mean: 1.144800066947937
# Title: A new focus of cutaneous leishmaniasis in the central area of Paraná State, southern Brazil.
#
# Distance to mean: 1.2084282636642456
# Title: [Cultures on NNN medium for the diagnosis of leishmaniasis].
#
# Distance to mean: 1.2225193977355957
# Title: Alterations in phenotypic profiles of peripheral blood cells from patients with human American cutaneous leishmaniasis following treatment with an antimonial drug and a vaccine.
#
# Distance to mean: 1.2552984952926636
# Title: Cutaneous and mucocutaneous leishmaniasis in Tigray, northern Ethiopia: clinical aspects and therapeutic concerns.
#
# Year: 2010
#
# Distance to mean: 0.9603343605995178
# Title: [An adult case of visceral leishmaniasis in a province of Black-Sea region, Turkey].
#
# Distance to mean: 1.1535452604293823
# Title: Visceral leishmaniasis in children: a review.
#
# Distance to mean: 1.160703182220459
# Title: Clinical and epidemiological studies on the cutaneous leishmaniasis caused by Leishmania (Leishmania) donovani in Sri Lanka.
#
# Distance to mean: 1.1959775686264038
# Title: Experimental canine leishmaniasis: clinical, parasitological and serological follow-up.
#
# Distance to mean: 1.230139970779419
# Title: Biosensors for efficient diagnosis of leishmaniasis: innovations in bioanalytics for a neglected disease.
#
# Year: 2011
#
# Distance to mean: 1.1102259159088135
# Title: [Diagnosis and therapy of cutaneous and mucocutaneous Leishmaniasis in Germany].
#
# Distance to mean: 1.176876425743103
# Title: Atypical lesions as a sign of cutaneous dissemination of visceral leishmaniasis in a human immunodeficiency virus-positive patient simultaneously infected by two viscerotropic Leishmania species.
#
# Distance to mean: 1.1897140741348267
# Title: Vaccine candidates for leishmaniasis: a review.
#
# Distance to mean: 1.2335492372512817
# Title: [Visceral leishmaniasis: an update].
#
# Distance to mean: 1.257530689239502
# Title: [Therapy of leishmaniasis in France: consensus on proposed guidelines].
#
# Year: 2012
#
# Distance to mean: 1.099518895149231
# Title: Leishmaniasis: new insights from an old and neglected disease.
#
# Distance to mean: 1.1760668754577637
# Title: [Cutaneous leishmaniasis as travelers' disease. Clinical presentation, diagnostics and therapy].
#
# Distance to mean: 1.1829819679260254
# Title: [A case of cutaneous leishmaniasis caused by Leishmania infantum in a non-endemic province (Ankara) of Turkey].
#
# Distance to mean: 1.2552833557128906
# Title: Leishmaniasis in rheumatology, haematology and oncology: epidemiological, immunological and clinical aspects and caveats.
#
# Distance to mean: 1.2638158798217773
# Title: Cutaneous leishmaniasis in the Nalut District, Libyan Arab Jamahiriya: a clinico-epidemiologic study and Leishmania species identification.
#
# Year: 2013
#
# Distance to mean: 1.1594290733337402
# Title: [Evaluation of fourteen adult cases with visceral leishmaniasis].
#
# Distance to mean: 1.1747517585754395
# Title: Imported leishmaniasis in the Netherlands from 2005 to 2012: epidemiology, diagnostic techniques and sequence-based species typing from 195 patients.
#
# Distance to mean: 1.184008240699768
# Title: An atypical case of cutaneous leishmaniasis caused by Leishmania infantum in Portugal.
#
# Distance to mean: 1.1981315612792969
# Title: Evolution of Clinical Manifestations of Neck and Face due to Cutaneous Leishmaniasis Resulting In Diagnostic Errors.
#
# Distance to mean: 1.2026513814926147
# Title: Visceral leishmaniasis in Iran: Review of the Epidemiological and Clinical Features.
# Year: 2014
#
# Distance to mean: 1.057828426361084
# Title: Visceral leishmaniasis and HIV coinfection in Latin America.
#
# Distance to mean: 1.0701420307159424
# Title: New insights into the diagnosis and chemotheraphy for visceral leishmaniasis.
#
# Distance to mean: 1.1117219924926758
# Title: Immunotherapy and Immunochemotherapy in Visceral Leishmaniasis: Promising Treatments for this Neglected Disease.
#
# Distance to mean: 1.1219183206558228
# Title: Epidemiology of visceral leishmaniasis.
#
# Distance to mean: 1.123989224433899
# Title: Leishmaniasis in immunosuppressed individuals.
#
# Year: 2015
#
# Distance to mean: 1.0876562595367432
# Title: [Evaluation of clinical and laboratory findings of adult visceral leishmaniasis cases].
#
# Distance to mean: 1.0975266695022583
# Title: Cytokine Release Assays as Tests for Exposure to Leishmania, and for Confirming Cure from Leishmaniasis, in Solid Organ Transplant Recipients.
#
# Distance to mean: 1.1885664463043213
# Title: Cutaneous leishmaniasis caused by Leishmania donovani in the tribal population of the Agasthyamala Biosphere Reserve forest, Western Ghats, Kerala, India.
#
# Distance to mean: 1.1988072395324707
# Title: Genetic and clinical characterization of canine leishmaniasis caused by Leishmania (Leishmania) infantum in northeastern Argentina.
#
# Distance to mean: 1.1989277601242065
# Title: Atypical presentation in adults in the largest community outbreak of leishmaniasis in Europe (Fuenlabrada, Spain).
#
# Year: 2016
#
# Distance to mean: 1.036319375038147
# Title: Visceral leishmaniasis in immunocompromised: diagnostic and therapeutic approach and evaluation of the recently released IDSA guidelines.
#
# Distance to mean: 1.134128212928772
# Title: Evaluation of different diagnostic methods of American Cutaneous Leishmaniasis in the Brazilian Amazon.
#
# Distance to mean: 1.2046843767166138
# Title: Pediatric Visceral Leishmaniasis Caused by Leishmania infantum in Northern Cyprus.
#
# Distance to mean: 1.2161455154418945
# Title: Cutaneous Leishmaniasis in Khyber Pakhtunkhwa Province of Pakistan: Clinical Diversity and Species-Level Diagnosis.
#
# Distance to mean: 1.2194396257400513
# Title: Clinical and epidemiological features of leishmaniasis in northwestern-Argentina through a retrospective analysis of recent cases.
#
# Year: 2017
#
# Distance to mean: 1.1826262474060059
# Title: Atypical presentations of cutaneous leishmaniasis: A systematic review.
#
# Distance to mean: 1.1838093996047974
# Title: New epidemiological pattern of cutaneous leishmaniasis in two pre-Saharan arid provinces, southern Morocco.
#
# Distance to mean: 1.1949896812438965
# Title: Cutaneous Leishmaniasis in Saudi Arabia: A Comprehensive Overview.
#
# Distance to mean: 1.2242754697799683
# Title: An outbreak of cutaneous leishmaniasis in Modena province (Northern Italy): report of 35 cases.
#
# Distance to mean: 1.2303013801574707
# Title: American tegumentary leishmaniasis: epidemiological and molecular characterization of prevalent Leishmania species in the State of Tocantins, Brazil, 2011-2015.
#
# Year: 2018
#
# Distance to mean: 1.0557861328125
# Title: The Binomial Parasite-Host Immunity in the Healing Process and in Reactivation of Human Tegumentary Leishmaniasis.
#
# Distance to mean: 1.0718181133270264
# Title: Case Report: Diffuse Cutaneous Leishmaniasis by Leishmania infantum in a Patient Undergoing Immunosuppressive Therapy: Risk Status in an Endemic Mediterranean Area.
#
# Distance to mean: 1.0733461380004883
# Title: First report of an autochthonous human visceral leishmaniasis in a child from the South of Minas Gerais State, Brazil.
#
# Distance to mean: 1.0738352537155151
# Title: New antigens for the serological diagnosis of human visceral leishmaniasis identified by immunogenomic screening.
#
# Distance to mean: 1.110119342803955
# Title: IFN-γ Response Is Associated to Time Exposure Among Asymptomatic Immune Responders That Visited American Tegumentary Leishmaniasis Endemic Areas in Peru.
#
# Year: 2019
#
# Distance to mean: 1.1009708642959595
# Title: [Cutaneous leishmaniasis].
#
# Distance to mean: 1.1012241840362549
# Title: Cutaneous Leishmaniasis: The Complexity of Host's Effective Immune Response against a Polymorphic Parasitic Disease.
#
# Distance to mean: 1.1351230144500732
# Title: Cytokines: Key Determinants of Resistance or Disease Progression in Visceral Leishmaniasis: Opportunities for Novel Diagnostics and Immunotherapy.
#
# Distance to mean: 1.1624853610992432
# Title: A highly sensitive modified nested PCR to enhance case detection in leishmaniasis.
#
# Distance to mean: 1.1643165349960327
# Title: Current status and management of canine leishmaniasis in Latin America.
#
# Year: 2020
#
# Distance to mean: 1.118883490562439
# Title: Possible introduction of Leishmania tropica to urban areas determined by epidemiological and clinical profiles of patients with cutaneous leishmaniasis in Casablanca (Morocco).
#
# Distance to mean: 1.1219251155853271
# Title: First Report of an Urban Case of Canine Visceral Leishmaniasis in the Municipality of Cali, Colombia.
#
# Distance to mean: 1.178875207901001
# Title: Microscopic and molecular evidence in support of rodent as a reservoir for dissemination of Leishmaniasis.
#
# Distance to mean: 1.227308988571167
# Title: Prevalidation of an ELISA for Detection of a New Clinical Entity: Leishmania donovani-Induced Cutaneous Leishmaniasis.
#
# Distance to mean: 1.2568916082382202
# Title: Recent strategies for the development of oral medicines for the treatment of visceral leishmaniasis.

# %% [markdown]
# ### Quantify novelty of each year by the proportion of papers whose abstract embeddings are far from previous years' abstract embeddings

# %%
# threshold distance to consider a paper to be novel
CUTOFF_DISTANCE = 5

# %%
year = year_span[0]

abstracts_prev = abstracts[years == year]
abstract_vectors_prev = abstract_vectors[years == year]
abstracts_prev = years[years == year]

counts = []

for year in year_span[1:]:
    abstracts_curr = abstracts[years == year]
    abstract_vectors_curr = abstract_vectors[years == year]
    years_curr = years[years == year]
    
    ds = []
    abstracts_r, years_r = [], []
    
    count = 0.0
    
    for (abstract_curr, abstract_vector_curr, year_curr) in zip(abstracts_curr, abstract_vectors_curr, years_curr):
        min_distance = np.inf
        abstract_min, abstract_vector_min, year_min = None, None, None
        abstract_rmin, abstract_vector_rmin, year_rmin = None, None, None
        for (abstract_prev, abstract_vector_prev, year_prev) in zip(abstracts_prev, abstract_vectors_prev, years_prev):
            if dist(abstract_vector_curr, abstract_vector_prev) < min_distance:
                min_distance = dist(abstract_vector_curr, abstract_vector_prev)
                abstract_min, abstract_vector_min, year_min = abstract_curr, abstract_vector_curr, year_curr
                abstract_rmin, abstract_vector_rmin, year_rmin = abstract_prev, abstract_vector_prev, year_prev
                
        ds.append(min_distance)
        abstracts_r.append(abstract_rmin)
        years_r.append(year_rmin)
        
        if min_distance > CUTOFF_DISTANCE:
            count += 1
                
    ds_sorted, abstracts_r_sorted, years_r_sorted, abstracts_curr_sorted = zip(*sorted(zip(ds, abstracts_r, years_r, abstracts_curr), key=lambda x: -x[0]))
                                    
    abstracts_prev = np.concatenate((abstracts_prev, abstracts_curr))
    abstract_vectors_prev = np.concatenate((abstract_vectors_prev, abstract_vectors_curr))
    years_prev = np.concatenate((years_prev, years_curr))
    
    counts.append(count / len(years_curr))

# %%
plt.figure(figsize=(20, 10))
plt.scatter(year_span[1:], counts, color='b', s=100)
plt.plot(year_span[1:], counts, color='b')
plt.title(f'Semantic Distance Novelty for {term} from Abstracts')
plt.xlabel('Year')
plt.ylabel('Proportion of Novel Papers')
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Identify clusters of novel research based on paper abstracts

# %%
# identify research papers published between year CHANGEPOINT and CHANGEPOINT + DELTA,  such that
# (the mean distance between the paper abstract and its K nearest neighbors published before week CHANGEPOINT)
# is at least RATIO_THRESHOLD times (the mean distance between the paper abstract and its K nearest neighbors
# also published between CHANGEPOINT and CHANGEPOINT + DELTA)
CHANGEPOINT = 2000
K = 3
DELTA = 5
RATIO_THRESHOLD = 1.2

# %%
abstracts_old, abstract_vectors_old, years_old = [], [], []
abstracts_new, abstract_vectors_new, years_new, titles_new = [], [], [], []

for abstract, abstract_vector, year in zip(abstracts, abstract_vectors, years):
    if year < CHANGEPOINT:
        abstracts_old.append(abstract)
        abstract_vectors_old.append(abstract_vector)
        years_old.append(year)
    if year >= CHANGEPOINT and year <= CHANGEPOINT + DELTA:
        abstracts_new.append(abstract)
        abstract_vectors_new.append(abstract_vector)
        years_new.append(year)
        titles_new.append(title)
            
for abstract, abstract_vector, year, title in zip(abstracts_new, abstract_vectors_new, years_new, titles_new):
    new_distance = np.mean(sorted([dist(abstract_vector, t_v) for t_v in abstract_vectors_new])[1:][:K])
    old_distance = np.mean(sorted([dist(abstract_vector, t_v) for t_v in abstract_vectors_old])[:K])
    
    if (old_distance / new_distance) > RATIO_THRESHOLD:
        print(f'Year: {year}')
        print(f'Ratio: {old_distance / new_distance}')
        print(f'New Distance: {new_distance}')
        print(f'Old Distance: {old_distance}')
        print(f'Title: {title}')
        print()
# Out:
# Year: 2005
# Ratio: 1.2878309488296509
# New Distance: 1.3830299377441406
# Old Distance: 1.7811087369918823
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2005
# Ratio: 1.3614311218261719
# New Distance: 1.563545823097229
# Old Distance: 2.128659963607788
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2004
# Ratio: 1.301062822341919
# New Distance: 1.4852668046951294
# Old Distance: 1.9324254989624023
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2004
# Ratio: 1.3127388954162598
# New Distance: 1.3235324621200562
# Old Distance: 1.737452507019043
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2003
# Ratio: 1.2637732028961182
# New Distance: 1.336354374885559
# Old Distance: 1.688848853111267
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2003
# Ratio: 1.2016392946243286
# New Distance: 1.793919563293457
# Old Distance: 2.155644178390503
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2003
# Ratio: 1.2589073181152344
# New Distance: 1.3476428985595703
# Old Distance: 1.6965575218200684
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2003
# Ratio: 1.366385817527771
# New Distance: 1.4029537439346313
# Old Distance: 1.9169760942459106
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2003
# Ratio: 1.5218333005905151
# New Distance: 1.065343976020813
# Old Distance: 1.6212759017944336
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2003
# Ratio: 1.2439664602279663
# New Distance: 1.1193443536758423
# Old Distance: 1.39242684841156
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2003
# Ratio: 1.2039464712142944
# New Distance: 1.3175996541976929
# Old Distance: 1.5863194465637207
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2002
# Ratio: 1.5218333005905151
# New Distance: 1.065343976020813
# Old Distance: 1.6212759017944336
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2002
# Ratio: 1.5921928882598877
# New Distance: 1.1328951120376587
# Old Distance: 1.8037875890731812
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2003
# Ratio: 1.2628700733184814
# New Distance: 1.1602522134780884
# Old Distance: 1.4652477502822876
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2002
# Ratio: 1.2008737325668335
# New Distance: 1.2564698457717896
# Old Distance: 1.5088616609573364
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2002
# Ratio: 1.2716602087020874
# New Distance: 1.343222975730896
# Old Distance: 1.7081232070922852
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2001
# Ratio: 1.2040234804153442
# New Distance: 1.3454700708389282
# Old Distance: 1.619977593421936
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2002
# Ratio: 1.5921928882598877
# New Distance: 1.1328951120376587
# Old Distance: 1.8037875890731812
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2001
# Ratio: 1.2874096632003784
# New Distance: 1.1355773210525513
# Old Distance: 1.4619531631469727
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2001
# Ratio: 1.2257951498031616
# New Distance: 1.3995555639266968
# Old Distance: 1.7155684232711792
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2001
# Ratio: 1.2062580585479736
# New Distance: 1.2709242105484009
# Old Distance: 1.5330625772476196
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2000
# Ratio: 1.2454429864883423
# New Distance: 1.8149226903915405
# Old Distance: 2.260382652282715
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2001
# Ratio: 1.2374275922775269
# New Distance: 1.6233171224594116
# Old Distance: 2.008737325668335
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.
#
# Year: 2000
# Ratio: 1.2332406044006348
# New Distance: 1.4516159296035767
# Old Distance: 1.790191650390625
# Title: Roles of endogenous gamma interferon and macrophage microbicidal mechanisms in host response to chemotherapy in experimental visceral leishmaniasis.

# %% [markdown]
# ### Create differential wordclouds for paper abstracts

# %%
# creates a differential wordcloud for words appearing in year2, vs all words appearing before or during year1
def create_wordcloud(year1, year2):
    freqs_prev = np.sum(v[years <= year1], axis=0) / np.sum(years <= year1)
    freqs_new = np.sum(v[years == year2], axis=0) / np.sum(years == year2)

    diffs = np.subtract(freqs_prev, freqs_new)

    pos_features, neg_features = set(), set()

    d = {}
    for diff, feature in zip(diffs, features_unsorted):
        if feature in stop_words:
            continue

        diff = round(diff * 1000)
        if diff > 0:
            d[feature] = diff
            pos_features.add(feature)
        if diff < 0:
            neg_features.add(feature) 
            d[feature] = -diff

    def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
        if word in pos_features:
            return "rgb(0, 0, 0)"
        if word in neg_features:
            return "rgb(256, 0, 0)"

    wordcloud = WordCloud(background_color='white', height=500, width=1000)
    wordcloud.generate_from_frequencies(frequencies=d)
    plt.figure(figsize=(20, 10))
    plt.imshow(wordcloud.recolor(color_func=color_func, random_state=3),
               interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(1999, 2000)
