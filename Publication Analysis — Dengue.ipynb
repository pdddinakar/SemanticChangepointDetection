# %% [markdown]
# # Publication Analysis

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import necessary packages

# %%
import requests, lxml, sys, sent2vec, nltk, cProfile

import numpy as np
import matplotlib.pyplot as plt
import bayesian_changepoint_detection.offline_changepoint_detection as offcd

from sklearn.feature_extraction.text import CountVectorizer
from nltk import word_tokenize
from nltk.corpus import stopwords
from string import punctuation
from sklearn.decomposition import PCA
from functools import partial
from wordcloud import WordCloud
from bs4 import BeautifulSoup
# Out:
# Use scipy logsumexp().

# %% [markdown]
# ### Load models

# %%
nltk.download('stopwords')
nltk.download('punkt')

model_path = 'biosentvec.bin'
model = sent2vec.Sent2vecModel()
model.load_model(model_path)
# Out:
# [nltk_data] Downloading package stopwords to /Users/dddp/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/dddp/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Set constants

# %%
term = 'Dengue'

BASE_URL = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/'
MIN_PAPERS = 50 # minimum number of papers in a year to use for analysis
stop_words = set(stopwords.words('english'))

# %% [markdown]
# ### Define helper functions

# %%
# preprocesses text before BioSentVec embedding
def preprocess_sentence(text):
    text = text.replace('/', ' / ')
    text = text.replace('.-', ' .- ')
    text = text.replace('.', ' . ')
    text = text.replace('\'', ' \' ')
    text = text.lower()

    tokens = [token for token in word_tokenize(text) if token not in punctuation and token not in stop_words]

    return ' '.join(tokens)

# computes Euclidean distance
def dist(x, y):
    return np.linalg.norm(x - y)

# converts a list to a comma separated values format
def list_to_csv(lst):
    ret = ''
    for i, val in enumerate(lst):
        ret += f'{val},'
    return ret[:-1]

# returns the UIDs of papers based on searching the title for a query
def get_uids(query):
    uid_list = []

    retstart = 0
    RETMAX = 100000
    
    while True:
        params = {
            'db': 'pubmed',
            'term': f'{query}[title]',
            'retmax': RETMAX,
            'retstart': retstart,
        }
        res = requests.get(f'{BASE_URL}esearch.fcgi', params)
        soup = BeautifulSoup(res.text, 'xml')
        uids = soup.find_all('Id')
        num_uids = len(uids)
        if num_uids == 0:
            print(f'Found {len(uid_list)} UIDs corresponding to {query}.')
            return uid_list
        else:
            uid_list = uid_list + [uid.text for uid in uids]
            retstart += RETMAX
            
# returns the titles, abstracts, years, and year_span of publications corresponding to input UIDs          
def get_summaries(uids):
    titles = []
    abstracts = []
    years = []

    retstart = 0
    MAX_REQUEST = 10000 # number of uids to request at a time

    sys.stdout.write(f'\rRetrieved {retstart} / {len(uids)} titles.')
    sys.stdout.flush()

    while (retstart < len(uids)):
        query_uids = uids[retstart:retstart + MAX_REQUEST]
        params = {
        'db': 'pubmed',
        'id': list_to_csv(query_uids),
        'retmax': MAX_REQUEST,
        'retmode': 'xml',
        'rettyle': 'abstract,'
        }
        res = requests.post(f'{BASE_URL}efetch.fcgi', params)
        soup = BeautifulSoup(res.text, 'xml')

        soup_articles = soup.find_all('PubmedArticle')

        for soup_article in soup_articles:
            soup_title = soup_article.find('ArticleTitle')
            soup_date = soup_article.find('PubDate')
            soup_abstract = soup_article.find('AbstractText')

            if soup_title is None or soup_date is None or soup_abstract is None or soup_date.find('Year') is None:
                continue

            titles.append(soup_title.text.replace('\xa0', ' ').replace('<i>', '').replace('</i>', ''))
            years.append(int(soup_date.find('Year').text))
            abstracts.append(soup_abstract.text)

        retstart += MAX_REQUEST

        sys.stdout.write(f'\rRetrieved {min(retstart, len(uids))} / {len(uids)} summaries.')
        sys.stdout.flush()

    titles, abstracts, years = np.array(titles), np.array(abstracts), np.array(years)
    
    titles = titles[~np.isnan(years)]
    abstracts = abstracts[~np.isnan(years)]
    years = years[~np.isnan(years)]
    
    titles_mod, abstracts_mod, years_mod = [], [], []
    
    for title, abstract, year in zip(titles, abstracts, years):
        if len(years[years == year]) >= MIN_PAPERS:
            titles_mod.append(title)
            abstracts_mod.append(abstract)
            years_mod.append(year)
            
    titles, abstracts, years = np.array(titles_mod), np.array(abstracts_mod), np.array(years_mod)
    
    year_span = np.unique(years)

    print(f'\nAfter filtering, retrieved {len(titles)} summaries.')
        
    return titles, abstracts, years, year_span

def get_titles_and_abstracts_and_years(term):
    return get_summaries(get_uids(term))

# %% [markdown]
# ### Load publication data from NCBI

# %%
titles, abstracts, years, year_span = get_titles_and_abstracts_and_years(term)
# Out:
# Found 15251 UIDs corresponding to Dengue.
# Retrieved 15251 / 15251 summaries.
# After filtering, retrieved 11528 summaries.

# %% [markdown]
# ## Publication Analysis

# %% [markdown]
# ### Number of publications vs time

# %%
num_papers = [np.sum(years == year) for year in year_span]

fig = plt.figure(figsize=(20, 10))
plt.title(f'{term} Papers Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Papers')
plt.plot(year_span, num_papers, color='b')
plt.scatter(year_span, num_papers, color='b', s=100)
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Title length vs time

# %%
lengths = np.array([len(title) for title in titles])
average_lengths = [np.mean(lengths[years == year]) for year in year_span]
stdev_lengths = [np.std(lengths[years == year]) for year in year_span]

plt.figure(figsize=(20, 10))
plt.scatter(year_span, average_lengths, color='b', s=100)
plt.plot(year_span, average_lengths, color='b')
plt.errorbar(year_span, average_lengths, yerr=stdev_lengths, fmt='none', color='b', capsize=20)
plt.title(f'Yearly Title Length for {term}')
plt.xlabel('Year')
plt.ylabel('Title Length (characters)')
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Title entropies vs time

# %%
vectorizer = CountVectorizer()
v = vectorizer.fit_transform(titles).toarray()
frequencies_unsorted = np.sum(v, axis=0)
features_unsorted = vectorizer.get_feature_names()
features, frequencies = zip(*sorted(zip(features_unsorted, frequencies_unsorted), key=lambda f: -f[1]))

probabilities = []

for year in year_span:
    t = v[years == year]
    probabilities.append(np.sum(t, axis=0) / np.sum(np.sum(t, axis=0)))

entropies = [-np.sum(np.multiply(probability, np.nan_to_num(np.log2(probability), neginf=0))) for probability in probabilities]

plt.figure(figsize=(20, 10))
plt.plot(year_span, entropies, color='b')
plt.scatter(year_span, entropies, color='b', s=100)
plt.title(f'Yearly Entropy of Titles for {term}')
plt.xlabel('Year')
plt.ylabel('Entropy of Titles')
plt.rc('font', size=20)
plt.show()
# Out:
# /Users/dddp/Documents/TemporalLandscape/env_TemporalLandscape/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log2
#   del sys.path[0]

# %% [markdown]
# ### Most common words in publication titles

# %%
num_plot = 40

# %%
frequencies_per_title = np.divide(frequencies, len(years))

frequencies_plot, features_plot = [], []
for frequency, feature in zip(frequencies_per_title, features):
    if feature not in stop_words:
        frequencies_plot.append(frequency)
        features_plot.append(feature)

fig = plt.figure(figsize=(20, 10))
plt.title(f'Word Frequencies in {term} Titles')
plt.xlabel('Word')
plt.ylabel('Frequency per Title')
plt.bar(range(num_plot), frequencies_plot[1:num_plot+1], color='b')
plt.xticks(range(num_plot), features_plot[1:num_plot+1])
plt.setp(plt.gca().get_xticklabels(), rotation=-90, size=30)
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Word frequency changepoint analysis in publication titles

# %%
# only consider words whose average title frequency is at least FREQUENCY_THRESHOLD
FREQUENCY_THRESHOLD = 0.05

# only consider words with a changepoint probability of at least PROBABILITY_THRESHOLD
PROBABILITY_THRESHOLD = 0.5

# %%
word_distributions = []
for year in year_span:
    t = v[years == year]
    word_distributions.append(np.sum(t, axis=0) / np.sum(years == year))
word_distributions = np.transpose(word_distributions)

for feature in features:
    if np.mean(word_distributions[features_unsorted.index(feature)]) < FREQUENCY_THRESHOLD:
        break
    
    data_unnormalized = word_distributions[features_unsorted.index(feature)]
    
    data = []
    for i, year in enumerate(year_span):
        if data_unnormalized[i] == 0:
            data.append(0)
        else:
            data.append(data_unnormalized[i] / np.max(data_unnormalized) * 100)
    data = np.array(data)
    
    Q, P, Pcp = offcd.offline_changepoint_detection(data, partial(offcd.const_prior, l=(len(data)+1)), offcd.gaussian_obs_log_likelihood, truncate=-40)
    probs = np.exp(Pcp).sum(0)
    
    if np.max(probs) < PROBABILITY_THRESHOLD:
        continue
    
    plt.figure(figsize=(20, 20))
    plt.subplot(211)
    plt.plot(year_span, word_distributions[features_unsorted.index(feature)], color='b')
    plt.scatter(year_span, word_distributions[features_unsorted.index(feature)], color='b', s=100)
    plt.title(f'Word Frequency Per Title for {term}: {feature}')
    plt.xlabel('Year')
    plt.ylabel('Frequency Per Title')
    plt.rc('font', size=20)
    
    plt.subplot(212)
    plt.title(f'Changepoint Analysis for {term}: {feature}')
    plt.xlabel('Year')
    plt.ylabel('Changepoint Probability')
    plt.plot(year_span[1:], probs, color='r')
    plt.scatter(year_span[1:], probs, color='r', s=100)
    plt.rc('font', size=20)
    plt.show()

# %% [markdown]
# ### Generate title vectors with BioSentVec

# %%
titles_processed = [preprocess_sentence(title) for title in titles]
title_vectors = model.embed_sentences(titles_processed)
titles_reduced = PCA(n_components=2).fit_transform(title_vectors)

plt.figure(figsize=(15, 10))
plt.scatter(titles_reduced.T[0], titles_reduced.T[1], c=years, cmap='plasma')
plt.title(f'{term} Title Embeddings')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.rc('font', size=20)
plt.colorbar().set_label('Year', rotation=90)
plt.show()

# %%
titles_span = np.array([np.mean(title_vectors[years == year], axis=0) for year in year_span])
titles_span_reduced = PCA(n_components=2).fit_transform(titles_span)

plt.figure(figsize=(15, 10))
plt.scatter(titles_span_reduced.T[0], titles_span_reduced.T[1], c=year_span, cmap='plasma', s=100)
plt.title(f'{term} Average Title Embeddings by Year')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar().set_label('Year', rotation=90)

plot_1 = titles_span_reduced[:-1]
plot_2 = titles_span_reduced[1:]
for i, p1 in enumerate(plot_1):
    p2 = plot_2[i]
    plt.plot([p1[0], p2[0]], [p1[1], p2[1]], color='gray')

plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Identify research trends by identifying the paper titles with embeddings closest to the mean for each year

# %%
# number of representative papers to list closest to the mean
NUMBER_OF_PAPERS = 5

# %%
for title_mean, year in zip(titles_span, year_span):
    titles_mod = titles[year == years]
    title_vectors_mod = title_vectors[year == years]
    ds = [dist(title_mean, t_v) for t_v in title_vectors_mod]
    ds_sorted, titles_sorted = zip(*sorted(zip(ds, titles_mod), key=lambda x: x[0]))
    print(f'Year: {year}')
    print()
    for i in range(NUMBER_OF_PAPERS):
        try:
            print(f'Distance to mean: {ds_sorted[i]}')
            print(f'Title: {titles_sorted[i]}')
            print()
        except:
            break
# Out:
# Year: 1987
#
# Distance to mean: 2.447877883911133
# Title: The status of dengue fever virus in South Africa--serological studies and diagnosis of a case of dengue fever.
#
# Distance to mean: 2.6162936687469482
# Title: Disease severity-related antigenic differences in dengue 2 strains detected by dengue 4 monoclonal antibodies.
#
# Distance to mean: 2.626601219177246
# Title: Study of the distribution of antibody-dependent enhancement determinants on dengue 2 isolates using dengue 2-derived monoclonal antibodies.
#
# Distance to mean: 2.706205368041992
# Title: Dengue 4 virus monoclonal antibodies identify epitopes that mediate immune infection enhancement of dengue 2 viruses.
#
# Distance to mean: 2.869065284729004
# Title: Multiplication and distribution of type 2 dengue and Japanese encephalitis viruses in Toxorhynchites splendens after intrathoracic inoculation.
#
# Year: 1989
#
# Distance to mean: 2.713618278503418
# Title: Antibody-dependent enhancement of dengue virus growth in human monocytes as a risk factor for dengue hemorrhagic fever.
#
# Distance to mean: 2.862138271331787
# Title: [MAC-ELISA for the detection of IgM antibodies to dengue type I virus (rapid diagnosis of dengue type I virus infection)].
#
# Distance to mean: 2.907768726348877
# Title: Mice immunized with recombinant vaccinia virus expressing dengue 4 virus structural proteins with or without nonstructural protein NS1 are protected against fatal dengue virus encephalitis.
#
# Distance to mean: 2.973297595977783
# Title: An enzyme-linked immunosorbent assay to characterize dengue infections where dengue and Japanese encephalitis co-circulate.
#
# Distance to mean: 3.0179991722106934
# Title: Dengue virus-specific human T cell clones. Serotype crossreactive proliferation, interferon gamma production, and cytotoxic activity.
#
# Year: 1990
#
# Distance to mean: 2.6531150341033936
# Title: The antigenic structure of dengue type 1 virus envelope and NS1 proteins expressed in Escherichia coli.
#
# Distance to mean: 2.7593116760253906
# Title: [Comparative study of dengue 2 virus replication and isoenzymes in two strains of Aedes aegypti].
#
# Distance to mean: 2.784459352493286
# Title: Variation among strains of Aedes aegypti in susceptibility to oral infection with dengue virus type 2.
#
# Distance to mean: 2.8200671672821045
# Title: Identification of dengue sequences by genomic amplification: rapid diagnosis of dengue virus serotypes in peripheral blood.
#
# Distance to mean: 2.9003055095672607
# Title: Dengue 3 virus infection of Aedes albopictus and Aedes aegypti: comparison of parent and progeny candidate vaccine viruses.
#
# Year: 1991
#
# Distance to mean: 2.240111827850342
# Title: Growth of dengue type 2 virus isolates in human peripheral blood leukocytes correlates with severe and mild dengue disease.
#
# Distance to mean: 2.468688488006592
# Title: Demonstration of concurrent dengue 1 and dengue 3 infection in six patients by the polymerase chain reaction.
#
# Distance to mean: 2.7940313816070557
# Title: Production of dimer-specific and dengue virus group cross-reactive mouse monoclonal antibodies to the dengue 2 virus non-structural glycoprotein NS1.
#
# Distance to mean: 2.8340089321136475
# Title: Potential use of a baculovirus-expressed dengue-4 E protein as a diagnostic antigen in regions endemic for dengue and Japanese encephalitis.
#
# Distance to mean: 2.8761820793151855
# Title: Partial sequence analysis of type 1 dengue virus coding for the nonstructural hydrophilic protein NS-3.
#
# Year: 1992
#
# Distance to mean: 2.308783769607544
# Title: Oral susceptibility of Aedes albopictus to dengue type 2 virus: a study of infection kinetics, using the polymerase chain reaction for viral detection.
#
# Distance to mean: 2.533289670944214
# Title: Epidemiology of dengue and dengue haemorrhagic fever in Malaysia. III. A comparative study of clinical features seen in virologically confirmed cases for periods between 1963-1987--a review.
#
# Distance to mean: 2.7787280082702637
# Title: Envelope protein sequences of dengue virus isolates TH-36 and TH-Sman, and identification of a type-specific genetic marker for dengue and tick-borne flaviviruses.
#
# Distance to mean: 2.8390390872955322
# Title: Direct sequence analysis of amplified dengue virus genomic RNA from cultured cells, mosquitoes and mouse brain.
#
# Distance to mean: 2.852501630783081
# Title: Human antibodies to dengue and yellow fever do not react in diagnostic assays for hepatitis C virus.
#
# Year: 1993
#
# Distance to mean: 2.1394882202148438
# Title: Molecular epidemiology of dengue 3 viruses and genetic relatedness among dengue 3 strains isolated from patients with mild or severe form of dengue fever in French Polynesia.
#
# Distance to mean: 2.531083345413208
# Title: Dengue virus-specific human CD4+ T-lymphocyte responses in a recipient of an experimental live-attenuated dengue virus type 1 vaccine: bulk culture proliferation, clonal analysis, and precursor frequency determination.
#
# Distance to mean: 2.64380145072937
# Title: [Application of reverse transcription-polymerase chain reaction in rapid diagnosis and serotype identification of dengue virus infections].
#
# Distance to mean: 2.8321359157562256
# Title: Ultra-rapid, simple, sensitive, and economical silica method for extraction of dengue viral RNA from clinical specimens and mosquitoes by reverse transcriptase-polymerase chain reaction.
#
# Distance to mean: 2.8861491680145264
# Title: Applications of polymerase chain reaction for identification of dengue viruses isolated from patient sera.
#
# Year: 1994
#
# Distance to mean: 2.3532299995422363
# Title: Rapid detection of virus genome from imported dengue fever and dengue hemorrhagic fever patients by direct polymerase chain reaction.
#
# Distance to mean: 2.422295570373535
# Title: Dengue fever virus and Japanese encephalitis virus synthetic peptides, with motifs to fit HLA class I haplotypes prevalent in human populations in endemic regions, can be used for application to skin Langerhans cells to prime antiviral CD8+ cytotoxic T cells (CTLs)--a novel approach to the protection of humans.
#
# Distance to mean: 2.616974353790283
# Title: Dengue virus-specific memory T cell responses in human volunteers receiving a live attenuated dengue virus type 2 candidate vaccine.
#
# Distance to mean: 2.6827735900878906
# Title: Molecular comparison of dengue type 1 Mochizuki strain virus and other selected viruses concerning nucleotide and amino acid sequences of genomic RNA: a consideration of viral epidemiology and variation.
#
# Distance to mean: 2.7341129779815674
# Title: The envelope glycoproteins of dengue 1 and dengue 2 viruses grown in mosquito cells differ in their utilization of potential glycosylation sites.
#
# Year: 1995
#
# Distance to mean: 2.5355584621429443
# Title: Mice immunized with a dengue type 2 virus E and NS1 fusion protein made in Escherichia coli are protected against lethal dengue virus infection.
#
# Distance to mean: 2.6851742267608643
# Title: Computer simulations to predict the availability of peptides with known HLA class I motifs generated by proteolysis of dengue fever virus (DFV) type 1 structural and nonstructural proteins in infected cells.
#
# Distance to mean: 2.7443907260894775
# Title: Murine immunoglobulin G subclass responses following immunization with live dengue virus or a recombinant dengue envelope protein.
#
# Distance to mean: 2.7686917781829834
# Title: Genotype determination of three dengue type 2 virus strains from Myanmar by sequencing E/NSI gene junction.
#
# Distance to mean: 2.773383855819702
# Title: Symptoms of dengue fever in relation to host immunologic response and virus serotype, Puerto Rico, 1990-1991.
#
# Year: 1996
#
# Distance to mean: 2.517158031463623
# Title: Primary sequence of the envelope glycoprotein of a dengue type 2 virus isolated from patient with dengue hemorrhagic fever and encephalopathy.
#
# Distance to mean: 2.895850419998169
# Title: Pathogen-derived resistance to dengue type 2 virus in mosquito cells by expression of the premembrane coding region of the viral genome.
#
# Distance to mean: 2.9347171783447266
# Title: [Genetic relatedness of the dengue 3 virus isolated in the outbreak of dengue hemorrhagic fever in Nicaragua, 1994].
#
# Distance to mean: 2.942441463470459
# Title: The 1986 dengue and dengue hemorrhagic fever epidemic in Puerto Rico: epidemiologic and clinical observations.
#
# Distance to mean: 2.976893186569214
# Title: [Aedes aegypti in French Guiana. Some aspects of history, general ecology and vertical transmission of the dengue virus].
#
# Year: 1997
#
# Distance to mean: 2.2941479682922363
# Title: Dengue hemorrhagic fever in Jakarta, Indonesia in 1988: isolation of dengue virus from patient whole blood using cell cultures.
#
# Distance to mean: 2.4164254665374756
# Title: Antibody responses of dengue fever patients to dengue 2 (New Guinea C strain) viral proteins.
#
# Distance to mean: 2.718125104904175
# Title: Comparison of sequences of E/NS1 gene junction of dengue type 3 virus following culture subpassage in C6/36 cells to study the possible occurrence of mutations.
#
# Distance to mean: 2.77903151512146
# Title: Comparison of various methods of detection of different forms of dengue virus type 2 RNA in cultured cells.
#
# Distance to mean: 2.7793526649475098
# Title: The dengue virus nonstructural-1 protein (NS1) generates antibodies to common epitopes on human blood clotting, integrin/adhesin proteins and binds to human endothelial cells: potential implications in haemorrhagic fever pathogenesis.
#
# Year: 1998
#
# Distance to mean: 2.4134681224823
# Title: [Detection of dengue virus genome RNA in some kinds of animals caught from dengue fever endemic areas in Hainan Island with reverse transcription-polymerase chain reaction].
#
# Distance to mean: 2.5709033012390137
# Title: Apoptotic cell death in response to dengue virus infection: the pathogenesis of dengue haemorrhagic fever revisited.
#
# Distance to mean: 2.5976736545562744
# Title: Changing clinical and biological manifestations of dengue during the dengue-2 epidemic in French Polynesia in 1996/97--description and analysis in a prospective study.
#
# Distance to mean: 2.7427427768707275
# Title: Possible dengue sequential infection: dengue spread in a neighbourhood during the 1996/97 dengue-2 epidemic in French Polynesia.
#
# Distance to mean: 2.7480595111846924
# Title: Apoptosis in the mouse central nervous system in response to infection with mouse-neurovirulent dengue viruses.
#
# Year: 1999
#
# Distance to mean: 2.4749338626861572
# Title: Comparison of PanBio dengue duo enzyme-linked immunosorbent assay (ELISA) and MRL dengue fever virus immunoglobulin M capture ELISA for diagnosis of dengue virus infections in Southeast Asia.
#
# Distance to mean: 2.5876083374023438
# Title: Production of viral antigens in culture fluid of C6/36 mosquito cell line infected with dengue type 4 virus strains isolated from patients with different clinical severities.
#
# Distance to mean: 2.6357498168945312
# Title: [Oral receptivity of Aedes aegypti formosus from Franceville (Gabon, central Africa) for type 2 dengue virus].
#
# Distance to mean: 2.731341600418091
# Title: Quantitation of T lymphocyte subsets helps to distinguish dengue hemorrhagic fever from classic dengue fever during the acute febrile stage.
#
# Distance to mean: 2.7815511226654053
# Title: Detection of dengue virus RNA in patients after primary or secondary dengue infection by using the TaqMan automated amplification system.
#
# Year: 2000
#
# Distance to mean: 2.0012996196746826
# Title: Isolation and partial characterization of dengue virus type 2 and 4 strains from dengue fever and dengue haemorrhagic fever patients from Mindanao, Republic of the Philippines.
#
# Distance to mean: 2.762247323989868
# Title: Immunization of rhesus monkeys with a recombinant of modified vaccinia virus Ankara expressing a truncated envelope glycoprotein of dengue type 2 virus induced resistance to dengue type 2 virus challenge.
#
# Distance to mean: 2.762906551361084
# Title: The use of direct sequencing of dengue virus cDNA from individual field-collected Aedes aegypti for surveillance and epidemiological studies.
#
# Distance to mean: 2.768606424331665
# Title: Determination of tumor necrosis factor-alpha levels in dengue virus infected patients by sensitive biotin-streptavidin enzyme-linked immunosorbent assay.
#
# Distance to mean: 2.8049299716949463
# Title: The risk of dengue hemorrhagic fever (DHF) outbreak based on vector density in Kurau, Riau province, Indonesia.
#
# Year: 2001
#
# Distance to mean: 2.6312286853790283
# Title: Electron microscopic study of persistent dengue virus infection: analysis using a cell line persistently infected with Dengue-2 virus.
#
# Distance to mean: 2.6615424156188965
# Title: Amino acid and phenotypic changes in dengue 2 virus associated with escape from neutralisation by IgM antibody.
#
# Distance to mean: 2.667536497116089
# Title: Detection of circulant tumor necrosis factor-alpha, soluble tumor necrosis factor p75 and interferon-gamma in Brazilian patients with dengue fever and dengue hemorrhagic fever.
#
# Distance to mean: 2.6925301551818848
# Title: Analysis of plasma viral RNA levels during acute dengue virus infection using quantitative competitor reverse transcription-polymerase chain reaction.
#
# Distance to mean: 2.704787492752075
# Title: Comparison of techniques for extracting viral RNA from isolation-negative serum for dengue diagnosis by the polymerase chain reaction.
#
# Year: 2002
#
# Distance to mean: 2.273308753967285
# Title: Detection of dengue virus replication in peripheral blood mononuclear cells from dengue virus type 2-infected patients by a reverse transcription-real-time PCR assay.
#
# Distance to mean: 2.282872438430786
# Title: Enzyme-linked immunosorbent assay specific to Dengue virus type 1 nonstructural protein NS1 reveals circulation of the antigen in the blood during the acute phase of disease in patients experiencing primary or secondary infections.
#
# Distance to mean: 2.4640841484069824
# Title: Potential application of nonstructural protein NS1 serotype-specific immunoglobulin G enzyme-linked immunosorbent assay in the seroepidemiologic study of dengue virus infection: correlation of results with those of the plaque reduction neutralization test.
#
# Distance to mean: 2.5358846187591553
# Title: Antigenic cell associated dengue 2 virus proteins detected in vitro using dengue fever patients sera.
#
# Distance to mean: 2.569598913192749
# Title: Epidemiology of inapparent and symptomatic acute dengue virus infection: a prospective study of primary school children in Kamphaeng Phet, Thailand.
#
# Year: 2003
#
# Distance to mean: 2.300034999847412
# Title: Comparative immunological recognition of proteins from New Guinea "C" dengue virus type 2 prototype and from a dengue virus type 2 strain isolated in the State of Rio de Janeiro, Brazil.
#
# Distance to mean: 2.5203449726104736
# Title: Dendritic-cell-specific ICAM3-grabbing non-integrin is essential for the productive infection of human dendritic cells by mosquito-cell-derived dengue viruses.
#
# Distance to mean: 2.5503761768341064
# Title: Blocking the dengue virus 2 infections on BHK-21 cells with purified recombinant dengue virus 2 E protein expressed in Escherichia coli.
#
# Distance to mean: 2.5977675914764404
# Title: [Laboratory diagnosis of dengue virus infections in Aragua State, Venezuela: October 1997-December 1998].
#
# Distance to mean: 2.607719898223877
# Title: Detection of immune-complex-dissociated nonstructural-1 antigen in patients with acute dengue virus infections.
#
# Year: 2004
#
# Distance to mean: 2.447535991668701
# Title: Markedly reduced severity of Dengue virus infection in mosquito cell cultures persistently infected with Aedes albopictus densovirus (AalDNV).
#
# Distance to mean: 2.6376125812530518
# Title: Analysis of recombinant dengue virus polypeptides for dengue diagnosis and evaluation of the humoral immune response.
#
# Distance to mean: 2.6727688312530518
# Title: Epitope determinants of a chimpanzee Fab antibody that efficiently cross-neutralizes dengue type 1 and type 2 viruses map to inside and in close proximity to fusion loop of the dengue type 2 virus envelope glycoprotein.
#
# Distance to mean: 2.699273109436035
# Title: Serotype-specific entry of dengue virus into liver cells: identification of the 37-kilodalton/67-kilodalton high-affinity laminin receptor as a dengue virus serotype 1 receptor.
#
# Distance to mean: 2.710874080657959
# Title: Dengue virus detection by using reverse transcription-polymerase chain reaction in saliva and progeny of experimentally infected Aedes albopictus from Brazil.
#
# Year: 2005
#
# Distance to mean: 2.3168551921844482
# Title: Genetic variations and relationship among dengue virus type 3 strains isolated from patients with mild or severe form of dengue disease in Indonesia and Thailand.
#
# Distance to mean: 2.372694969177246
# Title: Classical dengue hemorrhagic fever resulting from two dengue infections spaced 20 years or more apart: Havana, Dengue 3 epidemic, 2001-2002.
#
# Distance to mean: 2.515753746032715
# Title: An information value based analysis of physical and climatic factors affecting dengue fever and dengue haemorrhagic fever incidence.
#
# Distance to mean: 2.578521490097046
# Title: Comparison of clinical features and hematologic abnormalities between dengue fever and dengue hemorrhagic fever among children in the Philippines.
#
# Distance to mean: 2.615257978439331
# Title: Use of four dengue virus antigens for determination of dengue immune status by enzyme-linked immunosorbent assay of immunoglobulin G avidity.
#
# Year: 2006
#
# Distance to mean: 2.1589913368225098
# Title: Temporal distribution of dengue virus serotypes in Colombian endemic area and dengue incidence. Re-introduction of dengue-3 associated to mild febrile illness and primary infection.
#
# Distance to mean: 2.280695915222168
# Title: Dengue hemorrhagic Fever caused by sequential dengue 1-3 virus infections over a long time interval: Havana epidemic, 2001-2002.
#
# Distance to mean: 2.3270466327667236
# Title: Dengue virus infections in the first 2 years of life and the kinetics of transplacentally transferred dengue neutralizing antibodies in thai children.
#
# Distance to mean: 2.4836537837982178
# Title: Short report: immune response and occurrence of dengue infection in thai children three to eight years after vaccination with live attenuated tetravalent dengue vaccine.
#
# Distance to mean: 2.512699604034424
# Title: Dengue fever with papilledema: a case of dengue-3 virus infection in central nervous system.
#
# Year: 2007
#
# Distance to mean: 2.364452600479126
# Title: Prospective study to determine accuracy of rapid serological assays for diagnosis of acute dengue virus infection in Laos.
#
# Distance to mean: 2.498739719390869
# Title: A survey of dengue viral infection in Aedes aegypti and Aedes albopictus from re-epidemic areas in the north of Thailand using nucleic acid sequence based amplification assay.
#
# Distance to mean: 2.551248073577881
# Title: Vaccine candidates for dengue virus type 1 (DEN1) generated by replacement of the structural genes of rDEN4 and rDEN4Delta30 with those of DEN1.
#
# Distance to mean: 2.551807165145874
# Title: An outbreak of dengue virus serotype 1 infection in Cixi, Ningbo, People's Republic of China, 2004, associated with a traveler from Thailand and high density of Aedes albopictus.
#
# Distance to mean: 2.5873031616210938
# Title: Identification of dengue virus in respiratory specimens from a patient who had recently traveled from a region where dengue virus infection is endemic.
#
# Year: 2008
#
# Distance to mean: 2.3124008178710938
# Title: Differences in global gene expression in peripheral blood mononuclear cells indicate a significant role of the innate responses in progression of dengue fever but not dengue hemorrhagic fever.
#
# Distance to mean: 2.3798980712890625
# Title: Comparison of two commercially available dengue virus (DENV) NS1 capture enzyme-linked immunosorbent assays using a single clinical sample for diagnosis of acute DENV infection.
#
# Distance to mean: 2.3892228603363037
# Title: Evaluation of the Panbio dengue virus nonstructural 1 antigen detection and immunoglobulin M antibody enzyme-linked immunosorbent assays for the diagnosis of acute dengue infections in Laos.
#
# Distance to mean: 2.478102445602417
# Title: Influence of the dengue serotype, previous dengue infection, and plasma viral load on clinical presentation and outcome during a dengue-2 and dengue-4 co-epidemic.
#
# Distance to mean: 2.5544497966766357
# Title: Infection-enhancing and -neutralizing activities of mouse monoclonal antibodies against dengue type 2 and 4 viruses are controlled by complement levels.
#
# Year: 2009
#
# Distance to mean: 2.1693930625915527
# Title: Dengue fever scoring system: new strategy for the early detection of acute dengue virus infection in Taiwan.
#
# Distance to mean: 2.2899985313415527
# Title: Patterns of gene transcript abundance in the blood of children with severe or uncomplicated dengue highlight differences in disease evolution and host response to dengue virus infection.
#
# Distance to mean: 2.3317501544952393
# Title: Early diagnosis of dengue virus infection by detection of dengue viral antigen in peripheral blood mononuclear cell.
#
# Distance to mean: 2.3486969470977783
# Title: Risk factors associated with development of dengue haemorrhagic fever or dengue shock syndrome in adults in Hospital Tengku Ampuan Afzan Kuantan.
#
# Distance to mean: 2.350781202316284
# Title: Concurrent outbreaks of Chikungunya and Dengue fever in Kandy, Sri Lanka, 2006-07: a comparative analysis of clinical and laboratory features.
#
# Year: 2010
#
# Distance to mean: 2.3125686645507812
# Title: Evaluation of a commercial SD dengue virus NS1 antigen capture enzyme-linked immunosorbent assay kit for early diagnosis of dengue virus infection.
#
# Distance to mean: 2.4354817867279053
# Title: Acute dengue virus 2 infection in Gabonese patients is associated with an early innate immune response, including strong interferon alpha production.
#
# Distance to mean: 2.467155694961548
# Title: Multiple dengue serotypes and high frequency of dengue hemorrhagic fever at two tertiary care hospitals in Lahore during the 2008 dengue virus outbreak in Punjab, Pakistan.
#
# Distance to mean: 2.4991440773010254
# Title: The early whole-blood transcriptional signature of dengue virus and features associated with progression to dengue shock syndrome in Vietnamese children and young adults.
#
# Distance to mean: 2.5659525394439697
# Title: Comparative analysis of full-length genomic sequences of 10 dengue serotype 1 viruses associated with different genotypes, epidemics, and disease severity isolated in Thailand over 22 years.
#
# Year: 2011
#
# Distance to mean: 2.4459073543548584
# Title: Could peak proteinuria determine whether patient with dengue fever develop dengue hemorrhagic/dengue shock syndrome?--a prospective cohort study.
#
# Distance to mean: 2.4539449214935303
# Title: Full serotype- and group-specific NS1 capture enzyme-linked immunosorbent assay for rapid differential diagnosis of dengue virus infection.
#
# Distance to mean: 2.499746084213257
# Title: Evaluation of widely used diagnostic tests to detect West Nile virus infections in horses previously infected with St. Louis encephalitis virus or dengue virus type 2.
#
# Distance to mean: 2.505986213684082
# Title: Factors influencing the seasonal abundance of Aedes (Stegomyia) aegypti and the control strategy of dengue and dengue haemorrhagic fever in Thanlyin Township, Yangon City, Myanmar.
#
# Distance to mean: 2.552097797393799
# Title: Different innate signatures induced in human monocyte-derived dendritic cells by wild-type dengue 3 virus, attenuated but reactogenic dengue 3 vaccine virus, or attenuated nonreactogenic dengue 1-4 vaccine virus strains.
#
# Year: 2012
#
# Distance to mean: 2.3521759510040283
# Title: Diabetes with hypertension as risk factors for adult dengue hemorrhagic fever in a predominantly dengue serotype 2 epidemic: a case control study.
#
# Distance to mean: 2.35634183883667
# Title: Recent introduction and rapid dissemination of Chikungunya virus and Dengue virus serotype 2 associated with human and mosquito coinfections in Gabon, central Africa.
#
# Distance to mean: 2.376591444015503
# Title: Early clinical features of dengue virus infection in nicaraguan children: a longitudinal analysis.
#
# Distance to mean: 2.473890781402588
# Title: Dengue virus identification by transmission electron microscopy and molecular methods in fatal dengue hemorrhagic fever.
#
# Distance to mean: 2.525874614715576
# Title: Dengue viral RNA levels in peripheral blood mononuclear cells are associated with disease severity and preexisting dengue immune status.
#
# Year: 2013
#
# Distance to mean: 2.4434814453125
# Title: Serological characterization of dengue virus infections observed among dengue hemorrhagic fever/dengue shock syndrome cases in upper Myanmar.
#
# Distance to mean: 2.4748101234436035
# Title: Measurement of dengue epidemic spreading pattern using density analysis method: retrospective spatial statistical study of dengue in Subang Jaya, Malaysia, 2006-2010.
#
# Distance to mean: 2.4845731258392334
# Title: Dengue virus neutralization and antibody-dependent enhancement activities of human monoclonal antibodies derived from dengue patients at acute phase of secondary infection.
#
# Distance to mean: 2.5104482173919678
# Title: Laboratory diagnostics of dengue fever: an emphasis on the role of commercial dengue virus nonstructural protein 1 antigen rapid test.
#
# Distance to mean: 2.5252304077148438
# Title: The Nicaraguan pediatric dengue cohort study: incidence of inapparent and symptomatic dengue virus infections, 2004-2010.
#
# Year: 2014
#
# Distance to mean: 2.4189200401306152
# Title: Evaluation of chimeric DNA vaccines consisting of premembrane and envelope genes of Japanese encephalitis and dengue viruses as a strategy for reducing induction of dengue virus infection-enhancing antibody response.
#
# Distance to mean: 2.425257444381714
# Title: Demographic and clinical features of suspected dengue and dengue haemorrhagic fever in the Northern Province of Sri Lanka, a region afflicted by an internal conflict for more than 30 years-a retrospective analysis.
#
# Distance to mean: 2.4300127029418945
# Title: Activation of peripheral blood mononuclear cells by dengue virus infection depotentiates balapiravir.
#
# Distance to mean: 2.431175708770752
# Title: Identification of natural antimicrobial agents to treat dengue infection: In vitro analysis of latarcin peptide activity against dengue virus.
#
# Distance to mean: 2.4418909549713135
# Title: Elevated dengue virus nonstructural protein 1 serum levels and altered toll-like receptor 4 expression, nitric oxide, and tumor necrosis factor alpha production in dengue hemorrhagic Fever patients.
#
# Year: 2015
#
# Distance to mean: 2.3464558124542236
# Title: Morbidity Rate Prediction of Dengue Hemorrhagic Fever (DHF) Using the Support Vector Machine and the Aedes aegypti Infection Rate in Similar Climates and Geographical Areas.
#
# Distance to mean: 2.4981331825256348
# Title: Robust and Balanced Immune Responses to All 4 Dengue Virus Serotypes Following Administration of a Single Dose of a Live Attenuated Tetravalent Dengue Vaccine to Healthy, Flavivirus-Naive Adults.
#
# Distance to mean: 2.5047385692596436
# Title: Discovery of fifth serotype of dengue virus (DENV-5): A new public health dilemma in dengue control.
#
# Distance to mean: 2.5265655517578125
# Title: Clinico-laboratory spectrum of dengue viral infection and risk factors associated with dengue hemorrhagic fever: a retrospective study.
#
# Distance to mean: 2.5443925857543945
# Title: Comparative Susceptibility of Aedes albopictus and Aedes aegypti to Dengue Virus Infection After Feeding on Blood of Viremic Humans: Implications for Public Health.
#
# Year: 2016
#
# Distance to mean: 2.2956197261810303
# Title: Characterization of dengue virus infections in a sample of patients suggests unique clinical, immunological, and virological profiles that impact on the diagnosis of dengue and dengue hemorrhagic fever.
#
# Distance to mean: 2.3737785816192627
# Title: Miscarriage following dengue virus 3 infection in the first six weeks of pregnancy of a dengue virus-naive traveller returning from Bali to Italy, April 2016.
#
# Distance to mean: 2.47544264793396
# Title: Tetravalent Dengue Vaccine Reduces Symptomatic and Asymptomatic Dengue Virus Infections in Healthy Children and Adolescents Aged 2-16 Years in Asia and Latin America.
#
# Distance to mean: 2.499539852142334
# Title: B cells naturally induced during dengue virus infection release soluble CD27, the plasma level of which is associated with severe forms of pediatric dengue.
#
# Distance to mean: 2.517986536026001
# Title: [Co-infection by Chikungunya virus (CHIK-V) and dengue virus (DEN-V) during a recent outbreak in Cali, Colombia: Report of a fatal case].
#
# Year: 2017
#
# Distance to mean: 2.0968518257141113
# Title: Aedes albopictus (Skuse, 1894) infected with the American-Asian genotype of dengue type 2 virus in Medellín suggests its possible role as vector of dengue fever in Colombia.
#
# Distance to mean: 2.2733962535858154
# Title: Social-ecological factors and preventive actions decrease the risk of dengue infection at the household-level: Results from a prospective dengue surveillance study in Machala, Ecuador.
#
# Distance to mean: 2.283127784729004
# Title: Distinguishing Secondary Dengue Virus Infection From Zika Virus Infection With Previous Dengue by a Combination of 3 Simple Serological Tests.
#
# Distance to mean: 2.338925361633301
# Title: Phylogenetic characterization of circulating Dengue and Alkhumra Hemorrhagic Fever viruses in western Saudi Arabia and lack of evidence of Zika virus in the region: A retrospective study, 2010-2015.
#
# Distance to mean: 2.4453654289245605
# Title: NS 1 lasts longer than the dengue virus nucleic acid in the clinically suspected patients with dengue fever and dengue haemorrhagic fever.
#
# Year: 2018
#
# Distance to mean: 2.2304608821868896
# Title: Episodes of the epidemiological factors correlated with prevailing viral infections with dengue virus and molecular characterization of serotype-specific dengue virus circulation in eastern India.
#
# Distance to mean: 2.3292105197906494
# Title: Analyses of clinical and laboratory characteristics of dengue adults at their hospital presentations based on the World Health Organization clinical-phase framework: Emphasizing risk of severe dengue in the elderly.
#
# Distance to mean: 2.3356213569641113
# Title: Complete Coding Sequences of Dengue Virus Type 2 Strains from Febrile Patients Seen in Malindi District Hospital, Kenya, during the 2017 Dengue Fever Outbreak.
#
# Distance to mean: 2.3693277835845947
# Title: In-depth molecular analysis of a small cohort of human and Aedes mosquito (adults and larvae) samples from Kolkata revealed absence of Zika but high prevalence of dengue virus.
#
# Distance to mean: 2.4285686016082764
# Title: Ability To Serologically Confirm Recent Zika Virus Infection in Areas with Varying Past Incidence of Dengue Virus Infection in the United States and U.S. Territories in 2016.
#
# Year: 2019
#
# Distance to mean: 2.291794538497925
# Title: Seroepidemiology of dengue virus infection among adults during the ending phase of a severe dengue epidemic in southern Taiwan, 2015.
#
# Distance to mean: 2.4285712242126465
# Title: Does prior dengue virus exposure worsen clinical outcomes of Zika virus infection? A systematic review, pooled analysis and lessons learned.
#
# Distance to mean: 2.490807056427002
# Title: Epidemiological trends and molecular dynamics of dengue, chikungunya virus infection, coinfection, and other undifferentiated fever during 2015-2016 in Odisha, India.
#
# Distance to mean: 2.491201639175415
# Title: Natural Infection of Aedes aegypti by Chikungunya and Dengue type 2 Virus in a Transition Area of North-Northeast Brazil.
#
# Distance to mean: 2.495626211166382
# Title: Evaluation of commercially available three dengue rapid diagnostic test kits for diagnosis of acute dengue virus infection at the point-of-care setting in Myanmar.
#
# Year: 2020
#
# Distance to mean: 2.31955623626709
# Title: Patterns of signs, symptoms and laboratory values associated with Zika, dengue and undefined acute illnesses in a dengue endemic region: secondary analysis of a prospective cohort study in southern México.
#
# Distance to mean: 2.3530595302581787
# Title: Comparison of clinical presentation and out-comes of Chikungunya and Dengue virus infections in patients with acute undifferentiated febrile illness from the Sindh region of Pakistan.
#
# Distance to mean: 2.4324028491973877
# Title: Assessment of diagnostic and analytic performance of the SD Bioline Dengue Duo test for dengue virus (DENV) infections in an endemic area (Savannakhet province, Lao People's Democratic Republic).
#
# Distance to mean: 2.4339182376861572
# Title: Whole genome sequencing and genetic variations in several dengue virus type 1 strains from unusual dengue epidemic of 2017 in Vietnam.
#
# Distance to mean: 2.4774646759033203
# Title: A vector-host model to assess the impact of superinfection exclusion on vaccination strategies using dengue and yellow fever as case studies.

# %% [markdown]
# ### Quantify novelty of each year by the proportion of papers whose title embeddings are far from previous years' title embeddings

# %%
# threshold distance to consider a paper to be novel
CUTOFF_DISTANCE = 5

# %%
year = year_span[0]

titles_prev = titles[years == year]
title_vectors_prev = title_vectors[years == year]
years_prev = years[years == year]

counts = []

for year in year_span[1:]:
    titles_curr = titles[years == year]
    title_vectors_curr = title_vectors[years == year]
    years_curr = years[years == year]
    
    ds = []
    titles_r, years_r = [], []
    
    count = 0.0
    
    for (title_curr, title_vector_curr, year_curr) in zip(titles_curr, title_vectors_curr, years_curr):
        min_distance = np.inf
        title_min, title_vector_min, year_min = None, None, None
        title_rmin, title_vector_rmin, year_rmin = None, None, None
        for (title_prev, title_vector_prev, year_prev) in zip(titles_prev, title_vectors_prev, years_prev):
            if dist(title_vector_curr, title_vector_prev) < min_distance:
                min_distance = dist(title_vector_curr, title_vector_prev)
                title_min, title_vector_min, year_min = title_curr, title_vector_curr, year_curr
                title_rmin, title_vector_rmin, year_rmin = title_prev, title_vector_prev, year_prev
                
        ds.append(min_distance)
        titles_r.append(title_rmin)
        years_r.append(year_rmin)
        
        if min_distance > CUTOFF_DISTANCE:
            count += 1
                
    ds_sorted, titles_r_sorted, years_r_sorted, titles_curr_sorted = zip(*sorted(zip(ds, titles_r, years_r, titles_curr), key=lambda x: -x[0]))
                                    
    titles_prev = np.concatenate((titles_prev, titles_curr))
    title_vectors_prev = np.concatenate((title_vectors_prev, title_vectors_curr))
    years_prev = np.concatenate((years_prev, years_curr))
    
    counts.append(count / len(years_curr))

# %%
plt.figure(figsize=(20, 10))
plt.scatter(year_span[1:], counts, color='b', s=100)
plt.plot(year_span[1:], counts, color='b')
plt.title(f'Semantic Distance Novelty for {term} from Titles')
plt.xlabel('Year')
plt.ylabel('Proportion of Novel Papers')
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Identify clusters of novel research based on paper titles

# %%
# identify research papers published between year CHANGEPOINT and CHANGEPOINT + DELTA,  such that
# (the mean distance between the paper title and its K nearest neighbors published before CHANGEPOINT)
# is at least RATIO_THRESHOLD times (the mean distance between the paper title and its K nearest neighbors
# also published between CHANGEPOINT and CHANGEPOINT + DELTA)
CHANGEPOINT = 2000
K = 3
DELTA = 5
RATIO_THRESHOLD = 1.2

# %%
titles_old, title_vectors_old, years_old = [], [], []
titles_new, title_vectors_new, years_new = [], [], []

for title, title_vector, year in zip(titles, title_vectors, years):
    if year < CHANGEPOINT:
        titles_old.append(title)
        title_vectors_old.append(title_vector)
        years_old.append(year)
    if year >= CHANGEPOINT and year <= CHANGEPOINT + DELTA:
        titles_new.append(title)
        title_vectors_new.append(title_vector)
        years_new.append(year)
            
for title, title_vector, year in zip(titles_new, title_vectors_new, years_new):
    new_distance = np.mean(sorted([dist(title_vector, t_v) for t_v in title_vectors_new])[1:][:K])
    old_distance = np.mean(sorted([dist(title_vector, t_v) for t_v in title_vectors_old])[:K])
    
    if (old_distance / new_distance) > RATIO_THRESHOLD:
        print(f'Year: {year}')
        print(f'Ratio: {old_distance / new_distance}')
        print(f'New Distance: {new_distance}')
        print(f'Old Distance: {old_distance}')
        print(f'Title: {title}')
        print()
# Out:
# Year: 2005
# Ratio: 1.2052217721939087
# New Distance: 2.3662469387054443
# Old Distance: 2.8518524169921875
# Title: Detection of dengue virus serotype 3 by reverse transcription-polymerase chain reaction in Aedes aegypti (Diptera, Culicidae) captured in Manaus, Amazonas.
#
# Year: 2005
# Ratio: 1.2099249362945557
# New Distance: 4.040247917175293
# Old Distance: 4.888396739959717
# Title: [Ocular complications of dengue fever].
#
# Year: 2005
# Ratio: 1.3647780418395996
# New Distance: 2.6043689250946045
# Old Distance: 3.5543854236602783
# Title: [Study on dengue virus infection of human dendritic cells].
#
# Year: 2005
# Ratio: 1.2462499141693115
# New Distance: 3.182737350463867
# Old Distance: 3.9664859771728516
# Title: Dengue virus type 3, Brazil, 2002.
#
# Year: 2005
# Ratio: 1.2247074842453003
# New Distance: 2.6786012649536133
# Old Distance: 3.280503034591675
# Title: Quantitative trait loci that control dengue-2 virus dissemination in the mosquito Aedes aegypti.
#
# Year: 2004
# Ratio: 1.8007878065109253
# New Distance: 2.2942049503326416
# Old Distance: 4.131376266479492
# Title: Ocular manifestations in Dengue fever.
#
# Year: 2004
# Ratio: 1.26076340675354
# New Distance: 2.54447865486145
# Old Distance: 3.2079856395721436
# Title: Chimpanzee Fab fragments and a derived humanized immunoglobulin G1 antibody that efficiently cross-neutralize dengue type 1 and type 2 viruses.
#
# Year: 2004
# Ratio: 1.8007878065109253
# New Distance: 2.2942049503326416
# Old Distance: 4.131376266479492
# Title: Ocular manifestations of dengue fever.
#
# Year: 2004
# Ratio: 1.2295607328414917
# New Distance: 3.292163133621216
# Old Distance: 4.047914505004883
# Title: Multi-analyte single-membrane biosensor for the serotype-specific detection of Dengue virus.
#
# Year: 2004
# Ratio: 1.3183294534683228
# New Distance: 2.7801783084869385
# Old Distance: 3.6651909351348877
# Title: Safety and efficacy of chimeric yellow Fever-dengue virus tetravalent vaccine formulations in nonhuman primates.
#
# Year: 2004
# Ratio: 1.2045053243637085
# New Distance: 3.027876615524292
# Old Distance: 3.6470935344696045
# Title: A dengue-2 Envelope fragment inserted within the structure of the P64k meningococcal protein carrier enables a functional immune response against the virus in mice.
#
# Year: 2004
# Ratio: 1.2044432163238525
# New Distance: 2.8806936740875244
# Old Distance: 3.4696319103240967
# Title: A fragment of the envelope protein from dengue-1 virus, fused in two different sites of the meningococcal P64k protein carrier, induces a functional immune response in mice.
#
# Year: 2003
# Ratio: 1.2159662246704102
# New Distance: 3.117884635925293
# Old Distance: 3.7912423610687256
# Title: Vaccination of rhesus macaques against dengue-2 virus with a plasmid DNA vaccine encoding the viral pre-membrane and envelope genes.
#
# Year: 2003
# Ratio: 1.3090996742248535
# New Distance: 2.930903434753418
# Old Distance: 3.8368446826934814
# Title: DC-SIGN (CD209) mediates dengue virus infection of human dendritic cells.
#
# Year: 2003
# Ratio: 1.2036150693893433
# New Distance: 2.310868978500366
# Old Distance: 2.7813966274261475
# Title: A live, attenuated dengue virus type 1 vaccine candidate with a 30-nucleotide deletion in the 3' untranslated region is highly attenuated and immunogenic in monkeys.
#
# Year: 2002
# Ratio: 1.2122292518615723
# New Distance: 2.5775516033172607
# Old Distance: 3.1245834827423096
# Title: Recombinant dengue virus type 2 envelope/hepatitis B surface antigen hybrid protein expressed in Pichia pastoris can function as a bivalent immunogen.
#
# Year: 2001
# Ratio: 1.2740144729614258
# New Distance: 2.7621123790740967
# Old Distance: 3.5189712047576904
# Title: Human dendritic cells as targets of dengue virus infection.
#
# Year: 2001
# Ratio: 1.221802830696106
# New Distance: 3.026430368423462
# Old Distance: 3.6977012157440186
# Title: Dengue virus type 3 in Rio de Janeiro, Brazil.
#
# Year: 2001
# Ratio: 1.218772053718567
# New Distance: 2.7079522609710693
# Old Distance: 3.3003766536712646
# Title: Development and evaluation of serotype- and group-specific fluorogenic reverse transcriptase PCR (TaqMan) assays for dengue virus.
#
# Year: 2001
# Ratio: 1.238093376159668
# New Distance: 2.8125617504119873
# Old Distance: 3.4822139739990234
# Title: Expression and purification of Dengue virus type 2 envelope protein as a fusion with hepatitis B surface antigen in Pichia pastoris.
#
# Year: 2001
# Ratio: 1.3416615724563599
# New Distance: 2.7971010208129883
# Old Distance: 3.752762794494629
# Title: Construction, safety, and immunogenicity in nonhuman primates of a chimeric yellow fever-dengue virus tetravalent vaccine.
#
# Year: 2000
# Ratio: 1.326507568359375
# New Distance: 3.5444133281707764
# Old Distance: 4.701691150665283
# Title: [Ocular manifestation in dengue fever].
#
# Year: 2000
# Ratio: 1.2016911506652832
# New Distance: 3.9742472171783447
# Old Distance: 4.77581787109375
# Title: Live attenuated tetravalent dengue vaccine.

# %% [markdown]
# ### Create differential wordclouds for paper titles

# %%
# creates a differential wordcloud for words appearing in year2, vs all words appearing before or during year1
def create_wordcloud(year1, year2):
    freqs_prev = np.sum(v[years <= year1], axis=0) / np.sum(years <= year1)
    freqs_new = np.sum(v[years == year2], axis=0) / np.sum(years == year2)

    diffs = np.subtract(freqs_prev, freqs_new)

    pos_features, neg_features = set(), set()

    d = {}
    for diff, feature in zip(diffs, features_unsorted):
        if feature in stop_words:
            continue

        diff = round(diff * 1000)
        if diff > 0:
            d[feature] = diff
            pos_features.add(feature)
        if diff < 0:
            neg_features.add(feature) 
            d[feature] = -diff

    def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
        if word in pos_features:
            return "rgb(0, 0, 0)"
        if word in neg_features:
            return "rgb(256, 0, 0)"

    wordcloud = WordCloud(background_color='white', height=500, width=1000)
    wordcloud.generate_from_frequencies(frequencies=d)
    plt.figure(figsize=(20, 10))
    plt.imshow(wordcloud.recolor(color_func=color_func, random_state=3),
               interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(1999, 2000)

# %% [markdown]
# ### Abstract length vs time

# %%
lengths = np.array([len(abstract) for abstract in abstracts])
average_lengths = [np.mean(lengths[years == year]) for year in year_span]
stdev_lengths = [np.std(lengths[years == year]) for year in year_span]

plt.figure(figsize=(20, 10))
plt.scatter(year_span, average_lengths, color='b', s=100)
plt.plot(year_span, average_lengths, color='b')
plt.errorbar(year_span, average_lengths, yerr=stdev_lengths, fmt='none', color='b', capsize=20)
plt.title(f'Weekly Abstract Length for {term}')
plt.xlabel('Year')
plt.ylabel('Abstract Length (characters)')
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Abstract entropies vs time

# %%
vectorizer = CountVectorizer()
v = vectorizer.fit_transform(abstracts).toarray()
frequencies_unsorted = np.sum(v, axis=0)
features_unsorted = vectorizer.get_feature_names()
features, frequencies = zip(*sorted(zip(features_unsorted, frequencies_unsorted), key=lambda f: -f[1]))

probabilities = []

for year in year_span:
    t = v[years == year]
    probabilities.append(np.sum(t, axis=0) / np.sum(np.sum(t, axis=0)))

entropies = [-np.sum(np.multiply(probability, np.nan_to_num(np.log2(probability), neginf=0))) for probability in probabilities]

plt.figure(figsize=(20, 10))
plt.plot(year_span, entropies, color='b')
plt.scatter(year_span, entropies, color='b', s=100)
plt.title(f'Yearly Entropy of Abstracts for {term}')
plt.xlabel('Year')
plt.ylabel('Entropy of Abstracts')
plt.rc('font', size=20)
plt.show()
# Out:
# /Users/dddp/Documents/TemporalLandscape/env_TemporalLandscape/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log2
#   del sys.path[0]

# %% [markdown]
# ### Most common words in abstracts

# %%
num_plot = 40

# %%
frequencies_per_abstract = np.divide(frequencies, len(years))

frequencies_plot, features_plot = [], []
for frequency, feature in zip(frequencies_per_abstract, features):
    if feature not in stop_words:
        frequencies_plot.append(frequency)
        features_plot.append(feature)

fig = plt.figure(figsize=(20, 10))
plt.title(f'Word Frequencies in {term} Abstracts')
plt.xlabel('Word')
plt.ylabel('Frequency per Abstract')
plt.bar(range(num_plot), frequencies_plot[1:num_plot+1], color='b')
plt.xticks(range(num_plot), features_plot[1:num_plot+1])
plt.setp(plt.gca().get_xticklabels(), rotation=-90, size=30)
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Word frequency changepoint analysis in publication abstracts

# %%
# only consider words whose average abstract frequency is at least FREQUENCY_THRESHOLD
FREQUENCY_THRESHOLD = 0.05

# only consider words with a changepoint probability of at least PROBABILITY_THRESHOLD
PROBABILITY_THRESHOLD = 0.8

# %%
word_distributions = []
for year in year_span:
    t = v[years == year]
    word_distributions.append(np.sum(t, axis=0) / np.sum(years == year))
word_distributions = np.transpose(word_distributions)

for feature in features:
    if np.mean(word_distributions[features_unsorted.index(feature)]) < FREQUENCY_THRESHOLD:
        break
    
    data_unnormalized = word_distributions[features_unsorted.index(feature)]
    
    data = []
    for i, year in enumerate(year_span):
        if data_unnormalized[i] == 0:
            data.append(0)
        else:
            data.append(data_unnormalized[i] / np.max(data_unnormalized) * 100)
    data = np.array(data)
    
    Q, P, Pcp = offcd.offline_changepoint_detection(data, partial(offcd.const_prior, l=(len(data)+1)), offcd.gaussian_obs_log_likelihood, truncate=-40)
    probs = np.exp(Pcp).sum(0)
    
    if np.max(probs) < PROBABILITY_THRESHOLD:
        continue
    
    plt.figure(figsize=(20, 20))
    plt.subplot(211)
    plt.plot(year_span, word_distributions[features_unsorted.index(feature)], color='b')
    plt.scatter(year_span, word_distributions[features_unsorted.index(feature)], color='b', s=100)
    plt.title(f'Word Frequency Per Abstract for {term}: {feature}')
    plt.xlabel('Year')
    plt.ylabel('Frequency Per Abstract')
    plt.rc('font', size=20)
    
    plt.subplot(212)
    plt.title(f'Changepoint Analysis for {term}: {feature}')
    plt.xlabel('Year')
    plt.ylabel('Changepoint Probability')
    plt.plot(year_span[1:], probs, color='r')
    plt.scatter(year_span[1:], probs, color='r', s=100)
    plt.rc('font', size=20)
    plt.show()

# %% [markdown]
# ### Generate abstract vectors with BioSentVec

# %%
abstracts_processed = [preprocess_sentence(abstract) for abstract in abstracts]
abstract_vectors = model.embed_sentences(abstracts_processed)
abstracts_reduced = PCA(n_components=2).fit_transform(abstract_vectors)

plt.figure(figsize=(15, 10))
plt.scatter(abstracts_reduced.T[0], abstracts_reduced.T[1], c=years, cmap='plasma')
plt.title(f'{term} Abstract Embeddings')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.rc('font', size=20)
plt.colorbar().set_label('Year', rotation=90)
plt.show()

# %%
abstracts_span = np.array([np.mean(abstract_vectors[years == year], axis=0) for year in year_span])
abstracts_span_reduced = PCA(n_components=2).fit_transform(abstracts_span)

plt.figure(figsize=(15, 10))
plt.scatter(abstracts_span_reduced.T[0], abstracts_span_reduced.T[1], c=year_span, cmap='plasma', s=100)
plt.title(f'{term} Average Abstract Embeddings by Year')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar().set_label('Year', rotation=90)

plot_1 = abstracts_span_reduced[:-1]
plot_2 = abstracts_span_reduced[1:]
for i, p1 in enumerate(plot_1):
    p2 = plot_2[i]
    plt.plot([p1[0], p2[0]], [p1[1], p2[1]], color='gray')

plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Identify research trends by identifying the paper abstracts with embeddings closest to the mean for each year

# %%
# number of representative papers to list closest to the mean
NUMBER_OF_PAPERS = 5

# %%
for abstract_mean, year in zip(abstracts_span, year_span):
    abstracts_mod = abstracts[year == years]
    titles_mod = titles[year == years]
    abstract_vectors_mod = abstract_vectors[year == years]
    ds = [dist(abstract_mean, t_v) for t_v in abstract_vectors_mod]
    ds_sorted, abstracts_sorted, titles_sorted = zip(*sorted(zip(ds, abstracts_mod, titles_mod), key=lambda x: x[0]))
    print(f'Year: {year}')
    print()
    for i in range(NUMBER_OF_PAPERS):
        try:
            print(f'Distance to mean: {ds_sorted[i]}')
            print(f'Title: {titles_sorted[i]}')
            print()
        except:
            break
# Out:
# Year: 1987
#
# Distance to mean: 1.389427900314331
# Title: Studies into the immunopathogenesis and laboratory diagnosis of dengue haemorrhagic fever.
#
# Distance to mean: 1.3970098495483398
# Title: Immunization with a live attenuated dengue-2-virus candidate vaccine (16681-PDK 53): clinical, immunological and biological responses in adult volunteers.
#
# Distance to mean: 1.4104970693588257
# Title: Outbreak of febrile illness due to dengue virus type 3 in Calcutta during 1983.
#
# Distance to mean: 1.428335428237915
# Title: Detection of dengue virus RNA using nucleic acid hybridization.
#
# Distance to mean: 1.4803956747055054
# Title: Effect of temperature on the vector efficiency of Aedes aegypti for dengue 2 virus.
#
# Year: 1989
#
# Distance to mean: 1.2585331201553345
# Title: Dengue fever in American military personnel in the Philippines: clinical observations on hospitalized patients during a 1984 epidemic.
#
# Distance to mean: 1.3891081809997559
# Title: Antibody-dependent enhancement of dengue virus growth in human monocytes as a risk factor for dengue hemorrhagic fever.
#
# Distance to mean: 1.3941943645477295
# Title: [Epidemiology of dengue fever in Taiwan].
#
# Distance to mean: 1.4112662076950073
# Title: [Clinical observations of dengue fever among children].
#
# Distance to mean: 1.4285986423492432
# Title: Serological evidence of dengue fever among refugees, Hargeysa, Somalia.
#
# Year: 1990
#
# Distance to mean: 1.2655913829803467
# Title: The dengue viruses.
#
# Distance to mean: 1.2748949527740479
# Title: Measurement of antibody-dependent infection enhancement of four dengue virus serotypes by monoclonal and polyclonal antibodies.
#
# Distance to mean: 1.3219164609909058
# Title: [A study on transovarial transmission of dengue type 1 virus in Aedes aegypti].
#
# Distance to mean: 1.3447887897491455
# Title: Pathogenesis of dengue: an alternative hypothesis.
#
# Distance to mean: 1.3858007192611694
# Title: Dengue virus serotypic identification using suckling mouse and western blot technique.
#
# Year: 1991
#
# Distance to mean: 1.2366033792495728
# Title: [Dengue. A review].
#
# Distance to mean: 1.283697247505188
# Title: Isolation of dengue virus with a human promonocyte cell line.
#
# Distance to mean: 1.3599870204925537
# Title: Outbreak of dengue fever in rural areas of Parbhani district of Maharashtra (India).
#
# Distance to mean: 1.3605443239212036
# Title: The first epidemic of dengue hemorrhagic fever in the People's Republic of China.
#
# Distance to mean: 1.4150817394256592
# Title: Growth of dengue type 2 virus isolates in human peripheral blood leukocytes correlates with severe and mild dengue disease.
#
# Year: 1992
#
# Distance to mean: 1.3575359582901
# Title: Dengue and dengue hemorrhagic fever.
#
# Distance to mean: 1.4213762283325195
# Title: Direct sequence analysis of amplified dengue virus genomic RNA from cultured cells, mosquitoes and mouse brain.
#
# Distance to mean: 1.425437331199646
# Title: Dengue activity in Puerto Rico, 1990.
#
# Distance to mean: 1.4324318170547485
# Title: Detection and differentiation of dengue-1 from Japanese encephalitis virus infections by ABC MAC-ELISA.
#
# Distance to mean: 1.4423747062683105
# Title: Use of dengue blot in dengue diagnosis: the Malaysian experience.
#
# Year: 1993
#
# Distance to mean: 1.2230387926101685
# Title: Dengue in the south-eastern region of Brazil: historical analysis and epidemiology.
#
# Distance to mean: 1.3125576972961426
# Title: Genetic and biological differentiation of dengue 3 isolates obtained from clinical cases in Java, Indonesia, 1976-1978.
#
# Distance to mean: 1.3217781782150269
# Title: [Dengue epidemic in New Caledonia (1989). Environmental factors and prevention].
#
# Distance to mean: 1.3247607946395874
# Title: Use of NS3 consensus primers for the polymerase chain reaction amplification and sequencing of dengue viruses and other flaviviruses.
#
# Distance to mean: 1.3485959768295288
# Title: [Yellow fever virus, dengue 2 and other arboviruses isolated from mosquitos, in Burkina Faso, from 1983 to 1986. Entomological and epidemiological considerations].
#
# Year: 1994
#
# Distance to mean: 1.3959909677505493
# Title: [Study of the relationship dengue-pregnancy in a group of cuban-mothers].
#
# Distance to mean: 1.4684314727783203
# Title: Detection and serotyping of dengue viruses by PCR: a simple, rapid method for the isolation of viral RNA from infected mosquito larvae.
#
# Distance to mean: 1.4749364852905273
# Title: Dengue in the Western Hemisphere.
#
# Distance to mean: 1.4837665557861328
# Title: An epidemic of dengue haemorrhagic fever & dengue shock syndrome in & around Vellore.
#
# Distance to mean: 1.513297438621521
# Title: The differentiation state of monocytic cells affects their susceptibility to infection and the effects of infection by dengue virus.
#
# Year: 1995
#
# Distance to mean: 1.2514203786849976
# Title: Detection of dengue viral RNA by microplate hybridization.
#
# Distance to mean: 1.299525260925293
# Title: Rapid and sensitive streptavidin-biotin amplified fluorogenic enzyme-linked immunosorbent-assay for direct detection and identification of dengue viral antigens in serum.
#
# Distance to mean: 1.3027737140655518
# Title: Dengue fever in U.S. troops during Operation Restore Hope, Somalia, 1992-1993.
#
# Distance to mean: 1.3233414888381958
# Title: [The diagnosis of dengue in Mexico: an update and outlook].
#
# Distance to mean: 1.3573240041732788
# Title: Dengue serologic survey in Ribeirão Preto, São Paulo, Brazil.
#
# Year: 1996
#
# Distance to mean: 1.2173991203308105
# Title: Silent transmission of the dengue virus in southern Taiwan.
#
# Distance to mean: 1.2508106231689453
# Title: [Dengue in Nicaragua, 1994: reintroduction of serotype 3 in the Americas].
#
# Distance to mean: 1.296297311782837
# Title: Dengue hemorrhagic fever.
#
# Distance to mean: 1.3480792045593262
# Title: [New epidemiological aspects of dengue].
#
# Distance to mean: 1.364876627922058
# Title: Primary sequence of the envelope glycoprotein of a dengue type 2 virus isolated from patient with dengue hemorrhagic fever and encephalopathy.
#
# Year: 1997
#
# Distance to mean: 0.9946370124816895
# Title: Emerging viral pathogens in long-term expatriates (II): Dengue virus.
#
# Distance to mean: 1.0710480213165283
# Title: Impact of dengue virus infection and its control.
#
# Distance to mean: 1.2223187685012817
# Title: The first reported outbreak of dengue hemorrhagic fever in Irian Jaya, Indonesia.
#
# Distance to mean: 1.2944010496139526
# Title: Dengue hemorrhagic fever in Jakarta, Indonesia in 1988: isolation of dengue virus from patient whole blood using cell cultures.
#
# Distance to mean: 1.316750407218933
# Title: [Dengue in Panama, 1993].
#
# Year: 1998
#
# Distance to mean: 1.1323596239089966
# Title: Changing clinical and biological manifestations of dengue during the dengue-2 epidemic in French Polynesia in 1996/97--description and analysis in a prospective study.
#
# Distance to mean: 1.1595622301101685
# Title: Molecular evolution of dengue type 2 virus in Thailand.
#
# Distance to mean: 1.2205052375793457
# Title: [Dengue in Martinique in 1995-1996].
#
# Distance to mean: 1.2348837852478027
# Title: Dengue: a review.
#
# Distance to mean: 1.2419474124908447
# Title: [Dengue: a re-emerging disease. A clinical and epidemiological study in 57 Spanish travelers].
#
# Year: 1999
#
# Distance to mean: 1.1899027824401855
# Title: Comments on the epidemiology, pathogenesis and control of dengue.
#
# Distance to mean: 1.240722894668579
# Title: Dengue virus structural differences that correlate with pathogenesis.
#
# Distance to mean: 1.2643837928771973
# Title: Dengue virus infection during post-epidemic period in Delhi, India.
#
# Distance to mean: 1.2869586944580078
# Title: Effects of dengue fever during pregnancy in French Guiana.
#
# Distance to mean: 1.2981815338134766
# Title: Detection of dengue virus RNA in patients after primary or secondary dengue infection by using the TaqMan automated amplification system.
#
# Year: 2000
#
# Distance to mean: 1.232303261756897
# Title: [Development of immunizing agents against dengue].
#
# Distance to mean: 1.2937175035476685
# Title: Prospective study of the duration and magnitude of viraemia in children hospitalised during the 1996-1997 dengue-2 outbreak in French Polynesia.
#
# Distance to mean: 1.3916834592819214
# Title: Dengue infection presenting with central nervous system manifestation.
#
# Distance to mean: 1.4003204107284546
# Title: Epidemiologic studies on Dengue in Santiago de Cuba, 1997.
#
# Distance to mean: 1.4124095439910889
# Title: Dengue situation in Brazil by year 2000.
#
# Year: 2001
#
# Distance to mean: 1.2824037075042725
# Title: [Evaluation of immunity against Venezuelan equine encephalitis virus and dengue in the human population of San Carlos, the Almirante Padilla Island Municipality, Zulia State, Venezuela. 1996].
#
# Distance to mean: 1.2884575128555298
# Title: Seroepidemiology and active surveillance of dengue fever/dengue haemorrhagic fever in Delhi.
#
# Distance to mean: 1.3264696598052979
# Title: An investigation into the cyclical incidence of dengue fever.
#
# Distance to mean: 1.3270690441131592
# Title: Prospective case-control study of encephalopathy in children with dengue hemorrhagic fever.
#
# Distance to mean: 1.3354911804199219
# Title: Bispecific monoclonal antibodies mediate binding of dengue virus to erythrocytes in a monkey model of passive viremia.
#
# Year: 2002
#
# Distance to mean: 1.0592153072357178
# Title: Predominance of the DEN-3 genotype during the recent dengue outbreak in Bangladesh.
#
# Distance to mean: 1.2503474950790405
# Title: The reappearance of dengue-3 and a subsequent dengue-4 and dengue-1 epidemic in Puerto Rico in 1998.
#
# Distance to mean: 1.2543202638626099
# Title: Epidemiology of inapparent and symptomatic acute dengue virus infection: a prospective study of primary school children in Kamphaeng Phet, Thailand.
#
# Distance to mean: 1.2564517259597778
# Title: Detection and identification of dengue-1 virus in clinical samples by a nested-PCR followed by restriction enzyme digestion of amplicons.
#
# Distance to mean: 1.3565068244934082
# Title: Assessment of dengue risk in relief workers in Puerto Rico after Hurricane Georges, 1998.
#
# Year: 2003
#
# Distance to mean: 1.2306420803070068
# Title: Microevolution and virulence of dengue viruses.
#
# Distance to mean: 1.2322620153427124
# Title: Transmission of epidemic dengue hemorrhagic fever in easternmost Indonesia.
#
# Distance to mean: 1.2334671020507812
# Title: Outbreak of dengue fever in Palau, Western Pacific: risk factors for infection.
#
# Distance to mean: 1.258180856704712
# Title: [Laboratory diagnosis of dengue virus infections in Aragua State, Venezuela: October 1997-December 1998].
#
# Distance to mean: 1.3173879384994507
# Title: Molecular epidemiology of dengue virus type 3 in Venezuela.
#
# Year: 2004
#
# Distance to mean: 1.228935956954956
# Title: Dengue: a review of the laboratory tests a clinician must know to achieve a correct diagnosis.
#
# Distance to mean: 1.2757729291915894
# Title: Imported Dengue fever presenting with febrile diarrhoea: report of two cases.
#
# Distance to mean: 1.301110029220581
# Title: Emergence and continued circulation of dengue-2 (genotype IV) virus strains in northern India.
#
# Distance to mean: 1.3306694030761719
# Title: Outbreak of dengue in Mumbai and predictive markers for dengue shock syndrome.
#
# Distance to mean: 1.3361194133758545
# Title: Association of human leukocyte antigen DQ1 and dengue fever in a white Southern Brazilian population.
#
# Year: 2005
#
# Distance to mean: 1.195096492767334
# Title: Secondary dengue virus type 4 infections in Vietnam.
#
# Distance to mean: 1.220125436782837
# Title: Circulating human antibodies against dengue NS1 protein: potential of recombinant D2V-NS1 proteins in diagnostic tests.
#
# Distance to mean: 1.2413265705108643
# Title: Emergence of dengue virus type-3 in northern India.
#
# Distance to mean: 1.2643320560455322
# Title: Laboratory diagnosis of dengue virus infection: current and future perspectives in clinical diagnosis and public health.
#
# Distance to mean: 1.2779899835586548
# Title: Optimized diagnosis of acute dengue fever in Swedish travelers by a combination of reverse transcription-PCR and immunoglobulin M detection.
#
# Year: 2006
#
# Distance to mean: 1.1091272830963135
# Title: Silent transmission of virus during a Dengue epidemic, Nakhon Pathom Province, Thailand 2001.
#
# Distance to mean: 1.1207057237625122
# Title: T cell responses in dengue hemorrhagic fever: are cross-reactive T cells suboptimal?
#
# Distance to mean: 1.2266443967819214
# Title: T cell responses and dengue haemorrhagic fever.
#
# Distance to mean: 1.2318187952041626
# Title: Purification and crystallization of dengue and West Nile virus NS2B-NS3 complexes.
#
# Distance to mean: 1.286835789680481
# Title: Four dengue virus serotypes found circulating during an outbreak of dengue fever and dengue haemorrhagic fever in Jakarta, Indonesia, during 2004.
#
# Year: 2007
#
# Distance to mean: 1.0536781549453735
# Title: Of cascades and perfect storms: the immunopathogenesis of dengue haemorrhagic fever-dengue shock syndrome (DHF/DSS).
#
# Distance to mean: 1.206085205078125
# Title: Progress for dengue virus diseases. Towards the NS2B-NS3pro inhibition for a therapeutic-based approach.
#
# Distance to mean: 1.2486329078674316
# Title: Dengue.
#
# Distance to mean: 1.261146903038025
# Title: Dengue hemorrhagic fever with special emphasis on immunopathogenesis.
#
# Distance to mean: 1.3084732294082642
# Title: [Molecular evolution of dengue virus: a necessary field of research].
#
# Year: 2008
#
# Distance to mean: 1.1537625789642334
# Title: Alternate hypothesis on the pathogenesis of dengue hemorrhagic fever (DHF)/dengue shock syndrome (DSS) in dengue virus infection.
#
# Distance to mean: 1.332754373550415
# Title: Influence of the dengue serotype, previous dengue infection, and plasma viral load on clinical presentation and outcome during a dengue-2 and dengue-4 co-epidemic.
#
# Distance to mean: 1.3449259996414185
# Title: Oral calcium administration attenuates thrombocytopenia in patients with dengue fever. Report of a pilot study.
#
# Distance to mean: 1.3557926416397095
# Title: Dengue in Vietnamese infants--results of infection-enhancement assays correlate with age-related disease epidemiology, and cellular immune responses correlate with disease severity.
#
# Distance to mean: 1.3582261800765991
# Title: Development and evaluation of a 1-step duplex reverse transcription polymerase chain reaction for differential diagnosis of chikungunya and dengue infection.
#
# Year: 2009
#
# Distance to mean: 1.1297731399536133
# Title: Is dengue a threat to the blood supply?
#
# Distance to mean: 1.1620067358016968
# Title: [Dengue fever: from disease to vaccination].
#
# Distance to mean: 1.1939692497253418
# Title: [Pathophysiological mechanisms of dengue fever: critical review of current concepts].
#
# Distance to mean: 1.2147161960601807
# Title: Dengue is a major global health problem. Foreword.
#
# Distance to mean: 1.2337632179260254
# Title: The Nicaraguan pediatric dengue cohort study: study design, methods, use of information technology, and extension to other infectious diseases.
#
# Year: 2010
#
# Distance to mean: 1.2207497358322144
# Title: Update on dengue: epidemiology, virus evolution, antiviral drugs, and vaccine development.
#
# Distance to mean: 1.2208225727081299
# Title: Prospective cohort studies of dengue viral transmission and severity of disease.
#
# Distance to mean: 1.227967381477356
# Title: Index cluster study of dengue virus infection in Nicaragua.
#
# Distance to mean: 1.2714042663574219
# Title: Dengue virus virulence and transmission determinants.
#
# Distance to mean: 1.3016159534454346
# Title: Markers of dengue disease severity.
#
# Year: 2011
#
# Distance to mean: 1.1028553247451782
# Title: Unusual dengue virus 3 epidemic in Nicaragua, 2009.
#
# Distance to mean: 1.1422749757766724
# Title: Dengue virus type 3 isolated from a fatal case with visceral complications induces enhanced proinflammatory responses and apoptosis of human dendritic cells.
#
# Distance to mean: 1.1771600246429443
# Title: Inhibition of dengue virus infections in cell cultures and in AG129 mice by a small interfering RNA targeting a highly conserved sequence.
#
# Distance to mean: 1.185052514076233
# Title: An in-depth analysis of original antigenic sin in dengue virus infection.
#
# Distance to mean: 1.2412495613098145
# Title: A molecular evaluation of dengue virus pathogenesis and its latest vaccine strategies.
#
# Year: 2012
#
# Distance to mean: 1.2255371809005737
# Title: Dengue in India.
#
# Distance to mean: 1.2370312213897705
# Title: The burden of dengue infection in some vulnerable regions of Nepal.
#
# Distance to mean: 1.251517653465271
# Title: Use of parallel validation high-throughput screens to reduce false positives and identify novel dengue NS2B-NS3 protease inhibitors.
#
# Distance to mean: 1.256820797920227
# Title: Characterization of a model of lethal dengue virus 2 infection in C57BL/6 mice deficient in the alpha/beta interferon receptor.
#
# Distance to mean: 1.2778091430664062
# Title: Screening of Dengue virus antiviral activity of marine seaweeds by an in situ enzyme-linked immunosorbent assay.
#
# Year: 2013
#
# Distance to mean: 1.052315592765808
# Title: Challenges for the formulation of a universal vaccine against dengue.
#
# Distance to mean: 1.134393572807312
# Title: Can non-human primates serve as models for investigating dengue disease pathogenesis?
#
# Distance to mean: 1.1719897985458374
# Title: Epidemiology of dengue: past, present and future prospects.
#
# Distance to mean: 1.2138534784317017
# Title: Dengue viruses - an overview.
#
# Distance to mean: 1.2220499515533447
# Title: [An imported dengue Fever case in Turkey and review of the literature].
#
# Year: 2014
#
# Distance to mean: 1.0434699058532715
# Title: Viral immune evasion in dengue: toward evidence-based revisions of clinical practice guidelines.
#
# Distance to mean: 1.1310219764709473
# Title: [Is the fight against dengue complicated with the emergence of a new viral serotype?].
#
# Distance to mean: 1.1390260457992554
# Title: [Modern immunological and clinical determinants of virus dengue infection].
#
# Distance to mean: 1.1434741020202637
# Title: Dengue Antibody-Dependent Enhancement: Knowns and Unknowns.
#
# Distance to mean: 1.1490833759307861
# Title: Seroprevalence of Dengue Fever in US Army Special Operations Forces: Initial Results and the Way Ahead.
# Year: 2015
#
# Distance to mean: 1.071252703666687
# Title: A Dengue Virus Type 4 Model of Disseminated Lethal Infection in AG129 Mice.
#
# Distance to mean: 1.080265998840332
# Title: Is transfusion-transmitted dengue fever a potential public health threat?
#
# Distance to mean: 1.1847037076950073
# Title: High Anti-Dengue Virus Activity of the OAS Gene Family Is Associated With Increased Severity of Dengue.
#
# Distance to mean: 1.1973382234573364
# Title: Dengue human infection models to advance dengue vaccine development.
#
# Distance to mean: 1.2119858264923096
# Title: A survey of the 2014 dengue fever epidemic in Guangzhou, China.
#
# Year: 2016
#
# Distance to mean: 1.100414514541626
# Title: An epidemiological study of dengue in Delhi, India.
#
# Distance to mean: 1.101154088973999
# Title: Changing pattern of dengue virus serotypes circulating during 2008-2012 and reappearance of dengue serotype 3 may cause outbreak in Kolkata, India.
#
# Distance to mean: 1.115261197090149
# Title: Short Report: Serological Evidence of Under-Reported Dengue Circulation in Sierra Leone.
#
# Distance to mean: 1.1231845617294312
# Title: Clinical Survey of Dengue Virus Circulation in the Republic of Djibouti between 2011 and 2014 Identifies Serotype 3 Epidemic and Recommends Clinical Diagnosis Guidelines for Resource Limited Settings.
#
# Distance to mean: 1.1285661458969116
# Title: Current perspectives on dengue episode in Malaysia.
#
# Year: 2017
#
# Distance to mean: 1.0908371210098267
# Title: Dengue Virus Serotypes 1 and 2 Responsible for Major Dengue Outbreaks in Nepal: Clinical, Laboratory, and Epidemiological Features.
#
# Distance to mean: 1.0983359813690186
# Title: A lethal model of disseminated dengue virus type 1 infection in AG129 mice.
#
# Distance to mean: 1.099858283996582
# Title: Global Epidemiology of Dengue Outbreaks in 1990-2015: A Systematic Review and Meta-Analysis.
#
# Distance to mean: 1.1763709783554077
# Title: Molecular studies with Aedes (Stegomyia) aegypti (Linnaeus, 1762), mosquito transmitting the dengue virus.
#
# Distance to mean: 1.1829625368118286
# Title: [Role of dendritic cells in infection by dengue virus: targets for replication and immune response].
#
# Year: 2018
#
# Distance to mean: 1.0659574270248413
# Title: Early Detection of Plasma Leakage in Dengue Hemorrhagic Fever.
#
# Distance to mean: 1.111186146736145
# Title: Baseline Characterization of Dengue Epidemiology in Yogyakarta City, Indonesia, before a Randomized Controlled Trial of Wolbachia for Arboviral Disease Control.
#
# Distance to mean: 1.119075059890747
# Title: Detection and serotyping of dengue viruses in febrile patients consulting at the New-Bell District Hospital in Douala, Cameroon.
#
# Distance to mean: 1.1245801448822021
# Title: History, epidemiology and diagnostics of dengue in the American and Brazilian contexts: a review.
#
# Distance to mean: 1.1254521608352661
# Title: Complete assembly of a dengue virus type 3 genome from a recent genotype III clade by metagenomic sequencing of serum.
#
# Year: 2019
#
# Distance to mean: 1.0661747455596924
# Title: Recent advances in understanding dengue.
#
# Distance to mean: 1.1318740844726562
# Title: Unusual clinical manifestations of dengue disease - Real or imagined?
#
# Distance to mean: 1.1407526731491089
# Title: Clinical relevance of gallbladder wall thickening for dengue severity: A cross-sectional study.
#
# Distance to mean: 1.171319603919983
# Title: T-Cell mediated adaptive immunity and antibody-dependent enhancement in secondary dengue infection.
#
# Distance to mean: 1.1734614372253418
# Title: Cross-serotype interactions and disease outcome prediction of dengue infections in Vietnam.
#
# Year: 2020
#
# Distance to mean: 1.0916290283203125
# Title: Key Findings and Comparisons From Analogous Case-Cluster Studies for Dengue Virus Infection Conducted in Machala, Ecuador, and Kamphaeng Phet, Thailand.
#
# Distance to mean: 1.0957807302474976
# Title: Mobile Laboratory Reveals the Circulation of Dengue Virus Serotype I of Asian Origin in Medina Gounass (Guediawaye), Senegal.
#
# Distance to mean: 1.1274769306182861
# Title: Humanized Mice in Dengue Research: A Comparison with Other Mouse Models.
#
# Distance to mean: 1.1508045196533203
# Title: Multivariate time-series analysis of biomarkers from a dengue cohort offers new approaches for diagnosis and prognosis.
#
# Distance to mean: 1.1635663509368896
# Title: Dengue Fever and Severe Dengue in Barbados, 2008-2016.

# %% [markdown]
# ### Quantify novelty of each year by the proportion of papers whose abstract embeddings are far from previous years' abstract embeddings

# %%
# threshold distance to consider a paper to be novel
CUTOFF_DISTANCE = 5

# %%
year = year_span[0]

abstracts_prev = abstracts[years == year]
abstract_vectors_prev = abstract_vectors[years == year]
abstracts_prev = years[years == year]

counts = []

for year in year_span[1:]:
    abstracts_curr = abstracts[years == year]
    abstract_vectors_curr = abstract_vectors[years == year]
    years_curr = years[years == year]
    
    ds = []
    abstracts_r, years_r = [], []
    
    count = 0.0
    
    for (abstract_curr, abstract_vector_curr, year_curr) in zip(abstracts_curr, abstract_vectors_curr, years_curr):
        min_distance = np.inf
        abstract_min, abstract_vector_min, year_min = None, None, None
        abstract_rmin, abstract_vector_rmin, year_rmin = None, None, None
        for (abstract_prev, abstract_vector_prev, year_prev) in zip(abstracts_prev, abstract_vectors_prev, years_prev):
            if dist(abstract_vector_curr, abstract_vector_prev) < min_distance:
                min_distance = dist(abstract_vector_curr, abstract_vector_prev)
                abstract_min, abstract_vector_min, year_min = abstract_curr, abstract_vector_curr, year_curr
                abstract_rmin, abstract_vector_rmin, year_rmin = abstract_prev, abstract_vector_prev, year_prev
                
        ds.append(min_distance)
        abstracts_r.append(abstract_rmin)
        years_r.append(year_rmin)
        
        if min_distance > CUTOFF_DISTANCE:
            count += 1
                
    ds_sorted, abstracts_r_sorted, years_r_sorted, abstracts_curr_sorted = zip(*sorted(zip(ds, abstracts_r, years_r, abstracts_curr), key=lambda x: -x[0]))
                                    
    abstracts_prev = np.concatenate((abstracts_prev, abstracts_curr))
    abstract_vectors_prev = np.concatenate((abstract_vectors_prev, abstract_vectors_curr))
    years_prev = np.concatenate((years_prev, years_curr))
    
    counts.append(count / len(years_curr))

# %%
plt.figure(figsize=(20, 10))
plt.scatter(year_span[1:], counts, color='b', s=100)
plt.plot(year_span[1:], counts, color='b')
plt.title(f'Semantic Distance Novelty for {term} from Abstracts')
plt.xlabel('Year')
plt.ylabel('Proportion of Novel Papers')
plt.rc('font', size=20)
plt.show()

# %% [markdown]
# ### Identify clusters of novel research based on paper abstracts

# %%
# identify research papers published between year CHANGEPOINT and CHANGEPOINT + DELTA,  such that
# (the mean distance between the paper abstract and its K nearest neighbors published before week CHANGEPOINT)
# is at least RATIO_THRESHOLD times (the mean distance between the paper abstract and its K nearest neighbors
# also published between CHANGEPOINT and CHANGEPOINT + DELTA)
CHANGEPOINT = 2000
K = 3
DELTA = 5
RATIO_THRESHOLD = 1.2

# %%
abstracts_old, abstract_vectors_old, years_old = [], [], []
abstracts_new, abstract_vectors_new, years_new, titles_new = [], [], [], []

for abstract, abstract_vector, year in zip(abstracts, abstract_vectors, years):
    if year < CHANGEPOINT:
        abstracts_old.append(abstract)
        abstract_vectors_old.append(abstract_vector)
        years_old.append(year)
    if year >= CHANGEPOINT and year <= CHANGEPOINT + DELTA:
        abstracts_new.append(abstract)
        abstract_vectors_new.append(abstract_vector)
        years_new.append(year)
        titles_new.append(title)
            
for abstract, abstract_vector, year, title in zip(abstracts_new, abstract_vectors_new, years_new, titles_new):
    new_distance = np.mean(sorted([dist(abstract_vector, t_v) for t_v in abstract_vectors_new])[1:][:K])
    old_distance = np.mean(sorted([dist(abstract_vector, t_v) for t_v in abstract_vectors_old])[:K])
    
    if (old_distance / new_distance) > RATIO_THRESHOLD:
        print(f'Year: {year}')
        print(f'Ratio: {old_distance / new_distance}')
        print(f'New Distance: {new_distance}')
        print(f'Old Distance: {old_distance}')
        print(f'Title: {title}')
        print()
# Out:
# Year: 2005
# Ratio: 1.2066296339035034
# New Distance: 1.550586223602295
# Old Distance: 1.8709832429885864
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2005
# Ratio: 1.3255099058151245
# New Distance: 1.6203864812850952
# Old Distance: 2.1478383541107178
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2005
# Ratio: 1.2304691076278687
# New Distance: 1.4757214784622192
# Old Distance: 1.8158296346664429
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2005
# Ratio: 1.295111060142517
# New Distance: 1.2600386142730713
# Old Distance: 1.6318899393081665
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2005
# Ratio: 1.2115477323532104
# New Distance: 1.6101655960083008
# Old Distance: 1.9507924318313599
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2005
# Ratio: 1.341033697128296
# New Distance: 1.782723069190979
# Old Distance: 2.3906917572021484
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2005
# Ratio: 1.2371885776519775
# New Distance: 1.6352977752685547
# Old Distance: 2.0231716632843018
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2005
# Ratio: 1.2620465755462646
# New Distance: 1.501956582069397
# Old Distance: 1.8955391645431519
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2005
# Ratio: 1.2316521406173706
# New Distance: 1.6127427816390991
# Old Distance: 1.9863380193710327
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2005
# Ratio: 1.2344998121261597
# New Distance: 1.633664608001709
# Old Distance: 2.016758680343628
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2004
# Ratio: 1.486840844154358
# New Distance: 1.6745883226394653
# Old Distance: 2.4898462295532227
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2004
# Ratio: 1.2879146337509155
# New Distance: 1.6334056854248047
# Old Distance: 2.103687047958374
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2004
# Ratio: 1.2417373657226562
# New Distance: 1.2782384157180786
# Old Distance: 1.5872364044189453
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2004
# Ratio: 1.2784503698349
# New Distance: 1.522316813468933
# Old Distance: 1.9462064504623413
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2004
# Ratio: 1.2249746322631836
# New Distance: 1.3325384855270386
# Old Distance: 1.6323257684707642
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2004
# Ratio: 1.249392032623291
# New Distance: 1.4527021646499634
# Old Distance: 1.81499445438385
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2003
# Ratio: 1.2506722211837769
# New Distance: 1.575567603111267
# Old Distance: 1.970518708229065
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2003
# Ratio: 1.2195971012115479
# New Distance: 1.8073883056640625
# Old Distance: 2.2042856216430664
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2003
# Ratio: 1.2074936628341675
# New Distance: 1.4404325485229492
# Old Distance: 1.7393131256103516
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2003
# Ratio: 1.2010751962661743
# New Distance: 1.5369802713394165
# Old Distance: 1.8460288047790527
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2003
# Ratio: 1.274084210395813
# New Distance: 1.7142668962478638
# Old Distance: 2.1841204166412354
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2002
# Ratio: 1.214287519454956
# New Distance: 1.2690757513046265
# Old Distance: 1.541022777557373
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2002
# Ratio: 1.2221380472183228
# New Distance: 1.19224214553833
# Old Distance: 1.4570845365524292
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2002
# Ratio: 1.2065633535385132
# New Distance: 1.4053200483322144
# Old Distance: 1.6956076622009277
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2001
# Ratio: 1.29918372631073
# New Distance: 1.6041816473007202
# Old Distance: 2.0841267108917236
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2001
# Ratio: 1.2370635271072388
# New Distance: 1.2759681940078735
# Old Distance: 1.5784536600112915
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2001
# Ratio: 1.2512558698654175
# New Distance: 1.868983268737793
# Old Distance: 2.338576316833496
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2001
# Ratio: 1.2220466136932373
# New Distance: 1.4779280424118042
# Old Distance: 1.8060970306396484
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2000
# Ratio: 1.3878775835037231
# New Distance: 1.6479378938674927
# Old Distance: 2.2871360778808594
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.
#
# Year: 2000
# Ratio: 1.2662885189056396
# New Distance: 1.6930135488510132
# Old Distance: 2.143843650817871
# Title: Alpha-glucosidase inhibitors reduce dengue virus production by affecting the initial steps of virion morphogenesis in the endoplasmic reticulum.

# %% [markdown]
# ### Create differential wordclouds for paper abstracts

# %%
# creates a differential wordcloud for words appearing in year2, vs all words appearing before or during year1
def create_wordcloud(year1, year2):
    freqs_prev = np.sum(v[years <= year1], axis=0) / np.sum(years <= year1)
    freqs_new = np.sum(v[years == year2], axis=0) / np.sum(years == year2)

    diffs = np.subtract(freqs_prev, freqs_new)

    pos_features, neg_features = set(), set()

    d = {}
    for diff, feature in zip(diffs, features_unsorted):
        if feature in stop_words:
            continue

        diff = round(diff * 1000)
        if diff > 0:
            d[feature] = diff
            pos_features.add(feature)
        if diff < 0:
            neg_features.add(feature) 
            d[feature] = -diff

    def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
        if word in pos_features:
            return "rgb(0, 0, 0)"
        if word in neg_features:
            return "rgb(256, 0, 0)"

    wordcloud = WordCloud(background_color='white', height=500, width=1000)
    wordcloud.generate_from_frequencies(frequencies=d)
    plt.figure(figsize=(20, 10))
    plt.imshow(wordcloud.recolor(color_func=color_func, random_state=3),
               interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
create_wordcloud(1999, 2000)
